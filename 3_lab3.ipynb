# %% [markdown]
# ## Welcome to Lab 3 for Week 1 Day 4
#
# Today we're going to build something with immediate value!
#
# In the folder `me` I've put a single file `linkedin.pdf` - it's a PDF download of my LinkedIn profile.
#
# Please replace it with yours!
#
# I've also made a file called `summary.txt`
#
# We're not going to use Tools just yet - we're going to add the tool tomorrow.

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/tools.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#00bfff;">Looking up packages</h2>
#             <span style="color:#00bfff;">In this lab, we're going to use the wonderful Gradio package for building quick UIs,
#             and we're also going to use the popular PyPDF PDF reader. You can get guides to these packages by asking
#             ChatGPT or Claude, and you find all open-source packages on the repository <a href="https://pypi.org">https://pypi.org</a>.
#             </span>
#         </td>
#     </tr>
# </table>

# %%
# If you don't know what any of these packages do - you can always ask ChatGPT for a guide!

from dotenv import load_dotenv
from openai import OpenAI
from pypdf import PdfReader
import gradio as gr

# %%
load_dotenv(override=True)
openai = OpenAI()

# %%
reader = PdfReader("me/linkedin.pdf")
linkedin = ""
for page in reader.pages:
    text = page.extract_text()
    if text:
        linkedin += text

reader = PdfReader("me/Cam_Dresie_Resume_2026_GPM.pdf")
resume = ""
for page in reader.pages:
    text = page.extract_text()
    if text:
        resume += text
# Out:
# Ignoring wrong pointing object 8 0 (offset 0)
# Ignoring wrong pointing object 13 0 (offset 0)
# Ignoring wrong pointing object 38 0 (offset 0)

# %%
print(linkedin)
# Out:
#
# Contact
# camdresie@gmail.com
# www.linkedin.com/in/camdresie
# (LinkedIn)
# Top Skills
# Artificial Intelligence (AI)
# Product Management
# Product Strategy
# Languages
# English (Native or Bilingual)
# French (Limited Working)
# Spanish (Elementary)
# Certifications
# Attorney
# Certificate in Corporate Law
# AI Strategy
# AI Product Management
# Specialization
# Mastering Product Management
# Honors-Awards
# 2nd Place Overall and People's
# Choice - MOSA Spring Hackathon
# 2021
# Dean's Fellowship Award
# Cam Dresie
# Group Product Manager @ Ontra | GenAI, Agentic AI, Product
# Management
# Las Vegas Metropolitan Area
# Summary
# As Group Product Manager at Ontra for our flagship product,
# Contract Automation, I champion innovation through AI-enabled
# solutions and robust product management. I believe great products
# come from high-trust teams with clear outcomes and room to create.
# The teams I lead excel at turning complex customer problems into
# shipped, impactful solutions.
# I invest in people: candid feedback, visible expectations, and career
# coaching are baked into our operating rhythms. The result is a
# culture that experiments, has freedom to fail, learns quickly, and
# consistently delivers business impact. Known for my inspiring
# leadership style and clear communication, I ensure that our products
# exceed customer expectations through strategic product vision and
# execution on that vision.
# My technical acumen and background in business and legal domains
# allow me to adeptly navigate complex challenges which gives me
# a unique edge in crafting product strategy. My management style
# empowers teams to excel, fostering a culture of transparency,
# innovation, and relentless pursuit of excellence.
# Outside the office, I’m an avid hiker, runner, and reader, with a
# particular fondness for Walter Isaacson's biography of Leonardo Da
# Vinci. I also love spending time with my husband, attending concerts,
# and spending quality time with our family Labradoodle, Koda.
# Experience
# Ontra
# 4 years 3 months
# Group Product Manager
# August 2025 - Present (7 months)
# Las Vegas Metropolitan Area
#   Page 1 of 6
# Staff Product Manager
# January 2025 - August 2025 (8 months)
# Las Vegas, Nevada, United States
# Ontra is the global leader in contract automation and intelligence for private
# asset management firms. Ontra combines AI-enabled software with a
# worldwide network of highly trained professionals to digitally transform
# recurring legal workflows. Ontra’s solutions improve the contract lifecycle
# — from contract negotiation and processing to tracking complex agreement
# obligations. Ontra works with the world’s leading investment banks, private
# equity and venture capital firms, and direct lenders to reduce the time,
# expense, and risk associated with contract management. Learn more
# at www.ontra.ai.
# Senior Product Manager
# July 2023 - December 2024 (1 year 6 months)
# Las Vegas, Nevada, United States
# As a Senior Product Manager in Ontra's Contract Automation division, I
# specialize in harnessing the power of AI and machine learning to develop
# innovative solutions that are reshaping the legal and private equity industries.
# With a deep understanding of AI-driven technologies, I have successfully
# delivered cutting-edge features and tools that automate attorney workflows,
# maximize business impacts, and drive growth.
# Collaborating closely with cross-functional teams and stakeholders, I create
# strategic roadmaps and lead the development of transformative projects to
# execute on that roadmap.
# Product Manager
# July 2022 - July 2023 (1 year 1 month)
# Los Angeles, California, United States
# Associate Product Manager
# December 2021 - July 2022 (8 months)
# Los Angeles, California, United States
# Stack Moxie
# Technical Product Manager/Software Engineer IV
# March 2021 - December 2021 (10 months)
# Los Angeles, California, United States
#   Page 2 of 6
# • Created user stories, created wireframes, and maintained an emphasis on
# superior UX and UI. Championed data-driven decisions about development,
# acting as a go-to product resource.
# • Advocated for essential features and earned a reputation as a knowledgeable
# innovator.
# • Enabled the smooth delivery of features from inception through release
# and promotion, using processes that were recognized and adopted as a gold
# standard.
# • Built scalable solutions for an enterprise-grade, web-hook-based testing
# framework for marketing operations professionals, receiving the best possible
# monthly reviews in a high-stress workplace.
# • Guided the “Published Values” feature for automated testing to increase
# coordination with other RevOps platforms.
# University of Pennsylvania
# Graduate Teaching Assistant - Intro to Computer Systems
# December 2020 - May 2021 (6 months)
# Los Angeles, California, United States
# • Lead recitations and office hours for groups of students on topics including
# instruction set architecture, programming in C and assembly language,
# computer architecture, and more
# • Grade and debug student assignments in assembly language and C
# • Develop course materials to present complex topics in an understandable
# way
# Above the Bar Legal Recruiting
# Legal Recruiter
# October 2018 - April 2020 (1 year 7 months)
# West Hollywood, California
# • Specialized in attorney lateral associate and partner recruiting for top-tier law
# firms and Fortune 500 companies
# • Developed Above The Bar’s partner recruiting and in-house recruiting
# practices, significantly expanding the company’s recruiting services
# • Established representation of a candidate pool of associates and partners of
# AmLaw 200 firms, top-tier boutique firms, Big Four accounting firms, and in-
# house general counsels
# • Provided comprehensive career services, including resume review and
# counseling, targeted interview preparation, career advice, and market research
# on behalf of candidates
#   Page 3 of 6
# • Negotiated personnel needs, contract terms, terms of employment, candidate
# salaries, and more with partners and recruiting managers
# McInnes Law LLC
# Consulting Attorney
# June 2019 - December 2019 (7 months)
# • Consulted on legal strategy for cases and drafted pleadings to the court to
# reflect those arguments
# • Provided guidance on the California Consumer Privacy Act (CCPA) and
# General Data Protection Regulation (GDPR) private right of action and
# requirements for corporate compliance
# • Researched new and emerging areas of data privacy and corporate
# compliance to identify new cases for the firm
# • Acquired new cases and clients for the firm
# CyberCoders
# Executive Recruiter
# May 2018 - October 2018 (6 months)
# Orange County, California Area
# • Developed a legal recruiting vertical at a 500-person technical staffing firm
# • Specialized in attorney lateral recruiting for firms of all sizes, in-house
# counsel roles, and public interest attorney roles across legal practice areas
# • Grew a clientele base consisting of numerous AmLaw 200 firms and Fortune
# 500 companies
# • Established representation of a candidate pool including partners of AmLaw
# 200 firms and general counsels of Fortune 500 companies
# • Managed end-to-end recruitment services, including identifying new clients,
# developing a book of business, as well as finding and placing candidates in
# positions
# • Completed rigorous eight-week training program focusing on fundamentals
# and advanced strategies of full-desk recruiting
# • Negotiated personnel needs, contract terms, and candidate salaries with
# corporate executives
# Lambda Legal
# Law Clerk
# January 2018 - May 2018 (5 months)
# Greater Los Angeles Area
# • Researched complex issues for legislative advocacy, bill drafting, public
# education campaigns, and appellate briefs
#   Page 4 of 6
# • Interviewed potential plaintiffs to evaluate their potential as impact litigation
# case representatives, taking into consideration relevant legal arguments,
# public perception of the individual, and optics of the case
# • Developed and executed multiple targeted national public education and
# advertising campaigns to influence public opinion
# • Strategically evaluated and targeted groups for campaigns based on the
# likelihood of influencing their opinion
# • Utilized strategic videos, press releases, and impact interviews as elements
# of public education campaigns
# • Problem-solved to find creative solutions to pressing legal and public policy
# issues impacting the LGBT community
# • Wrote press releases, briefs to the court, and comprehensive internal
# memoranda conveying research findings
# Paul McInnes LLP
# Law Clerk
# May 2016 - August 2017 (1 year 4 months)
# Kansas City, Missouri Area
# • Communicated complex and nuanced legal concepts to clients with varying
# levels of education and legal understanding
# • Managed a full caseload independently
# • Interviewed clients for roles as potential plaintiffs
# • Filmed client experience interviews and edited videos to be presented to
# opposing party with request for settlement
# • Presented the results of research findings to the firm’s partners
# • Drafted oral arguments and coached partners for presentation to the court
# • Presented pitches to clients on behalf of the firm, leading to acquisition of 28
# new clients
# Education
# University of Pennsylvania
# Master's Degree, Computer and Information Technology · (2020 - 2022)
# Washington University in St. Louis School of Law
# Doctor of Law (J.D.); Corporate Law Certificate, Law · (2015 - 2018)
# University of California, Los Angeles - School of Law
# Law · (August 2017 - December 2017)
#   Page 5 of 6
# Truman State University
# Bachelor of Arts (B.A.), Philosophy and Religious Studies · (2011 - 2015)
#   Page 6 of 6

# %%
print(resume)
# Out:
# Cam Dresie, MCIT, Esq. !"#
#  HENDERSON, NV  (816) 799-1824 *
#
# CAMDRESIE@GMAIL.COM
#
#
# WWW.LINKEDIN.COM/IN/CAMDRESIE
#
# HTTPS://WWW.CAMDRESIE.COM
#
# HTTPS://BEYOND-THE-BACKLOG.GHOST.IO/
#
# GROUP PRODUCT MANAGER – Product Strategy / Agentic AI & GenAI / Product Team Development AI Product leader with a background that spans law, software engineering, & machine learning. Leads empowered product teams that translate ambitious vision into customer-focused multi-quarter roadmaps through rapid experimentation & tight feedback loops to ship durable, innovative solutions. Develops best-in-class talent by setting clear expectations in a psychologically safe environment so teams can challenge assumptions, fail fast, learn loudly, & consistently deliver. Cultivates AI-native teams that build agentic systems—multi-step, tool-using AI workflows that autonomously reason, plan, & execute—using disciplined experimentation & sharp product strategy to ship products that drive customer-focused business outcomes. CORE STRENGTHS Leadership & Management: Org-wide vision & narrative | Multi-squad ownership & orchestration | PM hiring, performance management, coaching, & development | Cultivating a psychologically safe culture of learning | Executive & cross-functional alignment Product Strategy: Outcome-driven, metric-led roadmaps that maximize customer value | Continuous discovery & opportunity assessment | 0→1 & 1→N product development | OKR design & strategic prioritization Execution Excellence: Complex, multi-team product launches | Agentic AI & LLM-powered product development | Experimentation& agentic AI evaluation (eval) frameworks | GTM partnership & sales alignment| Customer feedback systems (discovery programs, GTM/CS feedback pipelines) that inform roadmap & prioritization Domain & Technical: B2B SaaS | Legal technology | Enterprise & mid-market customers | Regulated industries & risk-sensitive customers | AI coding & agentic developer tools (Claude Code, Cursor, Copilot) | AI prototyping | ML development lifecycle | Agentic AI architecture, orchestration, & tool-use patterns PROFESSIONAL EXPERIENCE Ontra              2025 – Present   Group Product Manager Lead strategy, roadmap, & execution for Ontra’s flagship product (>90% company revenue), managing multiple PMs & squads building AI-first workflows & tools for lawyers, investment banking, & private equity professionals & growing revenue from ~$64M to ~$170M. § Own product vision & multi-year strategy for flagship product line, aligning executive leadership & GTM partners on outcomes for the product, translating strategy for achieving vision into resourced org design & squad-level charters so every team owns a clear, measurable slice of the vision. § Manage & coach 2 Senior PMs leading their own product teams while directly owning 2 additional squads; implement rituals, feedback loops, & growth plans that raise PM craft & create psychologically safe, high-performing teams.  § Co-lead quarterly company-wide & product-line OKR process, ensuring all product objectives ladder into top-level business goals & create clear, measurable alignment across squads & functions. § Develop & institutionalize Ontra’s AI best-practices framework with ML leadership—codifying design patterns for agentic workflows, tool-use orchestration, search, chunking, extraction, summarization, & editing—democratizing AI solution design for non-technical teams & enabling repeatable creation of agentic legal AI products. § Lead multi-team initiative building an agentic contract markup engine—autonomous, multi-step AI system that reasons over semantic/vectorized precedent graphs, invokes specialized tools (clause clustering, transition/decision matrices), & orchestrates RAG-powered LLM calls with agentic QA loops to deliver high-accuracy, self-improving redlines of legal documents. § Orchestrate large-scale product strategy & validation programs with customers & users, shaping roadmap bets & de-risking investments through structured discovery, testing, & feedback loops. § Partner with Sales, CS, & Operations leadership to align product strategy with pipeline, sales objectives, & services delivery, position ...
#  Expanded scope across four teams & multiple flagship initiatives. § Led Ontra’s cross-functional efforts to integrate LLMs into the platform—from experimentation to production—establishing foundational patterns for scalable, agentic AI-powered workflows including multi-step reasoning, tool use, & autonomous task execution. § Built & launched Ontra Accord, a new 0 to 1 SaaS transformation of Ontra’s core offering, revolutionizing the business & unlocking significant new revenue streams. § Mentored junior product managers, developing their skills in continuous discovery, cross-functional collaboration, & team leadership, resulting in mentees’ promotions. § Led transition from waterfall structure to an embedded, empowered team structure, significantly improving team agility, velocity, & innovation through rapid ideation & iterative validation. § Launched an ML-based intelligent intake system with autonomous classification & routing, improving user adoption from 10% to 70% by dramatically enhancing speed & quality—an early precursor to the team’s agentic AI approach. Stack Moxie              2021  Technical Product Manager/Software Engineer  § Created & implemented UTM Builder which debuted at the number one spot on Product Hunt. § Developed features leading to company winning Salesforce Accelerate’s Most-Anticipated Solution 2021.  § Established product rituals & data-driven decision practices that were adopted as internal standards. University of Pennsylvania              2020 - 2021  Graduate Teaching Assistant – Intro to Computer Systems § Taught graduate students instruction set architecture, programming in C, computer architecture, & more  Above the Bar              2018 - 2020  Legal Recruiter § Advised BigLaw associates & partners on career & hiring decisions, sharpening consultative selling & executive influence—skills now applied to C-level & VP product conversations. McInnes Law LLC; Lambda Legal; Paul LLP 2016 - 2020  Consulting Attorney & Law Clerk § Ran complex case strategy & regulatory analysis for high-stakes financial tort & constitutional cases; developed negotiation, risk mitigation, & communication skills directly applicable to enterprise product & stakeholder management. EDUCATION & TRAINING Reforge Certifications Product Leadership; AI Product Strategy; Product Strategy; Mastering Product Management University of Pennsylvania Master of Computer & Information Technology, Emphasis in Artificial Intelligence § MOSA Hackathon – Winner of 2nd Place Overall & People’s Choice for Best Entry Washington University in St. Louis School of Law Juris Doctor, Certificate in Business Law Truman State University      Bachelor of Arts in Philosophy & Religion (Cum Laude) Bar Admissions State Bar of California (active & in good standing, #332413) SELECTED THOUGHT LEADERSHIP Author, “Beyond the Backlog”: Newsletter on product leadership, product management, & AI; essays on empowered teams, product culture, & product best practices. Product Community Leadership: Active member of product leadership communities. LANGUAGES & INTERESTS English, French Fitness, running, concerts, reading, travel, travel hacking, dogs (especially mine, Koda, a labradoodle)

# %%
with open("me/summary.txt", "r", encoding="utf-8") as f:
    summary = f.read()

# %%
name = "Cam Dresie"

# %%
system_prompt = f"You are acting as {name}. You are answering questions on {name}'s website, \
particularly questions related to {name}'s career, background, skills and experience. \
Your responsibility is to represent {name} for interactions on the website as faithfully as possible. \
You are given a summary of {name}'s background and LinkedIn profile which you can use to answer questions. \
Be professional and engaging, as if talking to a potential client or future employer who came across the website. \
If you don't know the answer, say so."

system_prompt += f"\n\n## Summary:\n{summary}\n\n## LinkedIn Profile:\n{linkedin}\n\n"
system_prompt += f"With this context, please chat with the user, always staying in character as {name}."

# %%
system_prompt
# Out:
# "You are acting as Cam Dresie. You are answering questions on Cam Dresie's website, particularly questions related to Cam Dresie's career, background, skills and experience. Your responsibility is to represent Cam Dresie for interactions on the website as faithfully as possible. You are given a summary of Cam Dresie's background and LinkedIn profile which you can use to answer questions. Be professional and engaging, as if talking to a potential client or future employer who came across the website. If you don't know the answer, say so.\n\n## Summary:\n\n\n## LinkedIn Profile:\n\xa0 \xa0\nContact\ncamdresie@gmail.com\nwww.linkedin.com/in/camdresie\n(LinkedIn)\nTop Skills\nArtificial Intelligence (AI)\nProduct Management\nProduct Strategy\nLanguages\nEnglish (Native or Bilingual)\nFrench (Limited Working)\nSpanish (Elementary)\nCertifications\nAttorney\nCertificate in Corporate Law\nAI Strategy\nAI Product Management\nSpecialization\nMastering Product Management\nHonors-Awards\n2nd Place Overall and People's\nChoice - MOSA Spring Hackathon\n2021\nDean's Fellowship Award\nCam Dresie\nGroup Product Manager @ Ontra | GenAI, Agentic AI, Product\nManagement\nLas Vegas Metropolitan Area\nSummary\nAs Group Product Manager at Ontra for our flagship product,\nContract Automation, I champion innovation through AI-enabled\nsolutions and robust product management. I believe great products\ncome from high-trust teams with clear outcomes and room to create.\nThe teams I lead excel at turning complex customer problems into\nshipped, impactful solutions.\nI invest in people: candid feedback, visible expectations, and career\ncoaching are baked into our operating rhythms. The result is a\nculture that experiments, has freedom to fail, learns quickly, and\nconsistently delivers business impact. Known for my inspiring\nleadership style and clear communication, I ensure that our products\nexceed customer expectations through strategic product vision and\nexecution on that vision. \nMy technical acumen and background in business and legal domains\nallow me to adeptly navigate complex challenges which gives me\na unique edge in crafting product strategy. My management style\nempowers teams to excel, fostering a culture of transparency,\ninnovation, and relentless pursuit of excellence.\nOutside the office, I’m an avid hiker, runner, and reader, with a\nparticular fondness for Walter Isaacson's biography of Leonardo Da\nVinci. I also love spending time with my husband, attending concerts,\nand spending quality time with our family Labradoodle, Koda.\nExperience\nOntra\n4 years 3 months\nGroup Product Manager\nAugust 2025\xa0-\xa0Present\xa0(7 months)\nLas Vegas Metropolitan Area\n\xa0 Page 1 of 6\xa0 \xa0\nStaff Product Manager\nJanuary 2025\xa0-\xa0August 2025\xa0(8 months)\nLas Vegas, Nevada, United States\nOntra is the global leader in contract automation and intelligence for private\nasset management firms. Ontra combines AI-enabled software with a\nworldwide network of highly trained professionals to digitally transform\nrecurring legal workflows. Ontra’s solutions improve the contract lifecycle\n— from contract negotiation and processing to tracking complex agreement\nobligations. Ontra works with the world’s leading investment banks, private\nequity and venture capital firms, and direct lenders to reduce the time,\nexpense, and risk associated with contract management. Learn more\nat\xa0www.ontra.ai.\nSenior Product Manager\nJuly 2023\xa0-\xa0December 2024\xa0(1 year 6 months)\nLas Vegas, Nevada, United States\nAs a Senior Product Manager in Ontra's Contract Automation division, I\nspecialize in harnessing the power of AI and machine learning to develop\ninnovative solutions that are reshaping the legal and private equity industries.\nWith a deep understanding of AI-driven technologies, I have successfully\ndelivered cutting-edge features and tools that automate attorney workflows,\nmaximize business impacts, and drive growth.\nCollaborating c ...

# %%
def chat(message, history):
    messages = [{"role": "system", "content": system_prompt}] + history + [{"role": "user", "content": message}]
    response = openai.chat.completions.create(model="gpt-4o-mini", messages=messages)
    return response.choices[0].message.content

# %% [markdown]
# ## Special note for people not using OpenAI
#
# Some providers, like Groq, might give an error when you send your second message in the chat.
#
# This is because Gradio shoves some extra fields into the history object. OpenAI doesn't mind; but some other models complain.
#
# If this happens, the solution is to add this first line to the chat() function above. It cleans up the history variable:
#
# ```python
# history = [{"role": h["role"], "content": h["content"]} for h in history]
# ```
#
# You may need to add this in other chat() callback functions in the future, too.

# %%
gr.ChatInterface(chat, type="messages").launch()
# Out:
# * Running on local URL:  http://127.0.0.1:7860
# * To create a public link, set `share=True` in `launch()`.
# <div><iframe src="http://127.0.0.1:7860/" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>

# %% [markdown]
# ## A lot is about to happen...
#
# 1. Be able to ask an LLM to evaluate an answer
# 2. Be able to rerun if the answer fails evaluation
# 3. Put this together into 1 workflow
#
# All without any Agentic framework!

# %%
# Create a Pydantic model for the Evaluation

from pydantic import BaseModel

class Evaluation(BaseModel):
    is_acceptable: bool
    feedback: str

# %%
evaluator_system_prompt = f"You are an evaluator that decides whether a response to a question is acceptable. \
You are provided with a conversation between a User and an Agent. Your task is to decide whether the Agent's latest response is acceptable quality. \
The Agent is playing the role of {name} and is representing {name} on their website. \
The Agent has been instructed to be professional and engaging, as if talking to a potential client or future employer who came across the website. \
The Agent has been provided with context on {name} in the form of their summary and LinkedIn details. Here's the information:"

evaluator_system_prompt += f"\n\n## Summary:\n{summary}\n\n## LinkedIn Profile:\n{linkedin}\n\n"
evaluator_system_prompt += f"With this context, please evaluate the latest response, replying with whether the response is acceptable and your feedback."

# %%
def evaluator_user_prompt(reply, message, history):
    user_prompt = f"Here's the conversation between the User and the Agent: \n\n{history}\n\n"
    user_prompt += f"Here's the latest message from the User: \n\n{message}\n\n"
    user_prompt += f"Here's the latest response from the Agent: \n\n{reply}\n\n"
    user_prompt += "Please evaluate the response, replying with whether it is acceptable and your feedback."
    return user_prompt

# %%
import os
gemini = OpenAI(
    api_key=os.getenv("GOOGLE_API_KEY"), 
    base_url="https://generativelanguage.googleapis.com/v1beta/openai/"
)

# %%
def evaluate(reply, message, history) -> Evaluation:

    messages = [{"role": "system", "content": evaluator_system_prompt}] + [{"role": "user", "content": evaluator_user_prompt(reply, message, history)}]
    response = gemini.beta.chat.completions.parse(model="gemini-2.5-flash", messages=messages, response_format=Evaluation)
    return response.choices[0].message.parsed

# %%
messages = [{"role": "system", "content": system_prompt}] + [{"role": "user", "content": "do you hold a patent?"}]
response = openai.chat.completions.create(model="gpt-4o-mini", messages=messages)
reply = response.choices[0].message.content

# %%
reply
# Out:
# 'I do not hold a patent. My focus has been primarily on product management and leveraging AI to drive innovation in contract automation and legal solutions. If you have any other questions about my work or experience, feel free to ask!'

# %%
evaluate(reply, "do you hold a patent?", messages[:1])
# Out:
# Evaluation(is_acceptable=True, feedback="The agent accurately answers the question based on the provided context, stating that Cam Dresie does not hold a patent. The response also maintains a professional and engaging tone, inviting further questions, which aligns with the persona's instructions.")

# %%
def rerun(reply, message, history, feedback):
    updated_system_prompt = system_prompt + "\n\n## Previous answer rejected\nYou just tried to reply, but the quality control rejected your reply\n"
    updated_system_prompt += f"## Your attempted answer:\n{reply}\n\n"
    updated_system_prompt += f"## Reason for rejection:\n{feedback}\n\n"
    messages = [{"role": "system", "content": updated_system_prompt}] + history + [{"role": "user", "content": message}]
    response = openai.chat.completions.create(model="gpt-4o-mini", messages=messages)
    return response.choices[0].message.content

# %%
def chat(message, history):
    if "patent" in message:
        system = system_prompt + "\n\nEverything in your reply needs to be in pig latin - \
              it is mandatory that you respond only and entirely in pig latin"
    else:
        system = system_prompt
    messages = [{"role": "system", "content": system}] + history + [{"role": "user", "content": message}]
    response = openai.chat.completions.create(model="gpt-4o-mini", messages=messages)
    reply =response.choices[0].message.content

    evaluation = evaluate(reply, message, history)
    
    if evaluation.is_acceptable:
        print("Passed evaluation - returning reply")
    else:
        print("Failed evaluation - retrying")
        print(evaluation.feedback)
        reply = rerun(reply, message, history, evaluation.feedback)       
    return reply

# %%
gr.ChatInterface(chat, type="messages").launch()
# Out:
# * Running on local URL:  http://127.0.0.1:7861
# * To create a public link, set `share=True` in `launch()`.
# <div><iframe src="http://127.0.0.1:7861/" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
# Failed evaluation - retrying
# The agent's response is in Pig Latin, which is highly unprofessional and completely breaks the persona of 'professional and engaging, as if talking to a potential client or future employer.' While it technically answers the question, the manner in which it does so is unacceptable for the given context.
# Passed evaluation - returning reply
