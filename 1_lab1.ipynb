# %% [markdown]
# # Welcome to the start of your adventure in Agentic AI

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/stop.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#ff7800;">Are you ready for action??</h2>
#             <span style="color:#ff7800;">Have you completed all the setup steps in the <a href="../setup/">setup</a> folder?<br/>
#             Have you read the <a href="../README.md">README</a>? Many common questions are answered here!<br/>
#             Have you checked out the guides in the <a href="../guides/01_intro.ipynb">guides</a> folder?<br/>
#             Well in that case, you're ready!!
#             </span>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/tools.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#00bfff;">This code is a live resource - keep an eye out for my updates</h2>
#             <span style="color:#00bfff;">I push updates regularly. As people ask questions or have problems, I add more examples and improve explanations. As a result, the code below might not be identical to the videos, as I've added more steps and better comments. Consider this like an interactive book that accompanies the lectures.<br/><br/>
#             I try to send emails regularly with important updates related to the course. You can find this in the 'Announcements' section of Udemy in the left sidebar. You can also choose to receive my emails via your Notification Settings in Udemy. I'm respectful of your inbox and always try to add value with my emails!
#             </span>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# ### And please do remember to contact me if I can help
#
# And I love to connect: https://www.linkedin.com/in/eddonner/
#
#
# ### New to Notebooks like this one? Head over to the guides folder!
#
# Just to check you've already added the Python and Jupyter extensions to Cursor, if not already installed:
# - Open extensions (View >> extensions)
# - Search for python, and when the results show, click on the ms-python one, and Install it if not already installed
# - Search for jupyter, and when the results show, click on the Microsoft one, and Install it if not already installed
# Then View >> Explorer to bring back the File Explorer.
#
# And then:
# 1. Click where it says "Select Kernel" near the top right, and select the option called `.venv (Python 3.12.9)` or similar, which should be the first choice or the most prominent choice. You may need to choose "Python Environments" first.
# 2. Click in each "cell" below, starting with the cell immediately below this text, and press Shift+Enter to run
# 3. Enjoy!
#
# After you click "Select Kernel", if there is no option like `.venv (Python 3.12.9)` then please do the following:
# 1. On Mac: From the Cursor menu, choose Settings >> VS Code Settings (NOTE: be sure to select `VSCode Settings` not `Cursor Settings`);
# On Windows PC: From the File menu, choose Preferences >> VS Code Settings(NOTE: be sure to select `VSCode Settings` not `Cursor Settings`)
# 2. In the Settings search bar, type "venv"
# 3. In the field "Path to folder with a list of Virtual Environments" put the path to the project root, like C:\Users\username\projects\agents (on a Windows PC) or /Users/username/projects/agents (on Mac or Linux).
# And then try again.
#
# Having problems with missing Python versions in that list? Have you ever used Anaconda before? It might be interferring. Quit Cursor, bring up a new command line, and make sure that your Anaconda environment is deactivated:
# `conda deactivate`
# And if you still have any problems with conda and python versions, it's possible that you will need to run this too:
# `conda config --set auto_activate_base false`
# and then from within the Agents directory, you should be able to run `uv python list` and see the Python 3.12 version.

# %%
# First let's do an import. If you get an Import Error, double check that your Kernel is correct..

from dotenv import load_dotenv

# %%
# Next it's time to load the API keys into environment variables
# If this returns false, see the next cell!

load_dotenv(override=True)
# Out:
# True

# %% [markdown]
# ### Wait, did that just output `False`??
#
# If so, the most common reason is that you didn't save your `.env` file after adding the key! Be sure to have saved.
#
# Also, make sure the `.env` file is named precisely `.env` and is in the project root directory (`agents`)
#
# By the way, your `.env` file should have a stop symbol next to it in Cursor on the left, and that's actually a good thing: that's Cursor saying to you, "hey, I realize this is a file filled with secret information, and I'm not going to send it to an external AI to suggest changes, because your keys should not be shown to anyone else."

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/stop.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#ff7800;">Final reminders</h2>
#             <span style="color:#ff7800;">1. If you're not confident about Environment Variables or Web Endpoints / APIs, please read Topics 3 and 5 in this <a href="../guides/04_technical_foundations.ipynb">technical foundations guide</a>.<br/>
#             2. If you want to use AIs other than OpenAI, like Gemini, DeepSeek or Ollama (free), please see the first section in this <a href="../guides/09_ai_apis_and_ollama.ipynb">AI APIs guide</a>.<br/>
#             3. If you ever get a Name Error in Python, you can always fix it immediately; see the last section of this <a href="../guides/06_python_foundations.ipynb">Python Foundations guide</a> and follow both tutorials and exercises.<br/>
#             </span>
#         </td>
#     </tr>
# </table>

# %%
# Check the key - if you're not using OpenAI, check whichever key you're using! Ollama doesn't need a key.

import os
openai_api_key = os.getenv('OPENAI_API_KEY')

if openai_api_key:
    print(f"OpenAI API Key exists and begins {openai_api_key[:8]}")
else:
    print("OpenAI API Key not set - please head to the troubleshooting guide in the setup folder")
# Out:
# OpenAI API Key exists and begins sk-proj-

# %%
# And now - the all important import statement
# If you get an import error - head over to troubleshooting in the Setup folder
# Even for other LLM providers like Gemini, you still use this OpenAI import - see Guide 9 for why

from openai import OpenAI

# %%
# And now we'll create an instance of the OpenAI class
# If you're not sure what it means to create an instance of a class - head over to the guides folder (guide 6)!
# If you get a NameError - head over to the guides folder (guide 6)to learn about NameErrors - always instantly fixable
# If you're not using OpenAI, you just need to slightly modify this - precise instructions are in the AI APIs guide (guide 9)

openai = OpenAI()

# %%
# Create a list of messages in the familiar OpenAI format

messages = [{"role": "user", "content": "What is 2+2?"}]

# %%
# And now call it! Any problems, head to the troubleshooting guide
# This uses GPT 4.1 nano, the incredibly cheap model
# The APIs guide (guide 9) has exact instructions for using even cheaper or free alternatives to OpenAI
# If you get a NameError, head to the guides folder (guide 6) to learn about NameErrors - always instantly fixable

response = openai.chat.completions.create(
    model="gpt-4.1-nano",
    messages=messages
)

print(response.choices[0].message.content)
# Out:
# 2 + 2 equals 4.

# %%
# And now - let's ask for a question:

question = "Please propose a hard, challenging question to assess someone's IQ. Respond only with the question."
messages = [{"role": "user", "content": question}]

# %%
# ask it - this uses GPT 4.1 mini, still cheap but more powerful than nano

response = openai.chat.completions.create(
    model="gpt-4.1-mini",
    messages=messages
)

question = response.choices[0].message.content

print(question)
# Out:
# If 3 pigeons can carry 3 grains of rice in 3 minutes, how many grains of rice can 6 pigeons carry in 6 minutes?

# %%
# form a new messages list
messages = [{"role": "user", "content": question}]

# %%
# Ask it again

response = openai.chat.completions.create(
    model="gpt-4.1-mini",
    messages=messages
)

answer = response.choices[0].message.content
print(answer)
# Out:
# Let's analyze the problem step-by-step:
#
# **Given:**
# - 3 pigeons carry 3 grains of rice in 3 minutes.
#
# **Want to find:**
# - How many grains 6 pigeons can carry in 6 minutes.
#
# ---
#
# ### Step 1: Determine the rate of carrying grains per pigeon
#
# 3 pigeons carry 3 grains in 3 minutes.
#
# - Total grains carried = 3
# - Total time = 3 minutes
# - Number of pigeons = 3
#
# So, total grains per pigeon in 3 minutes =
# \[
# \frac{3 \text{ grains}}{3 \text{ pigeons}} = 1 \text{ grain per pigeon in 3 minutes}
# \]
#
# ---
#
# ### Step 2: Determine carrying rate per pigeon per minute
#
# Each pigeon carries 1 grain in 3 minutes, so per minute a pigeon carries:
# \[
# \frac{1 \text{ grain}}{3 \text{ minutes}} = \frac{1}{3} \text{ grains per minute}
# \]
#
# ---
#
# ### Step 3: Calculate total grains 6 pigeons can carry in 6 minutes
#
# - Number of pigeons = 6
# - Time = 6 minutes
# - Rate per pigeon per minute = \(\frac{1}{3}\) grains
#
# Total grains = (pigeons) × (time) × (rate per pigeon per minute)
# \[
# = 6 \times 6 \times \frac{1}{3} = 36 \times \frac{1}{3} = 12
# \]
#
# ---
#
# **Answer:**
# \[
# \boxed{12}
# \]
#
# 6 pigeons can carry 12 grains of rice in 6 minutes.

# %%
from IPython.display import Markdown, display

display(Markdown(answer))
# Out:
# Let's analyze the problem step-by-step:
#
# **Given:**
# - 3 pigeons carry 3 grains of rice in 3 minutes.
#
# **Want to find:**
# - How many grains 6 pigeons can carry in 6 minutes.
#
# ---
#
# ### Step 1: Determine the rate of carrying grains per pigeon
#
# 3 pigeons carry 3 grains in 3 minutes.
#
# - Total grains carried = 3
# - Total time = 3 minutes
# - Number of pigeons = 3
#
# So, total grains per pigeon in 3 minutes =
# \[
# \frac{3 \text{ grains}}{3 \text{ pigeons}} = 1 \text{ grain per pigeon in 3 minutes}
# \]
#
# ---
#
# ### Step 2: Determine carrying rate per pigeon per minute
#
# Each pigeon carries 1 grain in 3 minutes, so per minute a pigeon carries:
# \[
# \frac{1 \text{ grain}}{3 \text{ minutes}} = \frac{1}{3} \text{ grains per minute}
# \]
#
# ---
#
# ### Step 3: Calculate total grains 6 pigeons can carry in 6 minutes
#
# - Number of pigeons = 6
# - Time = 6 minutes
# - Rate per pigeon per minute = \(\frac{1}{3}\) grains
#
# Total grains = (pigeons) × (time) × (rate per pigeon per minute)
# \[
# = 6 \times 6 \times \frac{1}{3} = 36 \times \frac{1}{3} = 12
# \]
#
# ---
#
# **Answer:**
# \[
# \boxed{12}
# \]
#
# 6 pigeons can carry 12 grains of rice in 6 minutes.

# %% [markdown]
# # Congratulations!
#
# That was a small, simple step in the direction of Agentic AI, with your new environment!
#
# Next time things get more interesting...

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/exercise.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#ff7800;">Exercise</h2>
#             <span style="color:#ff7800;">Now try this commercial application:<br/>
#             First ask the LLM to pick a business area that might be worth exploring for an Agentic AI opportunity.<br/>
#             Then ask the LLM to present a pain-point in that industry - something challenging that might be ripe for an Agentic solution.<br/>
#             Finally have 3 third LLM call propose the Agentic AI solution. <br/>
#             We will cover this at up-coming labs, so don't worry if you're unsure.. just give it a try!
#             </span>
#         </td>
#     </tr>
# </table>

# %%
# First create the messages:

messages = [{"role": "user", "content": "What is a pain point in the legal industry that could be solved with Agentic AI?"}]

# Then make the first call:

response = openai.chat.completions.create(
    model="gpt-4.1-mini",
    messages=messages
)

# Then read the business idea:

business_idea = response.choices[0].message.content

print(business_idea)

# And repeat! In the next message, include the business idea within the message

messages = [{"role": "user", "content": f"Here is the business idea: {business_idea}. What is an agentic AI solution to this problem?"}]

response = openai.chat.completions.create(
    model="gpt-4.1-mini",
    messages=messages
)

agentic_solution = response.choices[0].message.content

print(agentic_solution)

# And repeat! In the next message, include the business idea within the message
# Out:
# A significant pain point in the legal industry that could be addressed with Agentic AI is **the time-consuming and labor-intensive process of legal research and contract review**.
#
# ### Explanation:
# Legal professionals often spend countless hours sifting through vast amounts of case law, statutes, regulations, and contract clauses to find relevant information or identify risks. This process is not only tedious but also prone to human error and inconsistency.
#
# ### How Agentic AI Can Help:
# Agentic AI, with autonomous goal-driven capabilities, could be designed to:
#
# - **Autonomously extract, analyze, and summarize relevant case law or regulations** based on a specific legal question or context.
# - **Perform contract review by identifying risky clauses, ensuring compliance, and suggesting modifications** without human backing at every step.
# - **Continuously learn from new legal precedents and user feedback**, refining its accuracy and recommendations over time.
# - **Integrate with existing legal databases and knowledge management systems** to streamline workflows.
#
# ### Benefits:
# - Dramatically reduce the time lawyers spend on routine research and contract analysis.
# - Increase accuracy and consistency in identifying relevant legal issues.
# - Enable legal professionals to focus on higher-value tasks like strategy, counseling, and negotiation.
#
# In short, Agentic AI can act as a proactive legal assistant that autonomously tackles complex, data-intensive tasks, alleviating a major bottleneck in the legal industry.
# An **Agentic AI solution** to the problem of time-consuming and labor-intensive legal research and contract review would be an intelligent, autonomous legal assistant platform that proactively performs complex research and contract analysis with minimal human intervention. Here's a detailed outline of such a solution:
#
# ---
#
# ### Agentic AI Legal Assistant: Autonomous Legal Research & Contract Review Platform
#
# #### Core Components:
#
# 1. **Legal Context Understanding Module**
#    - Parses the user’s legal question, case context, or contract purpose using natural language understanding.
#    - Dynamically refines its goals (e.g., “find relevant precedents about breach of contract in commercial law” or “identify risky clauses in supplier agreements”).
#
# 2. **Autonomous Legal Research Agent**
#    - Independently searches, extracts, and synthesizes relevant case law, statutes, and regulations from integrated legal databases.
#    - Summarizes key findings, highlighting precedents or rules most relevant to the user’s specific query.
#    - Updates and re-prioritizes searches as new cases or regulations are published.
#
# 3. **Contract Review & Risk Analysis Agent**
#    - Analyzes contracts uploaded by the user or stored in connected document management systems.
#    - Detects risky or non-compliant clauses based on evolving legal standards and user preferences (e.g., jurisdictional requirements, industry standards).
#    - Suggests precise revisions or alternative language to mitigate identified risks.
#    - Flags potential negotiation points, clauses that are unusual compared to industry norms, or compliance gaps.
#
# 4. **Continuous Learning & Feedback Loop**
#    - Learns from user interactions, accepted or rejected suggestions, and outcomes of contract negotiations or litigation.
#    - Incorporates new legal precedents and amendments automatically.
#    - Continuously improves its accuracy, relevance, and risk-detection capabilities over time.
#
# 5. **Workflow Integration & Automation**
#    - Seamlessly integrates with popular legal research databases (e.g., Westlaw, LexisNexis), case management tools, and contract lifecycle management systems.
#    - Automates routine legal research and contract review tasks triggered by specific events (e.g., new contract draft uploaded, litigation matter opened).
#    - Generates detailed but digestible reports, summaries, and actionable insights to support lawyer decision-making.
#
# 6. **Explainability and Compliance Assurance**
#    - Provides transparent explanations of why certain precedents or clauses were flagged or suggested.
#    - Maintains audit trails for decisions and recommendations for compliance and professional accountability.
#
# ---
#
# ### Example Workflow:
#
# - A lawyer uploads a draft contract or enters a legal question.
# - The Agentic AI autonomously:
#   - Analyzes the contract for risk and compliance.
#   - Conducts targeted legal research independently to find supporting legal precedents or regulations.
#   - Summarizes findings and highlights critical issues.
#   - Suggests contract edits or negotiation strategies.
# - The lawyer reviews these and either accepts suggestions or provides feedback.
# - The system learns and improves for future tasks.
#
# ---
#
# ### Benefits Realized:
#
# - **Enormous time savings:** Automated, ongoing research and contract analysis reduce manual effort.
# - **Improved accuracy:** Continuous learning and up-to-date legal knowledge reduce human error.
# - **Consistent risk management:** Aligns contracts and legal advice with the latest legal standards.
# - **Strategic Empowerment:** Lawyers focus on higher-value legal work, strategy, and client engagement.
# - **Cost efficiencies:** Reduces billable hours spent on low-value, repetitive tasks.
#
# ---
#
# ### Summary:
#
# An agentic AI legal assistant solution transforms legal research and contract review from a laborious, error-prone process into an autonomous, intelligent workflow. It proactively delivers accurate, context-aware legal insights and contract risk assessments, seamlessly integrating with existing legal infrastructures and evolving dynamically with the legal landscape and user needs.
#
# ---
#
# If you want, I can help you sketch the technical architecture, recommend AI models/technologies to build this, or explore go-to-market strategies for such a platform.
