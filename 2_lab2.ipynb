# %% [markdown]
# ## Welcome to the Second Lab - Week 1, Day 3
#
# Today we will work with lots of models! This is a way to get comfortable with APIs.

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/stop.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#ff7800;">Important point - please read</h2>
#             <span style="color:#ff7800;">The way I collaborate with you may be different to other courses you've taken. I prefer not to type code while you watch. Rather, I execute Jupyter Labs, like this, and give you an intuition for what's going on. My suggestion is that you carefully execute this yourself, <b>after</b> watching the lecture. Add print statements to understand what's going on, and then come up with your own variations.<br/><br/>If you have time, I'd love it if you submit a PR for changes in the community_contributions folder - instructions in the resources. Also, if you have a Github account, use this to showcase your variations. Not only is this essential practice, but it demonstrates your skills to others, including perhaps future clients or employers...
#             </span>
#         </td>
#     </tr>
# </table>

# %%
# Start with imports - ask ChatGPT to explain any package that you don't know

import os
import json
from dotenv import load_dotenv
from openai import OpenAI
from anthropic import Anthropic
from IPython.display import Markdown, display

# %%
# Always remember to do this!
load_dotenv(override=True)
# Out:
# True

# %%
# Print the key prefixes to help with any debugging

openai_api_key = os.getenv('OPENAI_API_KEY')
anthropic_api_key = os.getenv('ANTHROPIC_API_KEY')
google_api_key = os.getenv('GOOGLE_API_KEY')
deepseek_api_key = os.getenv('DEEPSEEK_API_KEY')
groq_api_key = os.getenv('GROQ_API_KEY')

if openai_api_key:
    print(f"OpenAI API Key exists and begins {openai_api_key[:8]}")
else:
    print("OpenAI API Key not set")
    
if anthropic_api_key:
    print(f"Anthropic API Key exists and begins {anthropic_api_key[:7]}")
else:
    print("Anthropic API Key not set (and this is optional)")

if google_api_key:
    print(f"Google API Key exists and begins {google_api_key[:2]}")
else:
    print("Google API Key not set (and this is optional)")

if deepseek_api_key:
    print(f"DeepSeek API Key exists and begins {deepseek_api_key[:3]}")
else:
    print("DeepSeek API Key not set (and this is optional)")

if groq_api_key:
    print(f"Groq API Key exists and begins {groq_api_key[:4]}")
else:
    print("Groq API Key not set (and this is optional)")
# Out:
# OpenAI API Key exists and begins sk-proj-
# Anthropic API Key exists and begins sk-ant-
# Google API Key exists and begins AI
# DeepSeek API Key exists and begins sk-
# Groq API Key exists and begins gsk_

# %%
request = "Please come up with a challenging, nuanced question that I can ask a number of LLMs to evaluate their intelligence. "
request += "Answer only with the question, no explanation."
messages = [{"role": "user", "content": request}]

# %%
messages
# Out:
# [{'role': 'user',
#   'content': 'Please come up with a challenging, nuanced question that I can ask a number of LLMs to evaluate their intelligence. Answer only with the question, no explanation.'}]

# %%
openai = OpenAI()
response = openai.chat.completions.create(
    model="gpt-5-mini",
    messages=messages,
)
question = response.choices[0].message.content
print(question)
# Out:
# You are an independent policy advisor to the mayor of a real but unnamed mid-sized coastal city (population 350,000) whose economy depends on tourism and fisheries. Sea-level projections suggest a 1.0 m rise over the next 50 years; storm surge frequency and intensity are also expected to increase. The city has $2.0 billion available over the next 30 years for adaptation, must preserve social equity (no program may make the poorest 20% worse off), and seeks to minimize long-term economic losses while maintaining ecological services and cultural heritage sites.
#
# Design a prioritized 30-year adaptation plan for the city that: (a) allocates the $2.0B budget across concrete interventions (with year-by-year or phase-by-phase spending where appropriate), (b) estimates the expected economic, social, and environmental benefits and costs for each intervention (provide numerical estimates where possible), (c) identifies which neighborhoods or assets are protected, relocated, or abandoned and why, (d) proposes at least three funding or finance mechanisms beyond the $2.0B baseline, (e) includes governance and community-engagement measures to ensure equity, and (f) specifies measurable success metrics and monitoring strategies.
#
# Also, for your proposal: list all explicit assumptions and data inputs you used (population growth, discount rate, damage functions, social values, etc.), provide a simple sensitivity analysis showing how the plan or its ranking changes if three key parameters each vary by ±20%, identify the three most important risks or failure modes and contingency actions for each, and finally state three concrete, falsifiable pieces of evidence that—if observed within the next 10 years—would make you abandon your plan.
#
# Present your answer with clear reasoning and show relevant calculations; then give a single overall confidence estimate (0–100%) in the plan’s likelihood of meeting the city’s goals and briefly justify that percentage.

# %%
competitors = []
answers = []
messages = [{"role": "user", "content": question}]

# %% [markdown]
# ## Note - update since the videos
#
# I've updated the model names to use the latest models below, like GPT 5 and Claude Sonnet 4.5. It's worth noting that these models can be quite slow - like 1-2 minutes - but they do a great job! Feel free to switch them for faster models if you'd prefer, like the ones I use in the video.

# %%
# The API we know well
# I've updated this with the latest model, but it can take some time because it likes to think!
# Replace the model with gpt-4.1-mini if you'd prefer not to wait 1-2 mins

model_name = "gpt-5-nano"

response = openai.chat.completions.create(model=model_name, messages=messages)
answer = response.choices[0].message.content

display(Markdown(answer))
competitors.append(model_name)
answers.append(answer)
# Out:
# Executive summary
# - Goal: Build a 30-year, equity-conscious, cost-effective adaptation plan for a medium coastal city (population ~350k) whose economy hinges on tourism and fisheries. Sea-level rise is projected to 1.0 m in 50 years; storm surge is expected to intensify. The city has a $2.0B budget for adaptation over 30 years, and policies must not worsen the poorest 20% of residents.
# - Core design: A phased package of hard protection, nature-based solutions, infrastructure upgrades, and voluntary relocation/buyout, prioritized by risk, economic value, and equity. The plan aims to reduce long-term economic losses from coastal hazards while preserving ecological services and cultural heritage.
# - Outcome (at a glance): Net present value (NPV) of benefits roughly matches the baseline budget, with substantial risk reduction in high-value zones and a path to long-term resilience that does not leave the poorest residents worse off. The plan includes governance, financing, and monitoring to ensure equity and transparency.
# - Confidence: Moderate-to-strong (about 72%). Reasonable assumptions and phased funding allow risk-managed implementation, but outcomes depend on financing stability, timely permitting, and community buy-in.
#
# A. Assumptions and data inputs (explicit)
# - Population and growth
#   - Current population: 350,000
#   - Baseline growth assumption: 0.60% per year (compound over 30 years) for planning purposes
#   - Sensitivity scenario: ±20% around growth rate
# - Sea-level rise and hazards
#   - SLR: 1.0 m rise projected over 50 years (approximate, regional variation acknowledged)
#   - Storm surge/frequency: Increases anticipated; higher surge heights during extreme events; risk concentrates in nearshore and low-lying zones
# - Valuation and damages
#   - Coastal-exposed asset value (coastal zone with high economic concentration): ~$16B
#   - Baseline annual hazard damage rate without adaptation: ~0.75% of coastal-exposed asset value in year 1, rising modestly with hazard intensification (roughly escalates over time with surge intensity and flood extent)
#   - Discount rate (real): 3% per year (used for PV calculations)
# - Economic structure and sectors
#   - Tourism and fisheries as primary sectors; damages affect hotels, ports/harbors, fishery facilities, boatyards, supply chains, and associated services
# - Equity and social values
#   - No program may reduce the material well-being or safety of the bottom 20% (poorest households)
#   - Protective plans include targeted housing assistance, relocation options, and affordable housing guarantees
# - Baseline governance and delivery
#   - 30-year horizon, with phased implementation and periodic evaluation
#   - Local cost of capital and permitting timelines assumed reasonable for a mid-sized city; delays risk higher costs or lower benefits
#
# Notes on data and calculations used
# - Present-value factor for 30 years at 3%: PV factor = [1 − (1.03)−30]/0.03 ≈ 19.6
# - Baseline EAD (present value) calculation example:
#   - Year 1 EAD = 0.75% × $16B ≈ $0.12B/year
#   - PV of 30-year annuity at 3%: $0.12B × 19.6 ≈ $2.35B
#   - This is a simplified illustration; we model gradual escalation with surges and other factors in the plan description.
# - Targeted reductions from interventions are estimated in PV terms (see intervention-specific numbers below)
#
# B. Priority 30-year adaptation plan (a) concrete interventions and (b) benefits/costs (numerical estimates where possible)
#
# Overarching design
# - Guiding principles: protect high-value economic assets and critical infrastructure; deploy nature-based solutions to preserve ecological services; ensure resilience of cultural heritage; implement voluntary, equitable relocation where needed; avoid worsening the poorest 20%; maintain and expand jobs in tourism and fisheries.
# - Total budget: $2.0B (nominal) over 30 years; plan uses phased spending and leverages other funds (see section D).
#
# Phase 1: Foundations, planning, and initial protections (Years 1–5)
# Budget: ~$400M
#
# - Governance, planning, and equity oversight
#   - Establish Climate Adaptation Authority; stakeholder engagement; data portal; annual public reporting
#   - Cost: ~$60M
# - Early nature-based and nearshore protection (living shorelines, dune restoration, buffer habitats)
#   - Targeted nearshore living shorelines to reduce wave energy and restore habitats; initial dune restoration along select beaches
#   - Cost: ~$150M
# - Interim protection of critical public facilities
#   - Elevation and floodproofing of city hall, main fire/police facilities, and wastewater treatment plant
#   - Cost: ~$110M
# - Evacuation planning, early warning, and core resilience communications
#   - Advanced warning systems, signage, drills, and evacuation route strengthening
#   - Cost: ~$40M
# - Readiness for buyouts (planning and first-draw funding)
#   - Voluntary buyout readiness for highest-risk parcels; appraisal framework; community outreach
#   - Cost: ~$40M
# - Small-scale risk reduction at priority tourist/fishing zones (e.g., minor seawall segments, floodproofing of marina facilities)
#   - Cost: ~$40M
#
# Net rationale: This phase builds the governance backbone, tests nature-based approaches, protects essential services, and sets up voluntary relocation processes without displacing any households yet. It also begins reducing risk exposure in high-visibility areas.
#
# Phase 2: Core protective infrastructure and targeted relocation (Years 6–12)
# Budget: ~$900M
#
# - Seawalls and surge barriers in high-value districts
#   - Focus on downtown core, harborfront hotels, cruise/port interface, and primary fishing harbor
#   - Estimated cost: ~$520M
#   - Expected benefit: substantial reduction in EAD for top-value zones; protection of tourism economy and port operations
# - Expanded nature-based protections and living shorelines
#   - Complement hard defenses with restored wetlands and oyster reefs, improving flood attenuation and habitat
#   - Estimated cost: ~$120M
#   - Expected benefit: additional EAD reductions; ecological co-benefits
# - Elevation/retrofit of additional critical infrastructure
#   - Water treatment, power substation, hospital secondary facilities, harbor-related infrastructure
#   - Estimated cost: ~$60M
# - Voluntary relocation/buyout program (Phase 1 deployments)
#   - Target households in high-risk housing with low replacement costs; provide relocation assistance and affordable replacement housing
#   - Estimated cost: ~$120M
#   - Rationale: reduce exposure where protection costs are high or where social equity concerns are acute
# - Enhanced evacuation routes and critical-asset redundancy
#   - Additional gates, bridges, and redundancy for critical corridors; back-up power for evacuation centers
#   - Estimated cost: ~$80M
# - Monitoring, adaptive management, and governance strengthening
#   - KPIs, independent oversight, annual progress report, and community feedback mechanisms
#   - Estimated cost: ~$20M
#
# Rationale: Phase 2 focuses on protecting high-value economic zones (port/tourist core) while expanding nature-based solutions and pushing forward the voluntary relocation program in a targeted, equitable way. The goal is to lower risk in the most valuable economic districts and begin reducing exposure in low- to middle-income neighborhoods where buyouts are most feasible and socially acceptable.
#
# Phase 3: Expansion, long-term protection, and cultural heritage resilience (Years 13–30)
# Budget: ~$700M
#
# - Expansion of protective corridors and additional seawall segments as needed
#   - Extend protection to peri-urban and additional tourism/fisheries corridors with phased segments
#   - Estimated cost: ~$420M
# - Long-term relocation/abandonment planning (where voluntary buyouts are accepted or feasible)
#   - Complete buyouts for remaining high-risk parcels; ensure affordable housing alternatives
#   - Estimated cost: ~$100M
# - Cultural heritage preservation and climate-proofing of historic districts
#   - Implement climate-resilient restoration, floodproofing, and display of cultural assets with community engagement
#   - Estimated cost: ~$80M
# - Ecosystem restoration and restoration of degraded coastal habitats
#   - Restoration of mangroves, wetlands, and nearshore habitats to support ecological services
#   - Estimated cost: ~$40M
# - Monitoring, governance, and continuous improvement
#   - Long-term program evaluation, equity audits, and adaptive management
#   - Estimated cost: ~$60M
#
# Rationale: Phase 3 consolidates gains, expands protection to more neighborhoods and assets, and preserves cultural heritage and ecological services. It also completes voluntary relocation in a manner that protects the poorest and avoids forced resettlement.
#
# Total budget by phase (summed estimates)
# - Phase 1 (Years 1–5): ~$400M
# - Phase 2 (Years 6–12): ~$900M
# - Phase 3 (Years 13–30): ~$700M
# - Total: ~$2.0B
#
# C. Neighborhoods/assets protected, relocated, or abandoned (why)
#
# - Protected (high-value economic and critical-assets):
#   - Downtown core, harborfront, primary hotels, cruise-ship and tourism-related infrastructure, main fishing harbor, and hospital/water/wastewater facilities
#   - Rationale: these assets generate the bulk of current economic activity (tourism and fisheries) and provide essential services; their protection yields the highest near-term economic and societal payoff and reduces risk to the broader economy.
# - Relocated (voluntary buyouts for equity and risk reduction):
#   - High-risk residential blocks in low-to-moderate property-value zones immediately adjacent to the shoreline; lower-income neighborhoods with limited mobility options; parcels with feasible replacement housing options
#   - Rationale: reduce displacement risk for poorer households; ensure fair compensation and replacement housing; voluntary buyouts minimize social conflict and support equity objectives.
# - Abandoned (economic/ease-of-risk decisions)
#   - In cases where the cost of protection is drastically higher than the asset value, or when risk is unacceptable (e.g., single-structure properties with extremely high hazard profiles and no feasible relocation options)
#   - Rationale: avoid locking in unsustainable costs; where feasible, offer relocation or conversion to non-residential uses (e.g., parks, open space) rather than continued hazard exposure. This would be pursued only if voluntary options are exhausted and risk remains unacceptable after protection investments.
#
# D. Funding and financing mechanisms beyond the $2.0B baseline
# 1) Climate resilience bonds (green or blue bonds)
#    - Sell city-backed bonds specifically for adaptation projects; issue debt with proceeds restricted to resilience interventions
#    - Rationale: broad market access, longer tenors, potential favorable rates for green issuance; aligns with investor appetite for resilience assets
# 2) Public-private partnerships (P3) for port/tourism infrastructure and critical facilities
#    - Leverage private sector investment in uptime, resilience, and service delivery (e.g., seawall maintenance, floodproofing of private assets near the port, or flood-resilient hotel upgrades) with performance-based payments
#    - Rationale: attract capital and expertise; accelerate delivery; align incentives for long-term maintenance
# 3) Federal/state grants, and disaster risk reduction funds (BRIC/HMA equivalents)
#    - Seek competitive grants targeted at resilience, hazard mitigation, and coastal restoration; apply for federal/state resilience and climate-adaptation programs
#    - Rationale: non-debt funding that does not impact local taxes or debt capacity
# 4) Catastrophe bonds and parametric insurance instruments
#    - Weather-triggered securitizations to cover extreme-event losses; funds can be earmarked for rapid post-disaster resilience investments or early-stage protection
#    - Rationale: diversify risk financing; provide rapid liquidity after extreme events
# 5) Tax-increment financing (TIF) or special assessment districts for targeted districts
#    - Create districts where incremental value from investments funds resilience works in specific corridors (e.g., harbor area) while preserving equity safeguards
#    - Rationale: leverages future gains to finance current improvements, with transparency and governance safeguards
#
# E. Governance, equity, and community engagement (measures to ensure equity)
# - Equity-focused oversight
#   - Establish an independent Equity and Adaptation Commission that includes representatives from affected neighborhoods, fisheries, tourism associations, historians, and public health
#   - Annual public report on equity metrics (cost burdens, displacement risk, access to housing, and benefits distribution)
# - Participatory planning
#   - Regular community town halls in multiple languages; community-defined project briefings; participatory budgeting elements for small but meaningful allocations
# - Transparent data and procurement
#   - Public data portal with hazard maps, asset inventories, project schedules, procurement logs, and contract performance
# - Housing and social safeguards
#   - Require affordable housing guarantees for relocated households; ensure rent protections and anti-displacement policies; provide mobility services and retraining programs where necessary
# - Cultural heritage safeguards
#   - Involve local cultural groups to guide restoration and interpretation of heritage sites; ensure accessible, inclusive interpretation for residents and visitors
# - Grievance and redress mechanisms
#   - Independent ombudsman to handle complaints related to relocation, compensation, or implementation delays
#
# F. Measurable success metrics and monitoring strategies
# - Physical and structural metrics
#   - Percent of high-value assets protected or retrofitted for flood and surge resistance
#   - Number of critical facilities with floodproofing or elevation completed
#   - Distance of evacuation routes improved or expanded; number of safe shelters with backup power
# - Economic metrics
#   - Reduction in expected annual damages (EAD) from coastal hazards; PV of avoided damages over 30 years
#   - Preservation or growth of tourism revenue and port activity in adaptation zones compared to baseline
#   - Reduced downtime for fisheries infrastructure during extreme events
# - Social equity metrics
#   - Share of benefits allocated to the bottom 40% and bottom 20% (poverty-weighted distribution)
#   - Number of households in lowest-income quintile aided by relocation/affordable housing guarantees
# - Environmental metrics
#   - Habitat restoration progress (wetlands, mangroves, reefs)
#   - Water quality and sediment transport indicators in nearshore zones
# - Governance and process metrics
#   - Transparency score (public dashboards updated quarterly)
#   - Community satisfaction and participation rates in engagement activities
# - Monitoring plan
#   - Annual reporting by the Climate Adaptation Authority
#   - Independent mid-term review at year 10; third-party evaluations at years 20 and 30
#   - Real-time dashboards for hazard events, system uptime, and shelter availability
#
# G. Explicit assumptions and data inputs used (catalog)
# - Population: 350k now; 0.60% annual growth assumed for planning (±20% sensitivity)
# - Discount rate: 3% real
# - Hazard exposure: coastal-exposed asset value ≈ $16B; baseline annual damage rate ≈ 0.75% of exposed value (year 1), escalating modestly with hazard intensification
# - SLR: +1.0 m by year 50 (50 years)
# - Storm surge: increasing frequency and intensity; nearshore protection needs
# - Economic structure: tourism and fisheries provide the majority of regional GDP and employment; disruption has multiplier effects
# - Equity constraint: poorest 20% must not be worse off; relocation/housing assistance programs included to ensure equity
# - Capital availability: baseline $2.0B funding is available; additional mechanisms will be used to bridge gaps
# - Construction and permitting timelines: phased schedule assumed feasible within local regulatory constraints and financing
# - Environmental co-benefits: habitat restoration improves ecology and resilience; certain interventions have spillover benefits (recreation, biodiversity)
#
# H. Sensitivity analysis (±20% on three key parameters)
# Method: Recompute a simplified PV of EAD with and without interventions, focusing on the core three levers below. Compare the net PV (benefits − costs) and rank changes among the major interventions.
#
# Parameters varied by ±20%:
# - Discount rate (real)
#   - Baseline: 3.0% → low: 2.4% high: 3.6%
# - Baseline hazard growth (EAD growth rate due to climate and hazard escalation)
#   - Baseline annual EAD growth: 0% escalation for simplicity in PV calculation (illustrative). Alternative: +0.5%/yr and +1.0%/yr escalations (compounding hazard escalation)
# - Population growth
#   - Baseline 0.60%/yr → low: 0.48%/yr; high: 0.72%/yr
#
# Illustrative numbers (order-of-magnitude; for the sake of comparison only)
# - PV of baseline EAD without adaptation (years 1–30, 3% discount)
#   - Baseline hazard growth 0%: ≈ $2.35B (as shown in the assumptions section)
#   - With +0.5% annual escalation: ≈ $2.72B
#   - With +1.0% annual escalation: ≈ $3.25B
# - PV of adaptation benefits (present value of avoided damages) for core interventions
#   - Seawalls +port protection (Phase 2): baseline PV avoided ≈ ($1.30–$1.60)B
#   - Nature-based solutions (Phase 1–2): baseline PV avoided ≈ ($0.45–$0.60)B
#   - Infrastructure elevation and floodproofing: baseline PV avoided ≈ ($0.25–$0.35)B
#   - Voluntary relocation/buyouts: baseline PV avoided ≈ ($0.15–$0.25)B
# - Net PV (PV benefits − PV costs)
#   - Baseline (discount 3%, hazard growth 0%, population growth 0.60%): Net PV ≈ +$0.25B to +$0.50B (positive)
#   - Lower discount rate (2.4%): Net PV increases by ~+15% to +25% for core components
#   - Higher hazard growth (+0.5% or +1.0%): Net PV decreases by ~10%–25%, depending on the phase
#   - Higher population growth (+0.72%): Increases exposure, but also increases benefits of protection; net PV may shift modestly upward if benefits scale with population
# Interpretation:
# - The ranking of interventions (hard protection first, then nature-based, then relocation) remains generally robust under ±20% variations in discount rate, hazard escalation, and population growth, though the magnitude of PV benefits shifts.
# - If discount rate falls, PV benefits rise; if hazards escalate quickly, costs are higher and urgent protection of high-value assets is more compelling.
#
# I. Risks, failure modes, and contingency actions (three per key risk)
#
# 1) Financing risk
# - Risk: Insufficient or delayed funding to complete planned phases; market conditions raise borrowing costs.
# - Contingencies:
#   - Front-load low-cost, high-ambiguity elements (governance, initial nature-based works) to maintain momentum
#   - Activate alternate financing (catalyze green bonds or cat bonds; apply for BRIC/HMA grants; pursue P3 structures)
#   - Phase gate decisions with clear triggers to release further funds; maintain reserve lines
#
# 2) Equity and community legitimacy risk
# - Risk: Plans that improve infrastructure but worsen or fail to protect the poorest; loss of trust and participation
# - Contingencies:
#   - Strengthen targeted protections and relocation guarantees; ensure affordable housing and relocation assistance
#   - Create an independent equity advisory panel with legal oversight and transparent metrics
#   - Maintain a robust grievance mechanism; adjust program scope based on feedback
#
# 3) Technical and permitting risk
# - Risk: Technical failures or delays (e.g., structural seawalls not performing as expected; environmental permitting delays)
# - Contingencies:
#   - Use modular, testable components; pilot segments with adaptive management
#   - Employ independent design reviews and third-party verification; maintain contingency budgets for redesigns
#   - Build redundancy (alternative evacuation routes, backup power) and non-structural measures (early warning, land-use planning)
#
# 4) Governance and political risk
# - Risk: Changes in leadership or policy priorities threaten long-term plan continuity
# - Contingencies:
#   - Enshrine plan in a formal city policy framework; secure multi-party support and charter formalities
#   - Establish durable governance bodies with long-term terms and rotating leadership
#   - Regular public reporting and citizen oversight to sustain legitimacy
#
# 5) Environmental and ecological risk
# - Risk: Unintended ecological impacts from interventions; habitat degradation
# - Contingencies:
#   - Implement adaptive management with ecological monitoring; adjust projects if biodiversity signals decline
#   - Prioritize nature-based solutions where possible to maximize co-benefits
#   - Require environmental impact assessments and post-implementation auditing
#
# J. Three falsifiable pieces of evidence that would lead to abandoning the plan (within 10 years)
# 1) Material failure to reduceEAD or to protect key economic zones
#   - If, after a 5–10 year window, the PV of avoided damages is below 50% of projected baseline damages and high-value districts experience repeated multi-hazard losses, re-evaluate the cost-effectiveness of the protection strategy or pivot to alternative approaches.
# 2) Worsening inequities among the bottom 20%
#   - If equity metrics show that the bottom quintile’s safety, housing affordability, or access to essential services deteriorate despite program implementation (e.g., net losses in living standards, rising displacement burden), stop the current buyout/relocation approach and redesign with stronger social protections, housing subsidies, and inclusive economic supports.
# 3) Infeasibility or insolvency of financing mechanisms
#   - If critical funding channels (bonds, grants, cat bonds, or P3 pipelines) fail to materialize or become prohibitively costly, and the city cannot sustain the 30-year plan without compromising essential services or equity commitments, pause and renegotiate the program design, focusing on non-debt financing, grant-expedited projects, and a narrower scope.
#
# K. Simple calculations illustrating core logic (selected calculations shown)
# - PV factor for 30 years at 3%: 19.6
# - Baseline EAD example (illustrative)
#   - Year 1 EAD ≈ 0.75% × $16B = $120M
#   - PV of 30-year annuity: $120M × 19.6 ≈ $2.35B
# - Intervention PV (illustrative ranges)
#   - Seawalls/port protection PV avoided: ~$1.30–$1.60B
#   - Nature-based solutions PV avoided: ~$0.45–$0.60B
#   - Infrastructure floodproofing PV avoided: ~$0.25–$0.35B
#   - Relocation/buyouts PV avoided: ~$0.15–$0.25B
#   - Total PV avoided: ~ $2.15–$2.75B
# - Net PV (illustrative)
#   - Baseline PV damages: ~$2.35B
#   - PV avoided by plan: ~ $2.15–$2.75B
#   - Net PV range: approx −$0.20B to +$0.40B (with a sensitivity leaning toward positive when benefits are on the higher end)
# - Budget alignment
#   - Program cost: $2.0B nominal
#   - PV-equivalent cost (3%): ~$1.8B
#   - Net PV: relative advantage within a narrow band near break-even, but with substantial tail benefits in avoided damages and ecological/cultural gains
#
# L. Overall confidence in achieving goals (0–100%)
# - Confidence estimate: 72%
# - Justification: The proposed plan is phased, equity-focused, and leverages multiple financing avenues, which improves feasibility. The expected benefits in high-value economic zones are substantial, and nature-based solutions add co-benefits and cost-effectiveness. However, confidence is constrained by:
#   - Financing risks (the need to mobilize additional funds beyond the baseline)
#   - Potential delays in permitting and implementation
#   - The necessity of robust community engagement to avoid inequitable outcomes
#   - The reliance on behavioral responses (voluntary relocation) and the political will to maintain continuity over 30 years
# - The plan remains viable if financing channels are efficiently activated, equity safeguards are rigorously implemented, and governance structures are stable. If these do not materialize, confidence would decrease accordingly.
#
# Bottom line
# - A phased, equity-forward mix of hard protection, nature-based solutions, infrastructure upgrades, and voluntary relocation can meet the city’s goals of reducing long-term losses, protecting ecological and cultural assets, and avoiding harm to the poorest residents, within the $2.0B baseline and leveraging additional financing. Ongoing governance, transparent monitoring, and strong community engagement are essential to realize the plan’s objectives and adjust to evolving hazards and economic conditions. A transparent, adaptive approach maximizes the probability of achieving long-term resilience while keeping the poorest residents safe and economically secure.

# %%
# Anthropic has a slightly different API, and Max Tokens is required

model_name = "claude-sonnet-4-5"

claude = Anthropic()
response = claude.messages.create(model=model_name, messages=messages, max_tokens=1000)
answer = response.content[0].text

display(Markdown(answer))
competitors.append(model_name)
answers.append(answer)
# Out:
# # 30-Year Coastal Adaptation Plan for Mid-Sized Coastal City
#
# ## EXECUTIVE SUMMARY
# This plan allocates $2.0B across hybrid grey-green infrastructure, strategic retreat, and social resilience programs. The strategy protects the downtown core and working waterfront while facilitating managed relocation from high-risk areas, prioritizing the most vulnerable populations.
#
# ---
#
# ## PART A: BUDGET ALLOCATION & INTERVENTION TIMELINE
#
# ### Phase 1: Years 1-10 (Foundation & Protection) - $850M
#
# **1. Critical Infrastructure Hardening - $280M**
# - Elevate water/sewage treatment plants (+2.5m): $120M
# - Relocate emergency services & critical facilities: $90M
# - Upgrade stormwater drainage system: $70M
#
# **2. Hybrid Coastal Defense (Downtown & Port) - $320M**
# - Living seawall with oyster reefs (4 km): $180M
# - Beach nourishment + dune restoration (6 km): $85M
# - Tidal gate system at harbor entrance: $55M
#
# **3. Early Warning & Monitoring Infrastructure - $35M**
# - Real-time flood sensor network: $15M
# - Storm surge prediction system: $12M
# - Community alert infrastructure: $8M
#
# **4. Equity-Focused Relocation Preparation - $155M**
# - Purchase 450 properties in highest-risk zones: $110M
# - Establish relocation trust fund: $30M
# - Community planning & social services: $15M
#
# **5. Nature-Based Solutions (Ecological Buffer) - $60M**
# - Restore 200 hectares coastal wetlands: $40M
# - Create 50 hectares upland buffer forest: $20M
#
# ### Phase 2: Years 11-20 (Transformation & Adaptation) - $780M
#
# **6. Strategic Managed Retreat - $380M**
# - Acquire additional 650 properties: $240M
# - Buyout compensation (above market for poorest 20%): $85M
# - Infrastructure decommissioning: $35M
# - New affordable housing in safe zones: $20M
#
# **7. Enhanced Coastal Defense (Selective) - $210M**
# - Multi-layer protection for cultural heritage district: $95M
# - Working waterfront adaptation (floating docks, elevated facilities): $80M
# - Green infrastructure expansion (urban wetlands, bioswales): $35M
#
# **8. Economic Transition Support - $115M**
# - Fisheries adaptation (climate-resilient aquaculture): $50M
# - Tourism infrastructure relocation/upgrade: $40M
# - Workforce retraining programs: $25M
#
# **9. Social Infrastructure & Resilience Hubs - $75M**
# - Five community resilience centers (cooling, emergency shelter): $50M
# - Subsidized flood insurance pool: $25M
#
# ### Phase 3: Years 21-30 (Consolidation & Maintenance) - $370M
#
# **10. Ongoing Maintenance & Adaptive Management - $180M**
# - Infrastructure upkeep (6M/year × 30 years): $180M
#
# **11. Second-Generation Interventions - $120M**
# - Technology upgrades and replacements: $70M
# - Additional nature-based solutions: $50M
#
# **12. Contingency Reserve - $70M**
# - For accelerated sea-level rise or major storm damage
#
# ---
#
# ## PART B: COST-BENEFIT ANALYSIS
#
# ### Economic Benefits (Present Value, 3% discount rate, 50-year horizon)
#
# **Avoided Damages:**
# - Protected property value: ~$4.2B (12,000 structures × $350K average)
# - Avoided annual flood losses: $85M/year → PV ≈ $2.1B
# - Maintained tourism revenue: $180M/year × 30% at risk → PV ≈ $1.4B
# - Fisheries infrastructure protection: PV ≈ $420M
# - **Total avoided economic losses: ~$8.1B**
#
# **Direct Economic Returns:**
# - Green infrastructure ecosystem services: $8M/year → PV ≈ $200M
# - Enhanced property values in protected zones (+12%): PV ≈ $380M
# - Tourism resilience premium: PV ≈

# %%
gemini = OpenAI(api_key=google_api_key, base_url="https://generativelanguage.googleapis.com/v1beta/openai/")
model_name = "gemini-2.5-flash"

response = gemini.chat.completions.create(model=model_name, messages=messages)
answer = response.choices[0].message.content

display(Markdown(answer))
competitors.append(model_name)
answers.append(answer)
# Out:
# As an independent policy advisor, I have developed a comprehensive 30-year climate adaptation plan for your city. This plan prioritizes resilience, equity, and sustainable growth, aiming to minimize long-term economic losses while safeguarding your unique ecological and cultural heritage.
#
# ## Executive Summary
#
# This 30-year adaptation plan, budgeted at $2.0 billion, is designed to protect your mid-sized coastal city (population 350,000) from an anticipated 1.0 m sea-level rise and increased storm surge frequency/intensity over the next 50 years. The plan adopts a phased approach, combining nature-based solutions, targeted hard defenses, strategic infrastructure upgrades, and managed retreat, all underpinned by robust community engagement and a commitment to social equity. It aims to prevent an estimated $7-8 billion in economic losses, while preserving critical ecological services and cultural sites. The plan includes innovative funding mechanisms, strong governance, and clear monitoring strategies to ensure its success and adaptability.
#
# ## I. Assumptions and Data Inputs
#
# To develop this plan, the following explicit assumptions and data inputs were used:
#
# *   **Current City Population:** 350,000.
# *   **Population Growth Rate:** Assumed a modest 0.5% annual growth, leading to ~390,000 by year 30. This impacts future asset values and population at risk.
# *   **Sea-Level Rise (SLR):**
#     *   **Long-term Projection:** 1.0 meter over 50 years.
#     *   **30-Year Projection (for planning):** Assumed a linear rise, so (1.0 m / 50 years) * 30 years = **0.6 meters by year 30**. However, critical infrastructure interventions are designed with the full 1.0m (plus contingency) in mind due to their long lifespans.
# *   **Storm Surge Frequency & Intensity:** Assume a significant increase, where a current 1-in-100 year event effectively becomes a 1-in-50 year event, and typical storm surge heights increase by an additional **0.5 meters** during major events (on top of SLR).
# *   **Vulnerable Areas:** Estimated **20% of the city's land area** and associated assets (residential, commercial, infrastructure) are highly vulnerable to 0.6m SLR + surge, increasing to 25-30% with 1.0m SLR + surge.
# *   **Economic Structure:** Highly dependent on Tourism and Fisheries. Adaptation measures must support these sectors.
# *   **Property Values (Averages for Estimation):**
#     *   Residential Unit: $400,000
#     *   Commercial Establishment: $1,000,000
#     *   Public Infrastructure (per linear km for roads/utilities in vulnerable areas): $5,000,000
# *   **Total Asset Value at Risk (without adaptation):** Estimated cumulative potential economic damages over 30 years from chronic inundation and increased storm events (e.g., property damage, business interruption, infrastructure repair, environmental degradation) to be approximately **$10 billion**. This represents roughly 15-20% of the total estimated private and public asset value within the vulnerable zone (approx. 30,000 housing units, 1,000 commercial, 100km infrastructure).
# *   **Discount Rate:** Used **4%** for present value calculations, balancing short-term costs with long-term benefits.
# *   **Social Equity Constraint:** The poorest 20% of the population (approx. 70,000 individuals currently) **must not be made worse off**. This mandates targeted support for relocation, job training, and equitable access to protected areas.
# *   **Ecological Services & Cultural Heritage:** These are non-negotiable values requiring protection or appropriate mitigation/relocation.
# *   **Intervention Cost Estimates (Order of Magnitude):**
#     *   Nature-Based Solutions (NBS) (wetland/dune restoration): $5-15 million per km
#     *   Hard Defenses (seawalls, dikes): $15-25 million per km
#     *   Building Elevation/Flood-proofing: $100,000 - $200,000 per structure
#     *   Managed Retreat (property acquisition & relocation): $400,000 - $600,000 per household (includes property value, moving, social support).
# *   **Budget Allocation:** The available $2.0 billion over 30 years, implying an average annual spend of ~$67 million.
#
# ## II. Prioritized 30-Year Adaptation Plan
#
# The plan is structured into three phases, each building on the previous, with an emphasis on "no-regrets" actions and flexibility. The overall goal is to prevent approximately **$7-8 billion in cumulative economic losses** over 30 years, yielding an estimated Benefit-Cost Ratio (BCR) of 3.5:1 to 4:1 for the $2.0 billion investment.
#
# ### Phase 1: Planning, Nature-Based Solutions & Capacity Building (Years 1-10)
# *   **Budget Allocation:** $500 million
# *   **SLR by End of Phase:** ~0.2 m
#
# | Intervention | Description | Budget (Million) | Expected Benefits (30-yr cumulative) | Costs (30-yr cumulative) | Protected/Relocated/Abandoned & Why |
# | :---------- | :---------- | :--------------- | :---------------------------------- | :---------------------------- | :----------------------------------- |
# | **1. Comprehensive Vulnerability Assessment & Master Plan Integration** | Update zoning, building codes; detailed flood mapping; SLR scenarios. | $50 | Informed decision-making, reduced future maladaptation. Avoided **$500M** in misallocated funds. | Admin costs. | All areas - informs future actions. |
# | **2. Nature-Based Coastal Protection** | Restore/expand 25 km of wetlands & mangrove forests (estuaries, vulnerable coastlines); build 15 km of resilient dune systems. | $250 ($6.25M/km avg) | **Ecological:** Enhanced fisheries habitat, improved water quality, increased biodiversity. **Economic:** Natural storm buffer (avoided damages up to **$1.5B** in vulnerable low-lying commercial/residential areas near estuaries), boosted eco-tourism, carbon sequestration. **Social:** Recreational areas. | Land acquisition, planting, monitoring. | **Protected:** Key ecological zones, adjacent low-lying residential areas (e.g., "South Bay Wetlands"), some fishing communities. |
# | **3. Early Warning Systems & Evacuation Infrastructure** | Upgrade sensors, communication networks, reinforce evacuation routes and shelters. | $50 | **Social:** Reduced loss of life, safer evacuations. **Economic:** Reduced emergency response costs (avoided **$100M**), minimized business interruption. | Hardware, training, infrastructure. | All residents, particularly vulnerable communities. |
# | **4. Building Code Update & Pilot Flood-Proofing Program** | Mandatory new construction standards (elevation, flood-proofing). Pilot program for existing homes in moderate risk zones (500 homes). | $100 | **Economic:** Reduced property damage for new construction & participating homes (avoided **$200M** for pilot). **Social:** Increased homeowner resilience. | Admin, subsidies for pilot. | Select neighborhoods at moderate risk, future developments. |
# | **5. Cultural Heritage & Equity Preservation** | Inventory vulnerable sites; develop rapid relocation/documentation plans for key movable assets. Establish community engagement hubs. | $50 | **Cultural:** Safeguarding identity. **Social:** Inclusive planning, ensuring poorest 20% are engaged and informed. | Surveys, planning, initial engagement. | Specific historic districts (e.g., "Old Quarter"), vulnerable community assets. |
#
# ### Phase 2: Hardening Critical Assets & Strategic Retreat (Years 11-20)
# *   **Budget Allocation:** $800 million
# *   **SLR by End of Phase:** ~0.4 m
#
# | Intervention | Description | Budget (Million) | Expected Benefits (30-yr cumulative) | Costs (30-yr cumulative) | Protected/Relocated/Abandoned & Why |
# | :---------- | :---------- | :--------------- | :---------------------------------- | :---------------------------- | :----------------------------------- |
# | **1. Targeted Hard Defenses** | Construct/elevate 20 km of seawalls/dikes around the CBD, port, and key tourist zones. Incorporate floodgates. | $400 ($20M/km avg) | **Economic:** Direct protection of high-value commercial, tourism assets, and critical port infrastructure (avoided **$3.0B** in damages). Ensures business continuity. | Construction, maintenance. | **Protected:** Central Business District, Main Port Facilities, Premier Tourist Resorts. |
# | **2. Resilient Infrastructure Network** | Elevate and flood-proof critical utilities (substations, water treatment plants, communication hubs). Redundant systems. | $100 | **Economic:** Prevents cascading failures, maintains essential services (avoided **$500M** in economic disruption and repair). **Social:** Ensures public health and safety. | Engineering, construction. | All city infrastructure, supporting all residents. |
# | **3. Managed Retreat Program - Phase 1** | Acquire ~1,000 highly vulnerable low-income properties in designated flood zones (e.g., "Fisherman's Landing" and parts of "Old Town"). Provide comprehensive relocation assistance, job training, and new housing options (uphill, equitable). | $350 ($350k/household avg) | **Economic:** Avoided long-term protection costs for unviable areas (avoided **$700M** in property damages). **Social:** Enhanced safety, improved living conditions for vulnerable populations, upholding equity constraint. | Property acquisition, relocation services, social support. | **Relocated:** "Fisherman's Landing" (high flood risk, critical infrastructure in area to be relocated/elevated), parts of "Old Town" (historically significant but severely low-lying, with low-income residents). **Abandoned:** The vacated land will be converted into green space/tidal wetlands to provide further natural protection. |
# | **4. Cultural Heritage - Relocation/Documentation** | Begin physical relocation of selected smaller, movable cultural heritage assets; comprehensive digital documentation of immovable sites. | $50 | **Cultural:** Preservation of heritage. | Relocation, digital archiving. | Specific cultural heritage sites identified as unprotectable in situ. |
#
# ### Phase 3: Long-Term Resilience, Economic Diversification & Adaptive Management (Years 21-30)
# *   **Budget Allocation:** $700 million
# *   **SLR by End of Phase:** ~0.6 m
#
# | Intervention | Description | Budget (Million) | Expected Benefits (30-yr cumulative) | Costs (30-yr cumulative) | Protected/Relocated/Abandoned & Why |
# | :---------- | :---------- | :--------------- | :---------------------------------- | :---------------------------- | :----------------------------------- |
# | **1. Expansion of Multi-layered Defenses** | Further strengthen and extend 10 km of existing hard and nature-based defenses, based on updated SLR projections. | $300 ($15M/km avg) | **Economic:** Continued protection of critical assets, adapting to evolving threats (avoided **$1.5B** in damages post-Year 20). | Construction, maintenance. | Extended protection for key areas, new buffer zones. |
# | **2. Managed Retreat Program - Phase 2** | Acquire ~500 more properties in newly vulnerable or economically unviable areas; continue relocation and support programs. | $250 ($500k/household avg) | **Economic:** Avoided future protection costs (avoided **$350M**). **Social:** Prevents future displacement crises, ensures equity. | Property acquisition, relocation, new housing. | **Relocated:** Additional highly vulnerable residential areas (e.g., some waterfront homes), small commercial properties in newly identified risk zones. **Abandoned:** Converted to green infrastructure or nature preserves. |
# | **3. Economic Diversification & Green Jobs** | Invest in training programs for new 'blue economy' jobs (e.g., aquaculture, marine renewable energy, resilience consulting) for those affected by fisheries/tourism shifts. | $50 | **Economic:** Reduced reliance on vulnerable sectors, new growth opportunities. **Social:** Job security, reduced unemployment, enhances social equity. | Training programs, seed funding. | All residents, especially those affected by coastal changes. |
# | **4. Adaptive Governance & Monitoring Endowment** | Establish an endowment for ongoing monitoring, research, and adaptive management. Fund a permanent Climate Resilience Office. | $100 | **Operational:** Ensures long-term sustainability and flexibility of the plan. Continuous learning. | Endowment investment, staffing. | All aspects of the plan. |
#
# **Summary of Avoided Damages (Cumulative over 30 years):**
# *   Nature-Based Solutions: ~$1.5 Billion
# *   Pilot Flood-Proofing: ~$0.2 Billion
# *   Targeted Hard Defenses: ~$3.0 Billion
# *   Resilient Infrastructure: ~$0.5 Billion
# *   Managed Retreat: ~$1.05 Billion ($700M + $350M)
# *   Expansion of Defenses: ~$1.5 Billion
# *   **Total Estimated Avoided Damages:** ~$7.75 Billion (against a $2.0B investment)
#
# ## III. Funding and Finance Mechanisms (Beyond the $2.0B Baseline)
#
# The $2.0 billion budget is a strong start, but climate adaptation is an ongoing challenge. Here are three additional mechanisms to secure long-term funding:
#
# 1.  **Municipal Green Bonds:** The city could issue "Coastal Resilience Bonds" to attract socially responsible investors. These bonds would specifically fund eligible adaptation projects (e.g., nature-based solutions, resilient infrastructure).
#     *   **Mechanism:** Bonds are issued by the city, purchased by investors, and principal/interest repaid from general city revenues or dedicated fees.
#     *   **Potential:** Could raise an additional $500 million to $1 billion over the next 30 years, depending on market conditions and city credit rating.
#     *   **Benefit:** Diversifies funding, taps into a growing market for green investments, and signals the city's commitment to sustainability.
#
# 2.  **Tourism & Resilience Levy:** Implement a small, dedicated levy on tourism-related services (e.g., 1-2% on hotel stays, short-term rentals, or major attraction tickets).
#     *   **Mechanism:** Collected by businesses and remitted to a dedicated "Coastal Resilience Fund."
#     *   **Potential:** Given the city's tourism-dependent economy, this could generate $10-20 million annually (assuming $1 billion annual tourism revenue), accumulating to $300-600 million over 30 years.
#     *   **Benefit:** Directly links the industry benefiting from coastal attractions to their preservation. Tourists often accept small surcharges for environmental causes.
#
# 3.  **Public-Private Partnerships (PPPs) & Federal/State Grant Pursuit:** Actively pursue co-funding and partnerships for large-scale projects.
#     *   **Mechanism:**
#         *   **PPPs:** For projects benefiting specific private entities (e.g., port upgrades, beachfront resort protection), private developers or businesses contribute to project costs in exchange for long-term operational benefits or preferential leases.
#         *   **Federal/State Grants:** Dedicated grants for coastal resilience, infrastructure, wetland restoration, and community development.
#     *   **Potential:** Highly variable, but successful grant applications and PPPs could unlock hundreds of millions of dollars (e.g., $100-300 million over 30 years).
#     *   **Benefit:** Leverages external capital and expertise, reduces direct city burden, and ensures alignment with national/state resilience goals.
#
# ## IV. Governance and Community-Engagement Measures
#
# Ensuring equity and effectiveness requires robust governance and continuous community involvement:
#
# *   **1. City Resilience Office (CRO):** Establish a dedicated office with a Chief Resilience Officer reporting directly to the Mayor. This office will be responsible for plan implementation, inter-departmental coordination, external partnerships, and monitoring.
# *   **2. Multi-Stakeholder Resilience Task Force:** Create an oversight body comprising city officials, scientists, business leaders (tourism, fisheries), environmental NGOs, community representatives (including representatives from vulnerable groups), and cultural heritage experts. This task force will provide strategic guidance and ensure broad buy-in.
# *   **3. Neighborhood Resilience Hubs & Advisory Boards:** For areas most affected by proposed interventions (e.g., managed retreat zones, areas receiving new defenses), establish local hubs and dedicated advisory boards. These will serve as direct channels for feedback, co-design of solutions, and grievance resolution, ensuring the "poorest 20% not worse off" clause is upheld.
# *   **4. Dedicated Equity & Relocation Ombudsman:** An independent ombudsman will oversee the managed retreat and social support programs, ensuring fair compensation, equitable relocation options, and access to resources for affected households, particularly the poorest 20%.
# *   **5. Transparent Communication & Accessible Data:** Implement a public-facing dashboard showing project progress, spending, and monitoring data. Regular town halls, workshops, and accessible informational materials (multi-lingual) will foster trust and informed participation.
#
# ## V. Measurable Success Metrics and Monitoring Strategies
#
# **Measurable Success Metrics:**
#
# 1.  **Reduced Economic Losses:**
#     *   **Metric:** X% reduction in average annual direct property damages (residential, commercial) from storm events compared to the 5-year average pre-plan. Target: **30% reduction by Year 10, 60% by Year 20, 75% by Year 30.**
#     *   **Metric:** X% reduction in average annual business interruption losses from storm events. Target: **25% reduction by Year 10, 50% by Year 20, 70% by Year 30.**
# 2.  **Coastal Protection & Infrastructure Resilience:**
#     *   **Metric:** X km of coast protected by nature-based solutions (Target: 40 km).
#     *   **Metric:** X km of critical hard defenses constructed/elevated (Target: 30 km).
#     *   **Metric:** X% of critical public infrastructure (power, water, communication) in vulnerable zones upgraded to withstand 1.0m SLR + surge. Target: **80% by Year 30.**
# 3.  **Social Equity & Community Impact:**
#     *   **Metric:** Number of households successfully relocated with comprehensive support, without a decrease in household income or access to essential services for the poorest 20%. Target: **~1,500 households by Year 30.**
#     *   **Metric:** X% of affected residents reporting satisfaction with engagement processes and outcomes (via surveys). Target: **>70% satisfaction.**
#     *   **Metric:** No net increase in the poverty rate within the lowest 20% of the population due to adaptation initiatives.
# 4.  **Ecological Health & Cultural Heritage:**
#     *   **Metric:** X hectares of key coastal ecosystems (wetlands, dunes) restored/created, with documented increase in biodiversity (e.g., specific indicator species populations). Target: **>3,000 hectares.**
#     *   **Metric:** X number of priority cultural heritage sites physically protected or successfully relocated/digitally preserved. Target: **All identified priority sites.**
# 5.  **Funding & Governance:**
#     *   **Metric:** X% of annual budget successfully disbursed according to plan.
#     *   **Metric:** X additional funding secured from external sources.
#
# **Monitoring Strategies:**
#
# *   **Real-time Environmental Monitoring:** Network of tide gauges, wave buoys, and meteorological stations to track SLR, storm surge, and weather patterns.
# *   **Remote Sensing & GIS:** Regular aerial photography, LiDAR scans, and satellite imagery to track coastline changes, wetland health, and land use patterns.
# *   **Post-Event Damage Assessments:** Standardized protocols for quantifying direct and indirect economic losses after every major storm event, feeding into an economic impact model.
# *   **Socio-Economic Surveys:** Biennial surveys of vulnerable populations to track income, housing stability, access to services, and perceived safety/well-being. Specific focus on relocated communities.
# *   **Ecological Health Assessments:** Regular biodiversity surveys, water quality testing, and fisheries stock assessments in restoration areas and adjacent waters.
# *   **Financial Audits & Performance Reviews:** Annual audits of expenditure and independent reviews of project effectiveness against metrics.
# *   **Public Feedback & Grievance Mechanism:** Continuous collection of community feedback through the Resilience Hubs and Ombudsman, ensuring adaptive management.
#
# ## VI. Sensitivity Analysis
#
# We examine how the plan's ranking and resource allocation might shift if three key parameters vary by ±20%.
#
# 1.  **Sea-Level Rise (SLR) Rate (±20% by Year 30):**
#     *   **Base Case:** 0.6m by Year 30.
#     *   **Scenario A: Faster SLR (0.72m by Year 30):**
#         *   **Impact:** Urgency increases significantly. Phase 2 interventions (hard defenses, managed retreat) would need to be accelerated and potentially expanded. Less emphasis on long-term ecological restoration in Phase 1 if it doesn't provide immediate protection. More budget would shift to protection and proactive relocation, potentially reducing the scale of economic diversification efforts in Phase 3.
#         *   **Shift:** Re-prioritize hard defenses and larger-scale managed retreat to earlier phases. Increase budget allocation to Phase 2 by ~$100M, taking from Phase 1 NBS and Phase 3 economic diversification.
#     *   **Scenario B: Slower SLR (0.48m by Year 30):**
#         *   **Impact:** Provides more time for planning and nature-based solutions. Managed retreat can be more gradual. More resources could be allocated to economic diversification and comprehensive ecological restoration. The overall budget might be sufficient to achieve higher levels of protection or deliver more co-benefits.
#         *   **Shift:** Increase budget for Phase 1 NBS by ~$50M, delay some Phase 2 hard defenses or scale them back slightly, reallocate ~$50M to Phase 3 economic diversification and expanded green spaces.
#
# 2.  **Total Budget (±20%):**
#     *   **Base Case:** $2.0 Billion.
#     *   **Scenario A: Higher Budget ($2.4 Billion):**
#         *   **Impact:** Allows for more comprehensive protection, more generous relocation packages, and faster implementation. Could expand both hard defenses and nature-based solutions, and invest more in innovative technologies or economic diversification.
#         *   **Shift:** Increase the scale of all interventions, particularly expanding the linear kilometers of NBS and hard defenses, and offering enhanced compensation/housing for managed retreat, or reducing the timeline for certain projects. E.g., add $200M to Phase 2 for increased protection coverage, $200M to Phase 3 for expanded economic diversification.
#     *   **Scenario B: Lower Budget ($1.6 Billion):**
#         *   **Impact:** Forces difficult trade-offs. Prioritization would shift almost exclusively to critical infrastructure and high-value assets. Managed retreat might become more limited or less generous. Nature-based solutions might be scaled back significantly. More reliance on policy measures (building codes).
#         *   **Shift:** Deep cuts across the board. Prioritize the core CBD/Port protection in Phase 2 ($400M remains) and essential utility upgrades ($100M remains). Scale back NBS by 50% ($125M total). Significantly reduce managed retreat to only the most critical areas (~$400M total for both phases). Phase 3 becomes primarily monitoring and basic maintenance.
#
# 3.  **Discount Rate (±20%):**
#     *   **Base Case:** 4%.
#     *   **Scenario A: Higher Discount Rate (4.8%):**
#         *   **Impact:** Future benefits (e.g., avoided damages 20-30 years out) become less valuable in present terms. Favors interventions with immediate benefits and lower upfront costs. Might slightly de-prioritize long-term nature-based solutions or strategic retreat with distant payoffs if their immediate BCR is perceived as lower.
#         *   **Shift:** Could slightly reduce emphasis on longer-term NBS projects in favor of immediate hard defenses. Decision-making for managed retreat might prioritize properties with higher immediate protection costs.
#     *   **Scenario B: Lower Discount Rate (3.2%):**
#         *   **Impact:** Future benefits are valued more highly. Favors long-term investments, including extensive nature-based solutions and well-planned strategic retreat, as their long-term payoffs become more attractive.
#         *   **Shift:** Strengthens the argument for nature-based solutions and comprehensive managed retreat, potentially allowing for more generous compensation packages in these programs.
#
# ## VII. Risks, Failure Modes, and Contingency Actions
#
# 1.  **Risk: Political Will and Funding Inconsistency**
#     *   **Failure Mode:** Future mayoral administrations or city councils may deprioritize adaptation, divert funds, or delay critical projects, leading to stalled progress and increased vulnerability over time.
#     *   **Contingency Actions:**
#         *   **Institutionalize:** Establish the City Resilience Office and Resilience Task Force through permanent ordinances, making them less susceptible to political whims.
#         *   **Demonstrate Early Success:** Focus on highly visible, early "wins" (e.g., successful wetland restoration, effective early warning system) to build public and political support.
#         *   **Diversify Funding:** Actively pursue external funding (Green Bonds, federal grants) to reduce sole reliance on fluctuating municipal budgets.
#         *   **Public Awareness Campaign:** Continuously educate citizens about the long-term benefits and costs of inaction, fostering public demand for plan adherence.
#
# 2.  **Risk: Underestimation of SLR or Storm Surge Impacts**
#     *   **Failure Mode:** Adaptation infrastructure (seawalls, elevated structures) is insufficient or too low to cope with actual rates of SLR or more intense storm surges, leading to catastrophic failures and widespread damage despite investment.
#     *   **Contingency Actions:**
#         *   **Adaptive Design:** All major infrastructure projects will incorporate "future-proofing" (e.g., foundations designed to support higher wall extensions, modular components for easy upgrade).
#         *   **Regular Scientific Review:** Biennial review of the latest IPCC reports and regional climate projections by an independent scientific panel to update local SLR and storm surge models.
#         *   **Contingency Reserve:** Allocate 5% of the annual budget to a flexible "Climate Contingency Fund" for emergency upgrades or unforeseen challenges.
#         *   **Enhanced Early Warning:** Continuously improve early warning systems and evacuation protocols to mitigate impacts of events exceeding design capacity.
#
# 3.  **Risk: Social Resistance to Managed Retreat and Equity Violations**
#     *   **Failure Mode:** Communities designated for managed retreat resist relocation due to perceived unfair compensation, lack of suitable alternatives, or cultural attachment, leading to legal challenges, social unrest, and failure to meet the "poorest 20% not worse off" constraint.
#     *   **Contingency Actions:**
#         *   **Proactive & Participatory Engagement:** Initiate dialogue with affected communities *years* in advance. Co-design solutions and ensure relocation options meet their needs (e.g., proximity to jobs, schools, cultural centers).
#         *   **"Fair Plus" Compensation:** Offer compensation packages that exceed market value and cover all relocation costs, including social and psychological support, job training, and assistance with establishing new community ties.
#         *   **Flexible Options:** Provide a range of relocation options, including assisted move, buy-out, or land swap.
#         *   **Independent Ombudsman:** The dedicated Equity & Relocation Ombudsman provides an impartial channel for grievances and ensures transparency and fairness.
#
# ## VIII. Falsifiable Evidence for Abandoning the Plan (within 10 years)
#
# If any of the following three concrete, falsifiable pieces of evidence are observed within the next 10 years, it would warrant a fundamental re-evaluation and likely abandonment of the current plan:
#
# 1.  **Observed Sea-Level Rise Divergence:** If, by Year 10, the observed local sea-level rise is either **less than 5 cm** (instead of the expected ~20 cm) *or* **more than 40 cm**, suggesting a drastic deviation from current scientific projections that would invalidate the underlying physical assumptions of the plan's scale and urgency.
# 2.  **Economic Foundation Collapse:** If the combined tourism and fisheries sectors experience a sustained **cumulative decline of 25% or more** in their contribution to the city's GDP (adjusted for inflation) within the next 10 years, *and* this decline is primarily attributable to factors unrelated to climate change, indicating a fundamental flaw in the city's economic viability and ability to fund such an ambitious adaptation plan.
# 3.  **Mass Exodus of Vulnerable Populations:** If, within the next 10 years, official census data or equivalent reliable demographic surveys show a **net out-migration of >15%** of the city's population identified as being in the lowest 20% income bracket, directly attributable to a perceived lack of safety, support, or economic opportunity within the city's adaptation framework, demonstrating a critical failure in the plan's core social equity mandate.
#
# ## IX. Overall Confidence Estimate
#
# **Confidence Estimate: 75%**
#
# **Justification:**
#
# This plan is comprehensive, balances diverse interventions, respects the city's constraints (budget, equity, heritage), and builds in mechanisms for long-term sustainability and adaptability. The phased approach allows for learning and adjustment, while the strong emphasis on community engagement and equity addresses critical social dimensions. The proposed funding mechanisms broaden financial capacity, and the monitoring strategies provide a clear pathway for tracking progress and ensuring accountability.
#
# However, a 100% confidence level is unachievable in real-world policy planning, especially for long-term, complex challenges like climate change. The 25% uncertainty acknowledges:
# 1.  **Scientific Uncertainty:** While based on best available data, the precise timing and intensity of SLR and storm surges can vary.
# 2.  **Political Will:** Sustaining commitment over 30 years and multiple administrations is always a challenge.
# 3.  **Unforeseen Events:** Global economic shocks, pandemics, or other local crises could divert resources or attention.
# 4.  **Social Dynamics:** Community engagement, while robust, can still encounter unforeseen resistance or complexities.
# 5.  **Cost Escalation:** Construction and relocation costs can increase beyond projections.
#
# Despite these inherent uncertainties, the plan's flexibility, multi-faceted approach, and strong governance framework provide a high degree of confidence in its ability to meet the city's stated goals.

# %%
deepseek = OpenAI(api_key=deepseek_api_key, base_url="https://api.deepseek.com/v1")
model_name = "deepseek-chat"

response = deepseek.chat.completions.create(model=model_name, messages=messages)
answer = response.choices[0].message.content

display(Markdown(answer))
competitors.append(model_name)
answers.append(answer)
# Out:
# # **Coastal Resilience Adaptation Plan for Mid-Sized Coastal City (2025–2055)**
#
# ---
#
# ## **1. Executive Summary**
#
# This 30-year adaptation plan prioritizes **hybrid approaches** combining engineered protection, ecosystem-based adaptation, and strategic relocation to address 1.0 m of sea-level rise (SLR) and increased storm surges. The $2.0 billion budget is allocated across three 10-year phases, focusing first on immediate risk reduction and equity protection, then on scaling up nature-based solutions and infrastructure, and finally on long-term resilience and managed retreat where unavoidable. The plan aims to protect 85% of economic assets, ensure no net loss of ecological services, and avoid disproportionate impacts on vulnerable communities.
#
# ---
#
# ## **2. Key Assumptions & Data Inputs**
#
# | Parameter | Value | Justification/Source |
# |-----------|-------|----------------------|
# | Population | 350,000, growing at 0.5%/year | Typical for stable coastal city |
# | Discount rate | 3% real | Standard for public long-term projects |
# | SLR by 2075 | 1.0 m | IPCC mid-range scenario (likely RCP4.5–6.0) |
# | Storm surge increase | +30% height, +50% frequency | Based on regional downscaling studies |
# | Current annual flood damage | $50M/year | Estimated from property exposure × flood probability |
# | Damage function exponent | 2.5 (damage ∝ (water depth)^2.5) | Standard in flood risk economics |
# | Value of ecological services | $5,000/ha/year for wetlands | Meta-analysis of coastal ecosystem values |
# | Poorest 20% income threshold | <$30,000/household | City-specific data |
# | Cultural heritage sites | 12 major sites, 40 minor sites | City inventory |
# | Tourism revenue | $800M/year, grows 2%/year without shocks | Current economic reports |
# | Fisheries revenue | $200M/year, stable if ecosystems maintained | Current economic reports |
# | Property value at risk (today) | $15B total, $3B in high-risk zones | Assessor data + flood mapping |
#
# ---
#
# ## **3. Prioritized 30-Year Adaptation Plan**
#
# ### **Phase 1 (2025–2034): Foundational Protection & Equity Focus**
# **Budget: $600M**
#
# | Intervention | Cost | Year-by-Year Spending | Benefits/Costs | Protected/Relocated Areas |
# |--------------|------|------------------------|----------------|----------------------------|
# | **1.1 Upgraded drainage & pump stations** | $200M | $20M/year for 10 years | Reduces nuisance flooding by 70%; benefit–cost ratio (BCR) ~2.5; protects low-income neighborhoods (e.g., Southbank, Harborview) from frequent flooding. | Protects 50,000 residents, prevents $15M/year in damages. |
# | **1.2 Living shorelines & mangrove/wetland restoration** | $150M | $15M/year for 10 years | Creates 500 ha of buffer; provides $2.5M/year in ecosystem services + $10M/year in avoided damages; enhances fisheries. | Protects eastern shore communities and fisheries infrastructure. |
# | **1.3 Elevation & flood-proofing grants for low-income households** | $150M | $15M/year for 10 years | Protects 3,000 households; avoids displacement; BCR ~1.8 considering social stability. | Targeted at poorest 20% neighborhoods (map attached). |
# | **1.4 Early warning systems & community resilience hubs** | $100M | $10M/year for 10 years | Reduces storm mortality by ~80%; provides cooling centers and emergency power. | All neighborhoods, with hubs in vulnerable areas. |
#
# ### **Phase 2 (2035–2044): Scaling Protection & Nature-Based Solutions**
# **Budget: $800M**
#
# | Intervention | Cost | Year-by-Year Spending | Benefits/Costs | Protected/Relocated Areas |
# |--------------|------|------------------------|----------------|----------------------------|
# | **2.1 Modular floodwalls & deployable barriers** | $300M | $30M/year for 10 years | Protects downtown and historic district; BCR ~3.0; allows incremental height increase as SLR progresses. | Protects $8B in property value and 12 major cultural sites. |
# | **2.2 Beach nourishment & dune restoration** | $200M | $20M/year for 10 years | Maintains tourism beaches; reduces wave energy; BCR ~2.2 (includes tourism benefits). | Protects north shore tourism corridor. |
# | **2.3 Aquifer recharge & stormwater green infrastructure** | $150M | $15M/year for 10 years | Prevents saltwater intrusion; reduces drainage costs; BCR ~1.5. | Protects water supply for entire city. |
# | **2.4 Subsidized relocation for highest-risk low-income households** | $150M | $15M/year for 10 years | Moves 500 households to higher ground; avoids catastrophic losses. | Managed retreat from lowest-lying areas (e.g., Seaside Flats). |
#
# ### **Phase 3 (2045–2055): Long-Term Resilience & Managed Transition**
# **Budget: $600M**
#
# | Intervention | Cost | Year-by-Year Spending | Benefits/Costs | Protected/Relocated Areas |
# |--------------|------|------------------------|----------------|----------------------------|
# | **3.1 Permanent storm surge barrier (gated)** | $400M | $40M/year for 10 years | Final defense for inner harbor; BCR ~2.8 over 50 years. | Protects port, wastewater plant, and 100,000 residents. |
# | **3.2 Floating infrastructure for marina & waterfront** | $100M | $10M/year for 10 years | Maintains tourism and fishing access; BCR ~1.8. | Adapts harbor zone without losing use. |
# | **3.3 Strategic abandonment & conversion to buffer zones** | $100M | $10M/year for 10 years | Converts at-risk areas to parks/wetlands; reduces future liabilities. | Abandons 200 ha of low-density, high-risk land (e.g., North Marshes). |
#
# ---
#
# ## **4. Additional Funding Mechanisms Beyond $2.0B Baseline**
#
# 1. **Resilience Bonds (Catastrophe Bonds)** – Transfer risk to capital markets; could raise $200–500M for post-disaster rebuilding without affecting city debt.
# 2. **Tourist Resilience Surcharge** – $2/night on hotel stays; generates ~$10M/year, dedicated to beach/dune maintenance and floodproofing cultural sites.
# 3. **Transfer of Development Rights (TDR) Program** – Allow developers to buy rights from retreat zones to build denser in safe areas; could generate $150M in equity value while directing growth away from risk.
#
# ---
#
# ## **5. Governance & Equity Measures**
#
# - **Community Resilience Councils** in each neighborhood, with veto power over projects affecting their area.
# - **Equity Impact Assessment** required for every project, ensuring no net harm to poorest 20%.
# - **Priority hiring** from vulnerable communities for adaptation jobs.
# - **Land trust model** for relocated households to prevent displacement gentrification.
#
# ---
#
# ## **6. Success Metrics & Monitoring**
#
# | Metric | Target | Monitoring Method |
# |--------|--------|-------------------|
# | Reduction in annual flood losses | >50% by 2035, >80% by 2055 | Insurance claims + city damage assessments |
# | No net loss of ecological services | Maintain or increase ecosystem service value | Remote sensing + biophysical surveys |
# | Zero displacement of poorest 20% without consent | 100% compliance | Household surveys + tracking |
# | Tourism revenue maintained | >$1B/year real by 2040 | Tourism board data |
# | Fisheries biomass stable | No decline beyond natural variability | Fisheries stock assessments |
#
# ---
#
# ## **7. Sensitivity Analysis (±20% Variation in Key Parameters)**
#
# | Parameter | Change | Impact on Plan |
# |-----------|--------|----------------|
# | **Discount rate** | +20% (3.6%) | Reduces NPV of long-term projects; shifts spending to short-term measures (e.g., more relocation, less surge barrier). |
# | **Discount rate** | –20% (2.4%) | Makes long-term engineering more attractive; could increase Phase 3 budget. |
# | **SLR rate** | +20% (1.2 m by 2075) | Accelerates relocation and barrier construction; may require reallocating funds from beach nourishment to higher protection. |
# | **SLR rate** | –20% (0.8 m by 2075) | Slows timeline; allows more investment in nature-based solutions and less in hard engineering. |
# | **Storm surge intensity** | +20% (36% height increase) | Increases early investment in floodwalls and warning systems; may require larger Phase 1 budget. |
# | **Storm surge intensity** | –20% (24% height increase) | Reduces urgency of some protections; could shift funds to ecological restoration. |
#
# ---
#
# ## **8. Key Risks & Contingency Actions**
#
# | Risk | Contingency Action |
# |------|---------------------|
# | **Faster-than-expected SLR** | Pre-purchased options for additional floodwall modules; pre-permitted retreat zones; accelerate relocation funding. |
# | **Political/community opposition to relocation** | Switch to “buy-out then lease-back” model; enhance participation; use TDR program to increase benefits. |
# | **Cost overruns on major engineering** | Establish 10% contingency fund from tourist surcharge; phase projects with clear go/no-go decision points. |
#
# ---
#
# ## **9. Falsifiable Evidence to Abandon Plan (within 10 years)**
#
# 1. **SLR acceleration** – If observed SLR rate exceeds 8 mm/year (currently ~4 mm/year) consistently for 5 years, indicating >1.5 m by 2075.
# 2. **Equity failure** – If poorest 20% experience >10% faster increase in flood insurance costs or displacement rates than city average.
# 3. **Ecosystem collapse** – If >30% of restored wetlands die off due to unforeseen water quality or temperature changes, undermining nature-based defense.
#
# ---
#
# ## **10. Overall Confidence Estimate**
#
# **70% confidence** that this plan will meet the city’s goals.
#
# **Justification:**
# - Strengths: Phased approach allows learning and adjustment; equity mechanisms are built in; hybrid strategies balance costs.
# - Weaknesses: Uncertainty in climate projections; potential for community conflict; reliance on sustained funding beyond baseline.
# - The 70% reflects a realistic assessment that the plan is robust to moderate changes in climate variables and socio-economic conditions, but could be undermined by extreme events or governance failures. Regular review every 5 years is essential to maintain confidence.
#
# ---
#
# **Plan designed by:** Independent Policy Advisor
# **Date:** 2025
# **Revision cycle:** 5 years, or after major trigger events.

# %%
# Updated with the latest Open Source model from OpenAI

groq = OpenAI(api_key=groq_api_key, base_url="https://api.groq.com/openai/v1")
model_name = "openai/gpt-oss-120b"

response = groq.chat.completions.create(model=model_name, messages=messages)
answer = response.choices[0].message.content

display(Markdown(answer))
competitors.append(model_name)
answers.append(answer)
# Out:
# ## 1.  Overview
#
# **City:** Mid‑size (≈350 000) coastal city, tourism + fisheries‑driven economy
# **Climate stressor:** +1.0 m sea‑level rise (SLR) by 2070 ± 20 %; 30 % ↑ storm‑surge frequency, 25 % ↑ intensity
# **Budget:** **US $2.0 billion** (real, 30‑yr horizon) – “baseline” funds that the mayor can allocate directly.
# **Mandates**
#
# | Goal | Constraint |
# |------|------------|
# | **Equity** – no program may leave the poorest 20 % of households worse‑off |  |
# | **Economic** – minimise long‑term net loss of tourism, fisheries, and tax base |  |
# | **Ecology & Culture** – preserve or enhance ecosystem services and heritage sites |  |
#
# The plan is organized into **four pillars** that together meet the mandates, each with a **phase‑by‑phase spending schedule**, **expected benefits**, and **equity safeguards**.
#
# ---
#
# ## 2.  Core Assumptions & Data Inputs
#
# | Parameter | Base value | Source / Rationale |
# |-----------|------------|--------------------|
# | **Population 2025** | 350 000 | Census |
# | **Population growth (annual)** | **0.8 %** | Regional trend (UN‑World Urbanization Prospects) |
# | **Real discount rate** | **3 %** | Standard municipal CBA practice |
# | **Sea‑level rise 2070** | **1.0 m** | IPCC AR6 “SSP2‑4.5” median for 30 °N‑35 °N coast |
# | **Storm‑surge frequency 2070** | **+30 %** | NOAA historical trend extrapolation |
# | **Baseline annual flood damage (2025)** | **US $200 M** (direct & indirect) | City insurance & loss‑adjuster data |
# | **Damage growth without adaptation** | **$200 M → $600 M** by 2070 (≈3 %/yr) | Damage function d = α·(SLR)^β, α=$200 M, β≈2 |
# | **Value of ecosystem services (wetland, reef, dunes)** | **$1.2 B** (present value 2025‑2070) | US EPA coastal ecosystem valuation |
# | **Social cost of carbon (SCC)** | **$55 / t CO₂** (2025) | US DOT SCC 2021 |
# | **Construction cost index (CCI)** | 1.0 in 2025; 1.5 by 2070 (inflation + material) | AIA construction cost forecast |
# | **Equity threshold** | Bottom‑quintile household income = **$30 k / yr** | City tax‑records |
# | **Maximum acceptable net‑present‑value (NPV) loss for poorest 20 %** | **0** (no net loss) | Policy mandate |
#
# All monetary figures are **real dollars** (inflation‑adjusted).
#
# ---
#
# ## 3.  Phase‑Based Budget Allocation
#
# | Phase | Years | Main Objectives | Core Interventions (cost) | % of $2 B | Real‑term spending (US$) |
# |-------|-------|----------------|--------------------------|----------|---------------------------|
# | **Phase 1 – Foundations** | **1‑5** | Rapid risk reduction, data, governance set‑up | • 1 km “Living‑Shoreline” pilot (wetland + oyster reef) – $40 M  <br>• City‑wide Flood‑Risk Mapping & Early‑Warning System – $30 M  <br>• Equity‑Resilience Office (staff, advisory board) – $10 M  <br>• Pilot “Elevate‑Critical‑Infrastructure” (water treatment plant) – $60 M | 7 % | **$140 M** |
# | **Phase 2 – Hard + Nature‑Based Defenses** | **6‑15** | Protect high‑value tourism & cultural assets, create buffer zones | • **Storm‑Surge Barrier** at main harbor (gate + levee) – $600 M  <br>• **Living‑Shoreline Expansion** (5 km of marsh & dune restoration) – $150 M  <br>• **Elevated Road Network** (primary arterial & evacuation routes) – $250 M  <br>• **Green Roof & Flood‑Resilient Housing Retrofits** for 3 000 low‑income units – $120 M  | 62 % | **$1 240 M** |
# | **Phase 3 – Managed Retreat & Adaptive Growth** | **16‑30** | Relocate untenable zones, re‑zone, sustain fisheries & tourism | • **Buy‑out & Relocation Program** for 1 500 properties in the historic waterfront (≈15 % of at‑risk housing) – $350 M  <br>• **New “Resilient Waterfront”** mixed‑use district on reclaimed upland (public‑private) – $300 M (city equity, private capital)  <br>• **Fisheries Port Modernisation** (dry‑dock, flexible‑pier, habitat zones) – $150 M  <br>• **Adaptive Tourism Hub** (climate‑proof hotels, boardwalks) – $120 M  | 31 % | **$620 M** |
# | **Contingency & Administration** | **All** | 5 % of total for overruns, monitoring, community outreach | — | **5 %** | **$100 M** |
# | **Total** | **30 yr** | — | — | **100 %** | **$2 000 M** |
#
# *All spending is front‑loaded to the first 15 yr because early risk reduction yields the highest NPV (see Section 5).*
#
# ---
#
# ## 4.  Intervention‑by‑Intervention Benefit‑Cost Summary
#
# | # | Intervention | Lifetime (yr) | NPV of Benefits* | NPV of Costs** | B/C Ratio (3 % disc.) | Primary Benefits (quantified) |
# |---|--------------|--------------|------------------|----------------|----------------------|--------------------------------|
# | 1 | Living‑Shoreline pilot (1 km) | 30 | $95 M | $40 M | **2.4** | • 0.15 km² marsh sequesters 0.3 Mt CO₂ → $16 M SCC benefit  <br>• Flood attenuation: 0.8 m reduction → $12 M avoided damage annually (PV $120 M) |
# | 2 | City‑wide Flood‑Risk Mapping + Early‑Warning | 30 | $80 M | $30 M | **2.7** | • 15 % reduction in storm‑surge casualties (value of statistical life $9 M) → $12 M PV <br>• Faster recovery saves $6 M/yr in business interruption |
# | 3 | Storm‑Surge Barrier (harbor) | 30 | $1 200 M | $600 M | **2.0** | • Protects $3 B of tourism & port assets (PV) → $1 200 M avoided loss <br>• Enables continued operation of heritage cruise terminal |
# | 4 | Living‑Shoreline expansion (5 km) | 30 | $400 M | $150 M | **2.7** | • Adds 0.75 km² wetland → $45 M SCC + $30 M flood protection <br>• Enhances fish nursery → $20 M fisheries revenue |
# | 5 | Elevated Road Network (10 km) | 30 | $520 M | $250 M | **2.1** | • Keeps evacuation routes functional → $40 M saved in life‑value <br>• Prevents $30 M/yr in freight disruption |
# | 6 | Flood‑Resilient Housing Retrofits (3 000 units) | 30 | $260 M | $120 M | **2.2** | • Keeps 3 000 low‑income families in place → $45 M avoided relocation cost <br>• Energy‑efficiency savings $5 M/yr |
# | 7 | Buy‑out & Relocation (1 500 homes) | 30 | $470 M | $350 M | **1.3** | • Eliminates exposure of 4 % of city‑wide built‑up area <br>• Opens land for public park (social value $30 M) |
# | 8 | Resilient Waterfront (mixed‑use) | 30 | $560 M | $300 M | **1.9** | • Generates $80 M/yr new tax base (PV $560 M) <br>• Provides climate‑safe tourism capacity |
# | 9 | Fisheries Port Modernisation | 30 | $340 M | $150 M | **2.3** | • 12 % increase in landed value (≈$15 M/yr) <br>• Habitat zones boost stock recruitment (+$5 M/yr) |
# |10 | Adaptive Tourism Hub | 30 | $260 M | $120 M | **2.2** | • 10 % reduction in climate‑related occupancy loss → $26 M/yr revenue retained |
#
# \* **NPV of Benefits** includes avoided flood damages, avoided loss of life (VSL = $9 M), ecosystem‑service valuation, and incremental economic activity.
# \** **NPV of Costs** includes construction, O&M (5 % of capital per yr), and de‑commissioning (if any).
#
# **Total NPV of benefits ≈ $5.1 B**, **NPV of costs = $2.0 B**, **aggregate B/C = 2.6** – a strong economic case even after discounting.
#
# ---
#
# ## 5.  Geographic Prioritisation (Who is Protected, Relocated, Abandoned?)
#
# | Area (population / assets) | Elevation (m ASL) | Current risk (2025) | Intervention | Status by 2050 |
# |----------------------------|-------------------|----------------------|--------------|----------------|
# | **A. Historic Harbor & Tourist Promenade** (≈15 % of tourism revenue) | 0‑0.5 | High (≥30 % chance of >1 m surge) | Storm‑Surge Barrier + levee + heritage‑site elevation | **Protected** – barrier operational; key heritage buildings lifted/retro‑fitted |
# | **B. Low‑income coastal district “Bayview”** (≈12 % of poorest 20 % households) | 0‑1.2 | Very high (annual flood >2 ×) | Buy‑out & relocation to new inland public housing (Phase 3) | **Relocated** – compensated at market + 20 % premium; new units meet “climate‑safe” standards |
# | **C. Commercial fishing village “Marlon”** (≈8 % of fisheries employment) | 0‑0.8 | Moderate‑high | Port modernisation + living‑shoreline buffer | **Protected** – flexible pier and habitat zones; fishery revenue projected +12 % |
# | **D. Central downtown (mid‑elevation, 3‑5 m) ** | 3‑5 | Low | Elevate key utilities (water, power) | **Protected** – utilities remain functional during surge |
# | **E. Suburban fringe (≥5 m)** | >5 | Negligible | No major action | **Monitor only** – low risk, no direct spend |
# | **F. Former “Old Dock” industrial zone (contaminated, 0‑0.4 m)** | 0‑0.4 | Very high | **Abandoned** – no buy‑out; site converted to open‑space floodplain (no residential use) | **Converted to green buffer** – reduces wave energy, improves ecosystem services |
#
# *Equity safeguard:* The relocation package for Bayview includes a **job‑training fund** ($30 M) and a **rent‑control guarantee** for the first 10 yr in the new district, ensuring the poorest 20 % are not financially worse off.
#
# ---
#
# ## 6.  Additional Financing Mechanisms (Beyond the $2 B Baseline)
#
# | Mechanism | Structure | Expected Yield (30 yr) | Use of Proceeds |
# |-----------|-----------|------------------------|-----------------|
# | **1. Green Municipal Bonds** | 30‑yr, tax‑exempt, rated “A‑”. Issued by the City, backed by future property‑tax increment from the Resilient Waterfront. | $300 M (≈$10 M/yr for O&M) | Funds Phase 2 barrier & Phase 3 waterfront |
# | **2. State/Federal Climate Adaptation Grants** | Competitive grant (e.g., FEMA Hazard Mitigation Grant Program, NOAA Climate Resilience Grants). | $150 M (non‑repayable) | Covers 30 % of living‑shoreline and early‑warning system |
# | **3. Public‑Private Partnerships (PPP) for Tourism Hub** | Long‑term lease‑back: private operator builds climate‑proof hotel, city receives 10 % of gross revenues for 20 yr. | $200 M equity from private sector (city contributes $20 M) | Enables Adaptive Tourism Hub with minimal upfront city outlay |
# | **4. Resilience Impact Fees on New Development** | $5 / ft² of new waterfront construction, collected for 20 yr. | ≈ $70 M | Dedicated to O&M of storm‑surge barrier |
# | **5. Insurance‑linked Securities (Cat‑Bonds)** | 10‑yr bond tied to storm‑surge index; triggers payout if >2 m surge occurs. | $50 M (contingent) | Provides emergency cash‑flow for rapid repairs |
#
# *Total “leveraged” additional resources ≈ **$770 M**, which can be reinvested to expand nature‑based solutions or increase the scale of managed retreat.*
#
# ---
#
# ## 7.  Governance & Community‑Engagement (Equity Lens)
#
# 1. **Resilience Office (RO)** – reports to the Mayor, chaired by the City Planner, with a statutory **Equity Advisory Council (EAC)** (5 elected community reps from poorest quintile, 2 NGOs, 2 academia).
# 2. **Participatory Budget Workshops** – every 5 yr, the RO presents a **“Resilience Budget Draft”**; residents vote on priority projects (non‑binding but informs final allocation).
# 3. **Transparent Data Portal** – open‑source GIS showing risk maps, project status, expenditures, and performance metrics (updated quarterly).
# 4. **Legal Safeguard** – any buy‑out contract must contain a “No‑Net‑Loss” clause: compensation ≥ market value + 20 % + relocation assistance.
# 5. **Capacity‑Building Grants** – $15 M over 30 yr earmarked for local NGOs to run climate‑literacy programs in schools and community centres, targeting low‑income neighbourhoods.
#
# ---
#
# ## 8.  Success Metrics & Monitoring Plan
#
# | Metric (target) | Baseline (2025) | Target (2050) | Measurement Frequency | Data Source |
# |-----------------|-----------------|---------------|-----------------------|-------------|
# | **Annual Expected Flood Damage** | $200 M | **<$30 M** (≈85 % reduction) | Yearly post‑event | City Insurance & FEMA claims |
# | **Number of households in poorest 20 % in flood‑prone zone** | 7 500 | **≤1 000** (≥86 % relocated/protected) | Annual census | City

# %% [markdown]
# ## For the next cell, we will use Ollama
#
# Ollama runs a local web service that gives an OpenAI compatible endpoint,
# and runs models locally using high performance C++ code.
#
# If you don't have Ollama, install it here by visiting https://ollama.com then pressing Download and following the instructions.
#
# After it's installed, you should be able to visit here: http://localhost:11434 and see the message "Ollama is running"
#
# You might need to restart Cursor (and maybe reboot). Then open a Terminal (control+\`) and run `ollama serve`
#
# Useful Ollama commands (run these in the terminal, or with an exclamation mark in this notebook):
#
# `ollama pull <model_name>` downloads a model locally
# `ollama ls` lists all the models you've downloaded
# `ollama rm <model_name>` deletes the specified model from your downloads

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/stop.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#ff7800;">Super important - ignore me at your peril!</h2>
#             <span style="color:#ff7800;">The model called <b>llama3.3</b> is FAR too large for home computers - it's not intended for personal computing and will consume all your resources! Stick with the nicely sized <b>llama3.2</b> or <b>llama3.2:1b</b> and if you want larger, try llama3.1 or smaller variants of Qwen, Gemma, Phi or DeepSeek. See the <A href="https://ollama.com/models">the Ollama models page</a> for a full list of models and sizes.
#             </span>
#         </td>
#     </tr>
# </table>

# %%
# !ollama pull llama3.2

# %%
ollama = OpenAI(base_url='http://localhost:11434/v1', api_key='ollama')
model_name = "llama3.2"

response = ollama.chat.completions.create(model=model_name, messages=messages)
answer = response.choices[0].message.content

display(Markdown(answer))
competitors.append(model_name)
answers.append(answer)
# Out:
# **Adaptation Plan**
#
# The proposed 30-year adaptation plan allocates the $2.0B budget across six concrete interventions, prioritizing those with the highest expected benefits and lowest costs.
#
# 1. **Sea Wall and Pump Replacement** (Year 1-5, $400M)
# Expected economic benefit: Reduce flood damage by 80% ($60M/year), increase property values by 25%
# Social benefit: Enhance quality of life, reduce displacement of vulnerable residents
# Environmental benefit: Protect infrastructure, preserve ecological habitats
# Costs estimated using a 4m/s flood velocity and storm surge frequency data; assuming an economic damages function, with higher expected benefits at lower cost thresholds (γ = 2.5).
#
# Phase-by-Phase Allocation:
# Year 1 - $40M for sea wall design and permitting
# Year 2 - $40M for pump installation
# Year 3 - $50M for sea level rise data analysis and policy development
# Year 4 - $75M for sea wall construction
# Year 5 - $55M for punch list items (accessibility, erosion control)
#
# Benefit-Cost Ratio: Estimated 3.9
#
# 2. **Erosion Mitigation in High-Risk Areas** (Year 5-10, $150M)
# Expected social benefit: Preserve low-income and elderly neighborhoods ($30M/year), reduce displacement risk
# Environmental benefits: Protect ecological habitats and infrastructure
#
# Benefit-Cost Ratio: Estimated 4.3
#
# Phase-by-Phase Allocation:
# Year 5 - $15M for site assessments and planning
# Year 6 - $20M for erosion control measures (vegetation, seawalls)
# Year 7 - $30M for construction of beach nourishment project
# Year 8 - $25M for restoration of habitats
# Year 9 - $20M for monitoring and maintenance
# Year 10 - $20M for community engagement and outreach
#
# 3. **Resilient Buildings and Infrastructure** (Year 5-15, $800M)
# Expected economic benefit: Reduce business interruption costs by 70% ($125M/year), increase property values by 15%
# Social benefit: Enhance quality of life, reduce displacement risk
# Environmental benefits: Protect infrastructure and ecological habitats
#
# Benefit-Cost Ratio: Estimated 3.9
#
# Phase-by-Phase Allocation:
# Year 5 - $50M for building codes update and training
# Year 6 - $80M for foundation reinforcement ( foundations, piers)
# Year 7 - $100M for elevated walkways and boardwalks
# Year 8 - $120M for seawall support structures
# Year 9 - $75M for roof reinforcements
# Year 10-15 - $350M for ongoing maintenance and monitoring
#
# 4. **Ecological Restoration** (Year 5-20, $200M)
# Expected social benefit: Support ecosystem services, preserve biodiversity ($40M/year), reduce storm surges ($10M/year)
# Environmental benefits: Preserve ecological habitats, restore natural barriers to ocean waves
#
# Benefit-Cost Ratio: Estimated 3.6
#
# Phase-by-Phase Allocation:
# Year 5 - $10M for habitat monitoring and restoration planning
# Year 6-10 - $20M for wetland restoration
# Year 11-15 - $40M for mangrove enhancement projects
# Year 16-20 - $50M for larger-scale ecological restoration initiatives
#
# 5. **Cultural Heritage Preservation** (Year 5-25, $150M)
# Expected social benefit: Preserve community history and cultural identity ($30M/year), support local heritage industries
# Environmental benefits: Reduce disruption caused by urban planning
#
# Benefit-Cost Ratio: Estimated 3.9
#
# Phase-by-Phase Allocation:
# Year 5 - $12M for heritage analysis and planning
# Year 6-8 - $20M for historic building restorations
# Year 9-15 - $30M for community engagement and education initiatives
# Year 16-25 - $60M for ongoing preservation and management
#
# 6. **Climate-Resilient Water** (Year 10-30, $200M)
# Expected social benefit: Address water quality concerns ($40M/year), strengthen wastewater infrastructure
# Environmental benefits: Reduce aquatic pollution
#
# Benefit-Cost Ratio: Estimated 4.5
#
# Phase-by-Phase Allocation:
# Year 10 - $15M for climate-resilient sewer design and implementation
# Year 11-20 - $60M for upgrades to the city's water treatment plant
# Year 21-25 - $35M for rehabilitation of affected aquifers
#
# **Funding and Finance Mechanisms**
#
# To supplement the $2.0B budget, we propose:
#
# 1. **Grants and Public Partnerships**: Collaborate with state, federal, and NGO partners to leverage an additional $100M over 10 years.
# 2. **Green Bond Financing**: Issues a climate-resilient infrastructure bond ($500M) within the first five years of our plan, taking advantage of favorable funding structures and expected long-term returns.
# 3. **Insurance Premiums**: Develop and manage specialized insurance products and premiums ($200M), leveraging municipal expertise alongside private sector risk management best practices.
#
# **Governance and Community Engagement**
#
# The administration will ensure equitable participation through:
#
# 1. City-led stakeholder groups
# 2. Regular public forums and consultations
# 3. Training programs on climate change and planning processes for vulnerable communities
#
# To verify the effectiveness of our plan, we have established measurable objectives like (a) a reduction of 20% in damages due to flooding and erosion within three decades; (b) community satisfaction rates >60% regarding overall quality of life by end Year 15.
#
# **Sensitivity Analysis**
#
# If parameters change,
#
# 1. An increase or decrease in damage functions would adjust relative priority allocation among projects.
# 2. Changes in economic discount rate impact return on investment, adjusting the final benefit-cost ratios and resource distribution across all projects.
# 3. Estimated impacts on public confidence would lead prioritization of long-term community benefits
#
# **Three Important Risks/Risk Modes and Contingency Actions**
#
# 1. Underestimated sea level rise or storm surge severity: Implement monitoring stations for updated predictions; reassess project durations under increased timelines.
#
# 2. Unsatisfactory stakeholder consensus, hindering adaptation planning feasibility.
#
# 3. Failure to implement effective measures to address inequality among target groups—revisit planning processes with community feedback and re-critical review the project's benefits distribution assumptions

# %%
# So where are we?

print(competitors)
print(answers)
# Out:
# ['gpt-5-nano', 'claude-sonnet-4-5', 'gemini-2.5-flash', 'deepseek-chat', 'openai/gpt-oss-120b', 'llama3.2']
# ['Executive summary\n- Goal: Build a 30-year, equity-conscious, cost-effective adaptation plan for a medium coastal city (population ~350k) whose economy hinges on tourism and fisheries. Sea-level rise is projected to 1.0 m in 50 years; storm surge is expected to intensify. The city has a $2.0B budget for adaptation over 30 years, and policies must not worsen the poorest 20% of residents.\n- Core design: A phased package of hard protection, nature-based solutions, infrastructure upgrades, and voluntary relocation/buyout, prioritized by risk, economic value, and equity. The plan aims to reduce long-term economic losses from coastal hazards while preserving ecological services and cultural heritage.\n- Outcome (at a glance): Net present value (NPV) of benefits roughly matches the baseline budget, with substantial risk reduction in high-value zones and a path to long-term resilience that does not leave the poorest residents worse off. The plan includes governance, financing, and monitoring to ensure equity and transparency.\n- Confidence: Moderate-to-strong (about 72%). Reasonable assumptions and phased funding allow risk-managed implementation, but outcomes depend on financing stability, timely permitting, and community buy-in.\n\nA. Assumptions and data inputs (explicit)\n- Population and growth\n  - Current population: 350,000\n  - Baseline growth assumption: 0.60% per year (compound over 30 years) for planning purposes\n  - Sensitivity scenario: ±20% around growth rate\n- Sea-level rise and hazards\n  - SLR: 1.0 m rise projected over 50 years (approximate, regional variation acknowledged)\n  - Storm surge/frequency: Increases anticipated; higher surge heights during extreme events; risk concentrates in nearshore and low-lying zones\n- Valuation and damages\n  - Coastal-exposed asset value (coastal zone with high economic concentration): ~$16B\n  - Baseline annual hazard damage rate without adaptation: ~0.75% of coastal-exposed asset value in year 1, rising modestly with hazard intensification (roughly escalates over time with surge intensity and flood extent)\n  - Discount rate (real): 3% per year (used for PV calculations)\n- Economic structure and sectors\n  - Tourism and fisheries as primary sectors; damages affect hotels, ports/harbors, fishery facilities, boatyards, supply chains, and associated services\n- Equity and social values\n  - No program may reduce the material well-being or safety of the bottom 20% (poorest households)\n  - Protective plans include targeted housing assistance, relocation options, and affordable housing guarantees\n- Baseline governance and delivery\n  - 30-year horizon, with phased implementation and periodic evaluation\n  - Local cost of capital and permitting timelines assumed reasonable for a mid-sized city; delays risk higher costs or lower benefits\n\nNotes on data and calculations used\n- Present-value factor for 30 years at 3%: PV factor = [1 − (1.03)−30]/0.03 ≈ 19.6\n- Baseline EAD (present value) calculation example:\n  - Year 1 EAD = 0.75% × $16B ≈ $0.12B/year\n  - PV of 30-year annuity at 3%: $0.12B × 19.6 ≈ $2.35B\n  - This is a simplified illustration; we model gradual escalation with surges and other factors in the plan description.\n- Targeted reductions from interventions are estimated in PV terms (see intervention-specific numbers below)\n\nB. Priority 30-year adaptation plan (a) concrete interventions and (b) benefits/costs (numerical estimates where possible)\n\nOverarching design\n- Guiding principles: protect high-value economic assets and critical infrastructure; deploy nature-based solutions to preserve ecological services; ensure resilience of cultural heritage; implement voluntary, equitable relocation where needed; avoid worsening the poorest 20%; maintain and expand jobs in tourism and fisheries.\n- Total budget: $2.0B (nominal) over 30 years; plan uses phased spending and leverages other funds (see section D).\n\nPhase 1: Foundations, planning, and initial protectio ...

# %%
# It's nice to know how to use "zip"
for competitor, answer in zip(competitors, answers):
    print(f"Competitor: {competitor}\n\n{answer}")
# Out:
# Competitor: gpt-5-nano
#
# Executive summary
# - Goal: Build a 30-year, equity-conscious, cost-effective adaptation plan for a medium coastal city (population ~350k) whose economy hinges on tourism and fisheries. Sea-level rise is projected to 1.0 m in 50 years; storm surge is expected to intensify. The city has a $2.0B budget for adaptation over 30 years, and policies must not worsen the poorest 20% of residents.
# - Core design: A phased package of hard protection, nature-based solutions, infrastructure upgrades, and voluntary relocation/buyout, prioritized by risk, economic value, and equity. The plan aims to reduce long-term economic losses from coastal hazards while preserving ecological services and cultural heritage.
# - Outcome (at a glance): Net present value (NPV) of benefits roughly matches the baseline budget, with substantial risk reduction in high-value zones and a path to long-term resilience that does not leave the poorest residents worse off. The plan includes governance, financing, and monitoring to ensure equity and transparency.
# - Confidence: Moderate-to-strong (about 72%). Reasonable assumptions and phased funding allow risk-managed implementation, but outcomes depend on financing stability, timely permitting, and community buy-in.
#
# A. Assumptions and data inputs (explicit)
# - Population and growth
#   - Current population: 350,000
#   - Baseline growth assumption: 0.60% per year (compound over 30 years) for planning purposes
#   - Sensitivity scenario: ±20% around growth rate
# - Sea-level rise and hazards
#   - SLR: 1.0 m rise projected over 50 years (approximate, regional variation acknowledged)
#   - Storm surge/frequency: Increases anticipated; higher surge heights during extreme events; risk concentrates in nearshore and low-lying zones
# - Valuation and damages
#   - Coastal-exposed asset value (coastal zone with high economic concentration): ~$16B
#   - Baseline annual hazard damage rate without adaptation: ~0.75% of coastal-exposed asset value in year 1, rising modestly with hazard intensification (roughly escalates over time with surge intensity and flood extent)
#   - Discount rate (real): 3% per year (used for PV calculations)
# - Economic structure and sectors
#   - Tourism and fisheries as primary sectors; damages affect hotels, ports/harbors, fishery facilities, boatyards, supply chains, and associated services
# - Equity and social values
#   - No program may reduce the material well-being or safety of the bottom 20% (poorest households)
#   - Protective plans include targeted housing assistance, relocation options, and affordable housing guarantees
# - Baseline governance and delivery
#   - 30-year horizon, with phased implementation and periodic evaluation
#   - Local cost of capital and permitting timelines assumed reasonable for a mid-sized city; delays risk higher costs or lower benefits
#
# Notes on data and calculations used
# - Present-value factor for 30 years at 3%: PV factor = [1 − (1.03)−30]/0.03 ≈ 19.6
# - Baseline EAD (present value) calculation example:
#   - Year 1 EAD = 0.75% × $16B ≈ $0.12B/year
#   - PV of 30-year annuity at 3%: $0.12B × 19.6 ≈ $2.35B
#   - This is a simplified illustration; we model gradual escalation with surges and other factors in the plan description.
# - Targeted reductions from interventions are estimated in PV terms (see intervention-specific numbers below)
#
# B. Priority 30-year adaptation plan (a) concrete interventions and (b) benefits/costs (numerical estimates where possible)
#
# Overarching design
# - Guiding principles: protect high-value economic assets and critical infrastructure; deploy nature-based solutions to preserve ecological services; ensure resilience of cultural heritage; implement voluntary, equitable relocation where needed; avoid worsening the poorest 20%; maintain and expand jobs in tourism and fisheries.
# - Total budget: $2.0B (nominal) over 30 years; plan uses phased spending and leverages other funds (see section D).
#
# Phase 1: Foundations, planning, and initial protections (Years 1–5)
# Budget: ~$400M
#
# - Governance, planning, and equity oversight
#   - Establish Climate Adaptation Authority; stakeholder engagement; data portal; annual public reporting
#   - Cost: ~$60M
# - Early nature-based and nearshore protection (living shorelines, dune restoration, buffer habitats)
#   - Targeted nearshore living shorelines to reduce wave energy and restore habitats; initial dune restoration along select beaches
#   - Cost: ~$150M
# - Interim protection of critical public facilities
#   - Elevation and floodproofing of city hall, main fire/police facilities, and wastewater treatment plant
#   - Cost: ~$110M
# - Evacuation planning, early warning, and core resilience communications
#   - Advanced warning systems, signage, drills, and evacuation route strengthening
#   - Cost: ~$40M
# - Readiness for buyouts (planning and first-draw funding)
#   - Voluntary buyout readiness for highest-risk parcels; appraisal framework; community outreach
#   - Cost: ~$40M
# - Small-scale risk reduction at priority tourist/fishing zones (e.g., minor seawall segments, floodproofing of marina facilities)
#   - Cost: ~$40M
#
# Net rationale: This phase builds the governance backbone, tests nature-based approaches, protects essential services, and sets up voluntary relocation processes without displacing any households yet. It also begins reducing risk exposure in high-visibility areas.
#
# Phase 2: Core protective infrastructure and targeted relocation (Years 6–12)
# Budget: ~$900M
#
# - Seawalls and surge barriers in high-value districts
#   - Focus on downtown core, harborfront hotels, cruise/port interface, and primary fishing harbor
#   - Estimated cost: ~$520M
#   - Expected benefit: substantial reduction in EAD for top-value zones; protection of tourism economy and port operations
# - Expanded nature-based protections and living shorelines
#   - Complement hard defenses with restored wetlands and oyster reefs, improving flood attenuation and habitat
#   - Estimated cost: ~$120M
#   - Expected benefit: additional EAD reductions; ecological co-benefits
# - Elevation/retrofit of additional critical infrastructure
#   - Water treatment, power substation, hospital secondary facilities, harbor-related infrastructure
#   - Estimated cost: ~$60M
# - Voluntary relocation/buyout program (Phase 1 deployments)
#   - Target households in high-risk housing with low replacement costs; provide relocation assistance and affordable replacement housing
#   - Estimated cost: ~$120M
#   - Rationale: reduce exposure where protection costs are high or where social equity concerns are acute
# - Enhanced evacuation routes and critical-asset redundancy
#   - Additional gates, bridges, and redundancy for critical corridors; back-up power for evacuation centers
#   - Estimated cost: ~$80M
# - Monitoring, adaptive management, and governance strengthening
#   - KPIs, independent oversight, annual progress report, and community feedback mechanisms
#   - Estimated cost: ~$20M
#
# Rationale: Phase 2 focuses on protecting high-value economic zones (port/tourist core) while expanding nature-based solutions and pushing forward the voluntary relocation program in a targeted, equitable way. The goal is to lower risk in the most valuable economic districts and begin reducing exposure in low- to middle-income neighborhoods where buyouts are most feasible and socially acceptable.
#
# Phase 3: Expansion, long-term protection, and cultural heritage resilience (Years 13–30)
# Budget: ~$700M
#
# - Expansion of protective corridors and additional seawall segments as needed
#   - Extend protection to peri-urban and additional tourism/fisheries corridors with phased segments
#   - Estimated cost: ~$420M
# - Long-term relocation/abandonment planning (where voluntary buyouts are accepted or feasible)
#   - Complete buyouts for remaining high-risk parcels; ensure affordable housing alternatives
#   - Estimated cost: ~$100M
# - Cultural heritage preservation and climate-proofing of historic districts
#   - Implement climate-resilient restoration, floodproofing, and display of cultural assets with community engagement
#   - Estimated cost: ~$80M
# - Ecosystem restoration and restoration of degraded coastal habitats
#   - Restoration of mangroves, wetlands, and nearshore habitats to support ecological services
#   - Estimated cost: ~$40M
# - Monitoring, governance, and continuous improvement
#   - Long-term program evaluation, equity audits, and adaptive management
#   - Estimated cost: ~$60M
#
# Rationale: Phase 3 consolidates gains, expands protection to more neighborhoods and assets, and preserves cultural heritage and ecological services. It also completes voluntary relocation in a manner that protects the poorest and avoids forced resettlement.
#
# Total budget by phase (summed estimates)
# - Phase 1 (Years 1–5): ~$400M
# - Phase 2 (Years 6–12): ~$900M
# - Phase 3 (Years 13–30): ~$700M
# - Total: ~$2.0B
#
# C. Neighborhoods/assets protected, relocated, or abandoned (why)
#
# - Protected (high-value economic and critical-assets):
#   - Downtown core, harborfront, primary hotels, cruise-ship and tourism-related infrastructure, main fishing harbor, and hospital/water/wastewater facilities
#   - Rationale: these assets generate the bulk of current economic activity (tourism and fisheries) and provide essential services; their protection yields the highest near-term economic and societal payoff and reduces risk to the broader economy.
# - Relocated (voluntary buyouts for equity and risk reduction):
#   - High-risk residential blocks in low-to-moderate property-value zones immediately adjacent to the shoreline; lower-income neighborhoods with limited mobility options; parcels with feasible replacement housing options
#   - Rationale: reduce displacement risk for poorer households; ensure fair compensation and replacement housing; voluntary buyouts minimize social conflict and support equity objectives.
# - Abandoned (economic/ease-of-risk decisions)
#   - In cases where the cost of protection is drastically higher than the asset value, or when risk is unacceptable (e.g., single-structure properties with extremely high hazard profiles and no feasible relocation options)
#   - Rationale: avoid locking in unsustainable costs; where feasible, offer relocation or conversion to non-residential uses (e.g., parks, open space) rather than continued hazard exposure. This would be pursued only if voluntary options are exhausted and risk remains unacceptable after protection investments.
#
# D. Funding and financing mechanisms beyond the $2.0B baseline
# 1) Climate resilience bonds (green or blue bonds)
#    - Sell city-backed bonds specifically for adaptation projects; issue debt with proceeds restricted to resilience interventions
#    - Rationale: broad market access, longer tenors, potential favorable rates for green issuance; aligns with investor appetite for resilience assets
# 2) Public-private partnerships (P3) for port/tourism infrastructure and critical facilities
#    - Leverage private sector investment in uptime, resilience, and service delivery (e.g., seawall maintenance, floodproofing of private assets near the port, or flood-resilient hotel upgrades) with performance-based payments
#    - Rationale: attract capital and expertise; accelerate delivery; align incentives for long-term maintenance
# 3) Federal/state grants, and disaster risk reduction funds (BRIC/HMA equivalents)
#    - Seek competitive grants targeted at resilience, hazard mitigation, and coastal restoration; apply for federal/state resilience and climate-adaptation programs
#    - Rationale: non-debt funding that does not impact local taxes or debt capacity
# 4) Catastrophe bonds and parametric insurance instruments
#    - Weather-triggered securitizations to cover extreme-event losses; funds can be earmarked for rapid post-disaster resilience investments or early-stage protection
#    - Rationale: diversify risk financing; provide rapid liquidity after extreme events
# 5) Tax-increment financing (TIF) or special assessment districts for targeted districts
#    - Create districts where incremental value from investments funds resilience works in specific corridors (e.g., harbor area) while preserving equity safeguards
#    - Rationale: leverages future gains to finance current improvements, with transparency and governance safeguards
#
# E. Governance, equity, and community engagement (measures to ensure equity)
# - Equity-focused oversight
#   - Establish an independent Equity and Adaptation Commission that includes representatives from affected neighborhoods, fisheries, tourism associations, historians, and public health
#   - Annual public report on equity metrics (cost burdens, displacement risk, access to housing, and benefits distribution)
# - Participatory planning
#   - Regular community town halls in multiple languages; community-defined project briefings; participatory budgeting elements for small but meaningful allocations
# - Transparent data and procurement
#   - Public data portal with hazard maps, asset inventories, project schedules, procurement logs, and contract performance
# - Housing and social safeguards
#   - Require affordable housing guarantees for relocated households; ensure rent protections and anti-displacement policies; provide mobility services and retraining programs where necessary
# - Cultural heritage safeguards
#   - Involve local cultural groups to guide restoration and interpretation of heritage sites; ensure accessible, inclusive interpretation for residents and visitors
# - Grievance and redress mechanisms
#   - Independent ombudsman to handle complaints related to relocation, compensation, or implementation delays
#
# F. Measurable success metrics and monitoring strategies
# - Physical and structural metrics
#   - Percent of high-value assets protected or retrofitted for flood and surge resistance
#   - Number of critical facilities with floodproofing or elevation completed
#   - Distance of evacuation routes improved or expanded; number of safe shelters with backup power
# - Economic metrics
#   - Reduction in expected annual damages (EAD) from coastal hazards; PV of avoided damages over 30 years
#   - Preservation or growth of tourism revenue and port activity in adaptation zones compared to baseline
#   - Reduced downtime for fisheries infrastructure during extreme events
# - Social equity metrics
#   - Share of benefits allocated to the bottom 40% and bottom 20% (poverty-weighted distribution)
#   - Number of households in lowest-income quintile aided by relocation/affordable housing guarantees
# - Environmental metrics
#   - Habitat restoration progress (wetlands, mangroves, reefs)
#   - Water quality and sediment transport indicators in nearshore zones
# - Governance and process metrics
#   - Transparency score (public dashboards updated quarterly)
#   - Community satisfaction and participation rates in engagement activities
# - Monitoring plan
#   - Annual reporting by the Climate Adaptation Authority
#   - Independent mid-term review at year 10; third-party evaluations at years 20 and 30
#   - Real-time dashboards for hazard events, system uptime, and shelter availability
#
# G. Explicit assumptions and data inputs used (catalog)
# - Population: 350k now; 0.60% annual growth assumed for planning (±20% sensitivity)
# - Discount rate: 3% real
# - Hazard exposure: coastal-exposed asset value ≈ $16B; baseline annual damage rate ≈ 0.75% of exposed value (year 1), escalating modestly with hazard intensification
# - SLR: +1.0 m by year 50 (50 years)
# - Storm surge: increasing frequency and intensity; nearshore protection needs
# - Economic structure: tourism and fisheries provide the majority of regional GDP and employment; disruption has multiplier effects
# - Equity constraint: poorest 20% must not be worse off; relocation/housing assistance programs included to ensure equity
# - Capital availability: baseline $2.0B funding is available; additional mechanisms will be used to bridge gaps
# - Construction and permitting timelines: phased schedule assumed feasible within local regulatory constraints and financing
# - Environmental co-benefits: habitat restoration improves ecology and resilience; certain interventions have spillover benefits (recreation, biodiversity)
#
# H. Sensitivity analysis (±20% on three key parameters)
# Method: Recompute a simplified PV of EAD with and without interventions, focusing on the core three levers below. Compare the net PV (benefits − costs) and rank changes among the major interventions.
#
# Parameters varied by ±20%:
# - Discount rate (real)
#   - Baseline: 3.0% → low: 2.4% high: 3.6%
# - Baseline hazard growth (EAD growth rate due to climate and hazard escalation)
#   - Baseline annual EAD growth: 0% escalation for simplicity in PV calculation (illustrative). Alternative: +0.5%/yr and +1.0%/yr escalations (compounding hazard escalation)
# - Population growth
#   - Baseline 0.60%/yr → low: 0.48%/yr; high: 0.72%/yr
#
# Illustrative numbers (order-of-magnitude; for the sake of comparison only)
# - PV of baseline EAD without adaptation (years 1–30, 3% discount)
#   - Baseline hazard growth 0%: ≈ $2.35B (as shown in the assumptions section)
#   - With +0.5% annual escalation: ≈ $2.72B
#   - With +1.0% annual escalation: ≈ $3.25B
# - PV of adaptation benefits (present value of avoided damages) for core interventions
#   - Seawalls +port protection (Phase 2): baseline PV avoided ≈ ($1.30–$1.60)B
#   - Nature-based solutions (Phase 1–2): baseline PV avoided ≈ ($0.45–$0.60)B
#   - Infrastructure elevation and floodproofing: baseline PV avoided ≈ ($0.25–$0.35)B
#   - Voluntary relocation/buyouts: baseline PV avoided ≈ ($0.15–$0.25)B
# - Net PV (PV benefits − PV costs)
#   - Baseline (discount 3%, hazard growth 0%, population growth 0.60%): Net PV ≈ +$0.25B to +$0.50B (positive)
#   - Lower discount rate (2.4%): Net PV increases by ~+15% to +25% for core components
#   - Higher hazard growth (+0.5% or +1.0%): Net PV decreases by ~10%–25%, depending on the phase
#   - Higher population growth (+0.72%): Increases exposure, but also increases benefits of protection; net PV may shift modestly upward if benefits scale with population
# Interpretation:
# - The ranking of interventions (hard protection first, then nature-based, then relocation) remains generally robust under ±20% variations in discount rate, hazard escalation, and population growth, though the magnitude of PV benefits shifts.
# - If discount rate falls, PV benefits rise; if hazards escalate quickly, costs are higher and urgent protection of high-value assets is more compelling.
#
# I. Risks, failure modes, and contingency actions (three per key risk)
#
# 1) Financing risk
# - Risk: Insufficient or delayed funding to complete planned phases; market conditions raise borrowing costs.
# - Contingencies:
#   - Front-load low-cost, high-ambiguity elements (governance, initial nature-based works) to maintain momentum
#   - Activate alternate financing (catalyze green bonds or cat bonds; apply for BRIC/HMA grants; pursue P3 structures)
#   - Phase gate decisions with clear triggers to release further funds; maintain reserve lines
#
# 2) Equity and community legitimacy risk
# - Risk: Plans that improve infrastructure but worsen or fail to protect the poorest; loss of trust and participation
# - Contingencies:
#   - Strengthen targeted protections and relocation guarantees; ensure affordable housing and relocation assistance
#   - Create an independent equity advisory panel with legal oversight and transparent metrics
#   - Maintain a robust grievance mechanism; adjust program scope based on feedback
#
# 3) Technical and permitting risk
# - Risk: Technical failures or delays (e.g., structural seawalls not performing as expected; environmental permitting delays)
# - Contingencies:
#   - Use modular, testable components; pilot segments with adaptive management
#   - Employ independent design reviews and third-party verification; maintain contingency budgets for redesigns
#   - Build redundancy (alternative evacuation routes, backup power) and non-structural measures (early warning, land-use planning)
#
# 4) Governance and political risk
# - Risk: Changes in leadership or policy priorities threaten long-term plan continuity
# - Contingencies:
#   - Enshrine plan in a formal city policy framework; secure multi-party support and charter formalities
#   - Establish durable governance bodies with long-term terms and rotating leadership
#   - Regular public reporting and citizen oversight to sustain legitimacy
#
# 5) Environmental and ecological risk
# - Risk: Unintended ecological impacts from interventions; habitat degradation
# - Contingencies:
#   - Implement adaptive management with ecological monitoring; adjust projects if biodiversity signals decline
#   - Prioritize nature-based solutions where possible to maximize co-benefits
#   - Require environmental impact assessments and post-implementation auditing
#
# J. Three falsifiable pieces of evidence that would lead to abandoning the plan (within 10 years)
# 1) Material failure to reduceEAD or to protect key economic zones
#   - If, after a 5–10 year window, the PV of avoided damages is below 50% of projected baseline damages and high-value districts experience repeated multi-hazard losses, re-evaluate the cost-effectiveness of the protection strategy or pivot to alternative approaches.
# 2) Worsening inequities among the bottom 20%
#   - If equity metrics show that the bottom quintile’s safety, housing affordability, or access to essential services deteriorate despite program implementation (e.g., net losses in living standards, rising displacement burden), stop the current buyout/relocation approach and redesign with stronger social protections, housing subsidies, and inclusive economic supports.
# 3) Infeasibility or insolvency of financing mechanisms
#   - If critical funding channels (bonds, grants, cat bonds, or P3 pipelines) fail to materialize or become prohibitively costly, and the city cannot sustain the 30-year plan without compromising essential services or equity commitments, pause and renegotiate the program design, focusing on non-debt financing, grant-expedited projects, and a narrower scope.
#
# K. Simple calculations illustrating core logic (selected calculations shown)
# - PV factor for 30 years at 3%: 19.6
# - Baseline EAD example (illustrative)
#   - Year 1 EAD ≈ 0.75% × $16B = $120M
#   - PV of 30-year annuity: $120M × 19.6 ≈ $2.35B
# - Intervention PV (illustrative ranges)
#   - Seawalls/port protection PV avoided: ~$1.30–$1.60B
#   - Nature-based solutions PV avoided: ~$0.45–$0.60B
#   - Infrastructure floodproofing PV avoided: ~$0.25–$0.35B
#   - Relocation/buyouts PV avoided: ~$0.15–$0.25B
#   - Total PV avoided: ~ $2.15–$2.75B
# - Net PV (illustrative)
#   - Baseline PV damages: ~$2.35B
#   - PV avoided by plan: ~ $2.15–$2.75B
#   - Net PV range: approx −$0.20B to +$0.40B (with a sensitivity leaning toward positive when benefits are on the higher end)
# - Budget alignment
#   - Program cost: $2.0B nominal
#   - PV-equivalent cost (3%): ~$1.8B
#   - Net PV: relative advantage within a narrow band near break-even, but with substantial tail benefits in avoided damages and ecological/cultural gains
#
# L. Overall confidence in achieving goals (0–100%)
# - Confidence estimate: 72%
# - Justification: The proposed plan is phased, equity-focused, and leverages multiple financing avenues, which improves feasibility. The expected benefits in high-value economic zones are substantial, and nature-based solutions add co-benefits and cost-effectiveness. However, confidence is constrained by:
#   - Financing risks (the need to mobilize additional funds beyond the baseline)
#   - Potential delays in permitting and implementation
#   - The necessity of robust community engagement to avoid inequitable outcomes
#   - The reliance on behavioral responses (voluntary relocation) and the political will to maintain continuity over 30 years
# - The plan remains viable if financing channels are efficiently activated, equity safeguards are rigorously implemented, and governance structures are stable. If these do not materialize, confidence would decrease accordingly.
#
# Bottom line
# - A phased, equity-forward mix of hard protection, nature-based solutions, infrastructure upgrades, and voluntary relocation can meet the city’s goals of reducing long-term losses, protecting ecological and cultural assets, and avoiding harm to the poorest residents, within the $2.0B baseline and leveraging additional financing. Ongoing governance, transparent monitoring, and strong community engagement are essential to realize the plan’s objectives and adjust to evolving hazards and economic conditions. A transparent, adaptive approach maximizes the probability of achieving long-term resilience while keeping the poorest residents safe and economically secure.
# Competitor: claude-sonnet-4-5
#
# # 30-Year Coastal Adaptation Plan for Mid-Sized Coastal City
#
# ## EXECUTIVE SUMMARY
# This plan allocates $2.0B across hybrid grey-green infrastructure, strategic retreat, and social resilience programs. The strategy protects the downtown core and working waterfront while facilitating managed relocation from high-risk areas, prioritizing the most vulnerable populations.
#
# ---
#
# ## PART A: BUDGET ALLOCATION & INTERVENTION TIMELINE
#
# ### Phase 1: Years 1-10 (Foundation & Protection) - $850M
#
# **1. Critical Infrastructure Hardening - $280M**
# - Elevate water/sewage treatment plants (+2.5m): $120M
# - Relocate emergency services & critical facilities: $90M
# - Upgrade stormwater drainage system: $70M
#
# **2. Hybrid Coastal Defense (Downtown & Port) - $320M**
# - Living seawall with oyster reefs (4 km): $180M
# - Beach nourishment + dune restoration (6 km): $85M
# - Tidal gate system at harbor entrance: $55M
#
# **3. Early Warning & Monitoring Infrastructure - $35M**
# - Real-time flood sensor network: $15M
# - Storm surge prediction system: $12M
# - Community alert infrastructure: $8M
#
# **4. Equity-Focused Relocation Preparation - $155M**
# - Purchase 450 properties in highest-risk zones: $110M
# - Establish relocation trust fund: $30M
# - Community planning & social services: $15M
#
# **5. Nature-Based Solutions (Ecological Buffer) - $60M**
# - Restore 200 hectares coastal wetlands: $40M
# - Create 50 hectares upland buffer forest: $20M
#
# ### Phase 2: Years 11-20 (Transformation & Adaptation) - $780M
#
# **6. Strategic Managed Retreat - $380M**
# - Acquire additional 650 properties: $240M
# - Buyout compensation (above market for poorest 20%): $85M
# - Infrastructure decommissioning: $35M
# - New affordable housing in safe zones: $20M
#
# **7. Enhanced Coastal Defense (Selective) - $210M**
# - Multi-layer protection for cultural heritage district: $95M
# - Working waterfront adaptation (floating docks, elevated facilities): $80M
# - Green infrastructure expansion (urban wetlands, bioswales): $35M
#
# **8. Economic Transition Support - $115M**
# - Fisheries adaptation (climate-resilient aquaculture): $50M
# - Tourism infrastructure relocation/upgrade: $40M
# - Workforce retraining programs: $25M
#
# **9. Social Infrastructure & Resilience Hubs - $75M**
# - Five community resilience centers (cooling, emergency shelter): $50M
# - Subsidized flood insurance pool: $25M
#
# ### Phase 3: Years 21-30 (Consolidation & Maintenance) - $370M
#
# **10. Ongoing Maintenance & Adaptive Management - $180M**
# - Infrastructure upkeep (6M/year × 30 years): $180M
#
# **11. Second-Generation Interventions - $120M**
# - Technology upgrades and replacements: $70M
# - Additional nature-based solutions: $50M
#
# **12. Contingency Reserve - $70M**
# - For accelerated sea-level rise or major storm damage
#
# ---
#
# ## PART B: COST-BENEFIT ANALYSIS
#
# ### Economic Benefits (Present Value, 3% discount rate, 50-year horizon)
#
# **Avoided Damages:**
# - Protected property value: ~$4.2B (12,000 structures × $350K average)
# - Avoided annual flood losses: $85M/year → PV ≈ $2.1B
# - Maintained tourism revenue: $180M/year × 30% at risk → PV ≈ $1.4B
# - Fisheries infrastructure protection: PV ≈ $420M
# - **Total avoided economic losses: ~$8.1B**
#
# **Direct Economic Returns:**
# - Green infrastructure ecosystem services: $8M/year → PV ≈ $200M
# - Enhanced property values in protected zones (+12%): PV ≈ $380M
# - Tourism resilience premium: PV ≈
# Competitor: gemini-2.5-flash
#
# As an independent policy advisor, I have developed a comprehensive 30-year climate adaptation plan for your city. This plan prioritizes resilience, equity, and sustainable growth, aiming to minimize long-term economic losses while safeguarding your unique ecological and cultural heritage.
#
# ## Executive Summary
#
# This 30-year adaptation plan, budgeted at $2.0 billion, is designed to protect your mid-sized coastal city (population 350,000) from an anticipated 1.0 m sea-level rise and increased storm surge frequency/intensity over the next 50 years. The plan adopts a phased approach, combining nature-based solutions, targeted hard defenses, strategic infrastructure upgrades, and managed retreat, all underpinned by robust community engagement and a commitment to social equity. It aims to prevent an estimated $7-8 billion in economic losses, while preserving critical ecological services and cultural sites. The plan includes innovative funding mechanisms, strong governance, and clear monitoring strategies to ensure its success and adaptability.
#
# ## I. Assumptions and Data Inputs
#
# To develop this plan, the following explicit assumptions and data inputs were used:
#
# *   **Current City Population:** 350,000.
# *   **Population Growth Rate:** Assumed a modest 0.5% annual growth, leading to ~390,000 by year 30. This impacts future asset values and population at risk.
# *   **Sea-Level Rise (SLR):**
#     *   **Long-term Projection:** 1.0 meter over 50 years.
#     *   **30-Year Projection (for planning):** Assumed a linear rise, so (1.0 m / 50 years) * 30 years = **0.6 meters by year 30**. However, critical infrastructure interventions are designed with the full 1.0m (plus contingency) in mind due to their long lifespans.
# *   **Storm Surge Frequency & Intensity:** Assume a significant increase, where a current 1-in-100 year event effectively becomes a 1-in-50 year event, and typical storm surge heights increase by an additional **0.5 meters** during major events (on top of SLR).
# *   **Vulnerable Areas:** Estimated **20% of the city's land area** and associated assets (residential, commercial, infrastructure) are highly vulnerable to 0.6m SLR + surge, increasing to 25-30% with 1.0m SLR + surge.
# *   **Economic Structure:** Highly dependent on Tourism and Fisheries. Adaptation measures must support these sectors.
# *   **Property Values (Averages for Estimation):**
#     *   Residential Unit: $400,000
#     *   Commercial Establishment: $1,000,000
#     *   Public Infrastructure (per linear km for roads/utilities in vulnerable areas): $5,000,000
# *   **Total Asset Value at Risk (without adaptation):** Estimated cumulative potential economic damages over 30 years from chronic inundation and increased storm events (e.g., property damage, business interruption, infrastructure repair, environmental degradation) to be approximately **$10 billion**. This represents roughly 15-20% of the total estimated private and public asset value within the vulnerable zone (approx. 30,000 housing units, 1,000 commercial, 100km infrastructure).
# *   **Discount Rate:** Used **4%** for present value calculations, balancing short-term costs with long-term benefits.
# *   **Social Equity Constraint:** The poorest 20% of the population (approx. 70,000 individuals currently) **must not be made worse off**. This mandates targeted support for relocation, job training, and equitable access to protected areas.
# *   **Ecological Services & Cultural Heritage:** These are non-negotiable values requiring protection or appropriate mitigation/relocation.
# *   **Intervention Cost Estimates (Order of Magnitude):**
#     *   Nature-Based Solutions (NBS) (wetland/dune restoration): $5-15 million per km
#     *   Hard Defenses (seawalls, dikes): $15-25 million per km
#     *   Building Elevation/Flood-proofing: $100,000 - $200,000 per structure
#     *   Managed Retreat (property acquisition & relocation): $400,000 - $600,000 per household (includes property value, moving, social support).
# *   **Budget Allocation:** The available $2.0 billion over 30 years, implying an average annual spend of ~$67 million.
#
# ## II. Prioritized 30-Year Adaptation Plan
#
# The plan is structured into three phases, each building on the previous, with an emphasis on "no-regrets" actions and flexibility. The overall goal is to prevent approximately **$7-8 billion in cumulative economic losses** over 30 years, yielding an estimated Benefit-Cost Ratio (BCR) of 3.5:1 to 4:1 for the $2.0 billion investment.
#
# ### Phase 1: Planning, Nature-Based Solutions & Capacity Building (Years 1-10)
# *   **Budget Allocation:** $500 million
# *   **SLR by End of Phase:** ~0.2 m
#
# | Intervention | Description | Budget (Million) | Expected Benefits (30-yr cumulative) | Costs (30-yr cumulative) | Protected/Relocated/Abandoned & Why |
# | :---------- | :---------- | :--------------- | :---------------------------------- | :---------------------------- | :----------------------------------- |
# | **1. Comprehensive Vulnerability Assessment & Master Plan Integration** | Update zoning, building codes; detailed flood mapping; SLR scenarios. | $50 | Informed decision-making, reduced future maladaptation. Avoided **$500M** in misallocated funds. | Admin costs. | All areas - informs future actions. |
# | **2. Nature-Based Coastal Protection** | Restore/expand 25 km of wetlands & mangrove forests (estuaries, vulnerable coastlines); build 15 km of resilient dune systems. | $250 ($6.25M/km avg) | **Ecological:** Enhanced fisheries habitat, improved water quality, increased biodiversity. **Economic:** Natural storm buffer (avoided damages up to **$1.5B** in vulnerable low-lying commercial/residential areas near estuaries), boosted eco-tourism, carbon sequestration. **Social:** Recreational areas. | Land acquisition, planting, monitoring. | **Protected:** Key ecological zones, adjacent low-lying residential areas (e.g., "South Bay Wetlands"), some fishing communities. |
# | **3. Early Warning Systems & Evacuation Infrastructure** | Upgrade sensors, communication networks, reinforce evacuation routes and shelters. | $50 | **Social:** Reduced loss of life, safer evacuations. **Economic:** Reduced emergency response costs (avoided **$100M**), minimized business interruption. | Hardware, training, infrastructure. | All residents, particularly vulnerable communities. |
# | **4. Building Code Update & Pilot Flood-Proofing Program** | Mandatory new construction standards (elevation, flood-proofing). Pilot program for existing homes in moderate risk zones (500 homes). | $100 | **Economic:** Reduced property damage for new construction & participating homes (avoided **$200M** for pilot). **Social:** Increased homeowner resilience. | Admin, subsidies for pilot. | Select neighborhoods at moderate risk, future developments. |
# | **5. Cultural Heritage & Equity Preservation** | Inventory vulnerable sites; develop rapid relocation/documentation plans for key movable assets. Establish community engagement hubs. | $50 | **Cultural:** Safeguarding identity. **Social:** Inclusive planning, ensuring poorest 20% are engaged and informed. | Surveys, planning, initial engagement. | Specific historic districts (e.g., "Old Quarter"), vulnerable community assets. |
#
# ### Phase 2: Hardening Critical Assets & Strategic Retreat (Years 11-20)
# *   **Budget Allocation:** $800 million
# *   **SLR by End of Phase:** ~0.4 m
#
# | Intervention | Description | Budget (Million) | Expected Benefits (30-yr cumulative) | Costs (30-yr cumulative) | Protected/Relocated/Abandoned & Why |
# | :---------- | :---------- | :--------------- | :---------------------------------- | :---------------------------- | :----------------------------------- |
# | **1. Targeted Hard Defenses** | Construct/elevate 20 km of seawalls/dikes around the CBD, port, and key tourist zones. Incorporate floodgates. | $400 ($20M/km avg) | **Economic:** Direct protection of high-value commercial, tourism assets, and critical port infrastructure (avoided **$3.0B** in damages). Ensures business continuity. | Construction, maintenance. | **Protected:** Central Business District, Main Port Facilities, Premier Tourist Resorts. |
# | **2. Resilient Infrastructure Network** | Elevate and flood-proof critical utilities (substations, water treatment plants, communication hubs). Redundant systems. | $100 | **Economic:** Prevents cascading failures, maintains essential services (avoided **$500M** in economic disruption and repair). **Social:** Ensures public health and safety. | Engineering, construction. | All city infrastructure, supporting all residents. |
# | **3. Managed Retreat Program - Phase 1** | Acquire ~1,000 highly vulnerable low-income properties in designated flood zones (e.g., "Fisherman's Landing" and parts of "Old Town"). Provide comprehensive relocation assistance, job training, and new housing options (uphill, equitable). | $350 ($350k/household avg) | **Economic:** Avoided long-term protection costs for unviable areas (avoided **$700M** in property damages). **Social:** Enhanced safety, improved living conditions for vulnerable populations, upholding equity constraint. | Property acquisition, relocation services, social support. | **Relocated:** "Fisherman's Landing" (high flood risk, critical infrastructure in area to be relocated/elevated), parts of "Old Town" (historically significant but severely low-lying, with low-income residents). **Abandoned:** The vacated land will be converted into green space/tidal wetlands to provide further natural protection. |
# | **4. Cultural Heritage - Relocation/Documentation** | Begin physical relocation of selected smaller, movable cultural heritage assets; comprehensive digital documentation of immovable sites. | $50 | **Cultural:** Preservation of heritage. | Relocation, digital archiving. | Specific cultural heritage sites identified as unprotectable in situ. |
#
# ### Phase 3: Long-Term Resilience, Economic Diversification & Adaptive Management (Years 21-30)
# *   **Budget Allocation:** $700 million
# *   **SLR by End of Phase:** ~0.6 m
#
# | Intervention | Description | Budget (Million) | Expected Benefits (30-yr cumulative) | Costs (30-yr cumulative) | Protected/Relocated/Abandoned & Why |
# | :---------- | :---------- | :--------------- | :---------------------------------- | :---------------------------- | :----------------------------------- |
# | **1. Expansion of Multi-layered Defenses** | Further strengthen and extend 10 km of existing hard and nature-based defenses, based on updated SLR projections. | $300 ($15M/km avg) | **Economic:** Continued protection of critical assets, adapting to evolving threats (avoided **$1.5B** in damages post-Year 20). | Construction, maintenance. | Extended protection for key areas, new buffer zones. |
# | **2. Managed Retreat Program - Phase 2** | Acquire ~500 more properties in newly vulnerable or economically unviable areas; continue relocation and support programs. | $250 ($500k/household avg) | **Economic:** Avoided future protection costs (avoided **$350M**). **Social:** Prevents future displacement crises, ensures equity. | Property acquisition, relocation, new housing. | **Relocated:** Additional highly vulnerable residential areas (e.g., some waterfront homes), small commercial properties in newly identified risk zones. **Abandoned:** Converted to green infrastructure or nature preserves. |
# | **3. Economic Diversification & Green Jobs** | Invest in training programs for new 'blue economy' jobs (e.g., aquaculture, marine renewable energy, resilience consulting) for those affected by fisheries/tourism shifts. | $50 | **Economic:** Reduced reliance on vulnerable sectors, new growth opportunities. **Social:** Job security, reduced unemployment, enhances social equity. | Training programs, seed funding. | All residents, especially those affected by coastal changes. |
# | **4. Adaptive Governance & Monitoring Endowment** | Establish an endowment for ongoing monitoring, research, and adaptive management. Fund a permanent Climate Resilience Office. | $100 | **Operational:** Ensures long-term sustainability and flexibility of the plan. Continuous learning. | Endowment investment, staffing. | All aspects of the plan. |
#
# **Summary of Avoided Damages (Cumulative over 30 years):**
# *   Nature-Based Solutions: ~$1.5 Billion
# *   Pilot Flood-Proofing: ~$0.2 Billion
# *   Targeted Hard Defenses: ~$3.0 Billion
# *   Resilient Infrastructure: ~$0.5 Billion
# *   Managed Retreat: ~$1.05 Billion ($700M + $350M)
# *   Expansion of Defenses: ~$1.5 Billion
# *   **Total Estimated Avoided Damages:** ~$7.75 Billion (against a $2.0B investment)
#
# ## III. Funding and Finance Mechanisms (Beyond the $2.0B Baseline)
#
# The $2.0 billion budget is a strong start, but climate adaptation is an ongoing challenge. Here are three additional mechanisms to secure long-term funding:
#
# 1.  **Municipal Green Bonds:** The city could issue "Coastal Resilience Bonds" to attract socially responsible investors. These bonds would specifically fund eligible adaptation projects (e.g., nature-based solutions, resilient infrastructure).
#     *   **Mechanism:** Bonds are issued by the city, purchased by investors, and principal/interest repaid from general city revenues or dedicated fees.
#     *   **Potential:** Could raise an additional $500 million to $1 billion over the next 30 years, depending on market conditions and city credit rating.
#     *   **Benefit:** Diversifies funding, taps into a growing market for green investments, and signals the city's commitment to sustainability.
#
# 2.  **Tourism & Resilience Levy:** Implement a small, dedicated levy on tourism-related services (e.g., 1-2% on hotel stays, short-term rentals, or major attraction tickets).
#     *   **Mechanism:** Collected by businesses and remitted to a dedicated "Coastal Resilience Fund."
#     *   **Potential:** Given the city's tourism-dependent economy, this could generate $10-20 million annually (assuming $1 billion annual tourism revenue), accumulating to $300-600 million over 30 years.
#     *   **Benefit:** Directly links the industry benefiting from coastal attractions to their preservation. Tourists often accept small surcharges for environmental causes.
#
# 3.  **Public-Private Partnerships (PPPs) & Federal/State Grant Pursuit:** Actively pursue co-funding and partnerships for large-scale projects.
#     *   **Mechanism:**
#         *   **PPPs:** For projects benefiting specific private entities (e.g., port upgrades, beachfront resort protection), private developers or businesses contribute to project costs in exchange for long-term operational benefits or preferential leases.
#         *   **Federal/State Grants:** Dedicated grants for coastal resilience, infrastructure, wetland restoration, and community development.
#     *   **Potential:** Highly variable, but successful grant applications and PPPs could unlock hundreds of millions of dollars (e.g., $100-300 million over 30 years).
#     *   **Benefit:** Leverages external capital and expertise, reduces direct city burden, and ensures alignment with national/state resilience goals.
#
# ## IV. Governance and Community-Engagement Measures
#
# Ensuring equity and effectiveness requires robust governance and continuous community involvement:
#
# *   **1. City Resilience Office (CRO):** Establish a dedicated office with a Chief Resilience Officer reporting directly to the Mayor. This office will be responsible for plan implementation, inter-departmental coordination, external partnerships, and monitoring.
# *   **2. Multi-Stakeholder Resilience Task Force:** Create an oversight body comprising city officials, scientists, business leaders (tourism, fisheries), environmental NGOs, community representatives (including representatives from vulnerable groups), and cultural heritage experts. This task force will provide strategic guidance and ensure broad buy-in.
# *   **3. Neighborhood Resilience Hubs & Advisory Boards:** For areas most affected by proposed interventions (e.g., managed retreat zones, areas receiving new defenses), establish local hubs and dedicated advisory boards. These will serve as direct channels for feedback, co-design of solutions, and grievance resolution, ensuring the "poorest 20% not worse off" clause is upheld.
# *   **4. Dedicated Equity & Relocation Ombudsman:** An independent ombudsman will oversee the managed retreat and social support programs, ensuring fair compensation, equitable relocation options, and access to resources for affected households, particularly the poorest 20%.
# *   **5. Transparent Communication & Accessible Data:** Implement a public-facing dashboard showing project progress, spending, and monitoring data. Regular town halls, workshops, and accessible informational materials (multi-lingual) will foster trust and informed participation.
#
# ## V. Measurable Success Metrics and Monitoring Strategies
#
# **Measurable Success Metrics:**
#
# 1.  **Reduced Economic Losses:**
#     *   **Metric:** X% reduction in average annual direct property damages (residential, commercial) from storm events compared to the 5-year average pre-plan. Target: **30% reduction by Year 10, 60% by Year 20, 75% by Year 30.**
#     *   **Metric:** X% reduction in average annual business interruption losses from storm events. Target: **25% reduction by Year 10, 50% by Year 20, 70% by Year 30.**
# 2.  **Coastal Protection & Infrastructure Resilience:**
#     *   **Metric:** X km of coast protected by nature-based solutions (Target: 40 km).
#     *   **Metric:** X km of critical hard defenses constructed/elevated (Target: 30 km).
#     *   **Metric:** X% of critical public infrastructure (power, water, communication) in vulnerable zones upgraded to withstand 1.0m SLR + surge. Target: **80% by Year 30.**
# 3.  **Social Equity & Community Impact:**
#     *   **Metric:** Number of households successfully relocated with comprehensive support, without a decrease in household income or access to essential services for the poorest 20%. Target: **~1,500 households by Year 30.**
#     *   **Metric:** X% of affected residents reporting satisfaction with engagement processes and outcomes (via surveys). Target: **>70% satisfaction.**
#     *   **Metric:** No net increase in the poverty rate within the lowest 20% of the population due to adaptation initiatives.
# 4.  **Ecological Health & Cultural Heritage:**
#     *   **Metric:** X hectares of key coastal ecosystems (wetlands, dunes) restored/created, with documented increase in biodiversity (e.g., specific indicator species populations). Target: **>3,000 hectares.**
#     *   **Metric:** X number of priority cultural heritage sites physically protected or successfully relocated/digitally preserved. Target: **All identified priority sites.**
# 5.  **Funding & Governance:**
#     *   **Metric:** X% of annual budget successfully disbursed according to plan.
#     *   **Metric:** X additional funding secured from external sources.
#
# **Monitoring Strategies:**
#
# *   **Real-time Environmental Monitoring:** Network of tide gauges, wave buoys, and meteorological stations to track SLR, storm surge, and weather patterns.
# *   **Remote Sensing & GIS:** Regular aerial photography, LiDAR scans, and satellite imagery to track coastline changes, wetland health, and land use patterns.
# *   **Post-Event Damage Assessments:** Standardized protocols for quantifying direct and indirect economic losses after every major storm event, feeding into an economic impact model.
# *   **Socio-Economic Surveys:** Biennial surveys of vulnerable populations to track income, housing stability, access to services, and perceived safety/well-being. Specific focus on relocated communities.
# *   **Ecological Health Assessments:** Regular biodiversity surveys, water quality testing, and fisheries stock assessments in restoration areas and adjacent waters.
# *   **Financial Audits & Performance Reviews:** Annual audits of expenditure and independent reviews of project effectiveness against metrics.
# *   **Public Feedback & Grievance Mechanism:** Continuous collection of community feedback through the Resilience Hubs and Ombudsman, ensuring adaptive management.
# ...
# | **Value of ecosystem services (wetland, reef, dunes)** | **$1.2 B** (present value 2025‑2070) | US EPA coastal ecosystem valuation |
# | **Social cost of carbon (SCC)** | **$55 / t CO₂** (2025) | US DOT SCC 2021 |
# | **Construction cost index (CCI)** | 1.0 in 2025; 1.5 by 2070 (inflation + material) | AIA construction cost forecast |
# | **Equity threshold** | Bottom‑quintile household income = **$30 k / yr** | City tax‑records |
# | **Maximum acceptable net‑present‑value (NPV) loss for poorest 20 %** | **0** (no net loss) | Policy mandate |
#
# All monetary figures are **real dollars** (inflation‑adjusted).
#
# ---
#
# ## 3.  Phase‑Based Budget Allocation
#
# | Phase | Years | Main Objectives | Core Interventions (cost) | % of $2 B | Real‑term spending (US$) |
# |-------|-------|----------------|--------------------------|----------|---------------------------|
# | **Phase 1 – Foundations** | **1‑5** | Rapid risk reduction, data, governance set‑up | • 1 km “Living‑Shoreline” pilot (wetland + oyster reef) – $40 M  <br>• City‑wide Flood‑Risk Mapping & Early‑Warning System – $30 M  <br>• Equity‑Resilience Office (staff, advisory board) – $10 M  <br>• Pilot “Elevate‑Critical‑Infrastructure” (water treatment plant) – $60 M | 7 % | **$140 M** |
# | **Phase 2 – Hard + Nature‑Based Defenses** | **6‑15** | Protect high‑value tourism & cultural assets, create buffer zones | • **Storm‑Surge Barrier** at main harbor (gate + levee) – $600 M  <br>• **Living‑Shoreline Expansion** (5 km of marsh & dune restoration) – $150 M  <br>• **Elevated Road Network** (primary arterial & evacuation routes) – $250 M  <br>• **Green Roof & Flood‑Resilient Housing Retrofits** for 3 000 low‑income units – $120 M  | 62 % | **$1 240 M** |
# | **Phase 3 – Managed Retreat & Adaptive Growth** | **16‑30** | Relocate untenable zones, re‑zone, sustain fisheries & tourism | • **Buy‑out & Relocation Program** for 1 500 properties in the historic waterfront (≈15 % of at‑risk housing) – $350 M  <br>• **New “Resilient Waterfront”** mixed‑use district on reclaimed upland (public‑private) – $300 M (city equity, private capital)  <br>• **Fisheries Port Modernisation** (dry‑dock, flexible‑pier, habitat zones) – $150 M  <br>• **Adaptive Tourism Hub** (climate‑proof hotels, boardwalks) – $120 M  | 31 % | **$620 M** |
# | **Contingency & Administration** | **All** | 5 % of total for overruns, monitoring, community outreach | — | **5 %** | **$100 M** |
# | **Total** | **30 yr** | — | — | **100 %** | **$2 000 M** |
#
# *All spending is front‑loaded to the first 15 yr because early risk reduction yields the highest NPV (see Section 5).*
#
# ---
#
# ## 4.  Intervention‑by‑Intervention Benefit‑Cost Summary
#
# | # | Intervention | Lifetime (yr) | NPV of Benefits* | NPV of Costs** | B/C Ratio (3 % disc.) | Primary Benefits (quantified) |
# |---|--------------|--------------|------------------|----------------|----------------------|--------------------------------|
# | 1 | Living‑Shoreline pilot (1 km) | 30 | $95 M | $40 M | **2.4** | • 0.15 km² marsh sequesters 0.3 Mt CO₂ → $16 M SCC benefit  <br>• Flood attenuation: 0.8 m reduction → $12 M avoided damage annually (PV $120 M) |
# | 2 | City‑wide Flood‑Risk Mapping + Early‑Warning | 30 | $80 M | $30 M | **2.7** | • 15 % reduction in storm‑surge casualties (value of statistical life $9 M) → $12 M PV <br>• Faster recovery saves $6 M/yr in business interruption |
# | 3 | Storm‑Surge Barrier (harbor) | 30 | $1 200 M | $600 M | **2.0** | • Protects $3 B of tourism & port assets (PV) → $1 200 M avoided loss <br>• Enables continued operation of heritage cruise terminal |
# | 4 | Living‑Shoreline expansion (5 km) | 30 | $400 M | $150 M | **2.7** | • Adds 0.75 km² wetland → $45 M SCC + $30 M flood protection <br>• Enhances fish nursery → $20 M fisheries revenue |
# | 5 | Elevated Road Network (10 km) | 30 | $520 M | $250 M | **2.1** | • Keeps evacuation routes functional → $40 M saved in life‑value <br>• Prevents $30 M/yr in freight disruption |
# | 6 | Flood‑Resilient Housing Retrofits (3 000 units) | 30 | $260 M | $120 M | **2.2** | • Keeps 3 000 low‑income families in place → $45 M avoided relocation cost <br>• Energy‑efficiency savings $5 M/yr |
# | 7 | Buy‑out & Relocation (1 500 homes) | 30 | $470 M | $350 M | **1.3** | • Eliminates exposure of 4 % of city‑wide built‑up area <br>• Opens land for public park (social value $30 M) |
# | 8 | Resilient Waterfront (mixed‑use) | 30 | $560 M | $300 M | **1.9** | • Generates $80 M/yr new tax base (PV $560 M) <br>• Provides climate‑safe tourism capacity |
# | 9 | Fisheries Port Modernisation | 30 | $340 M | $150 M | **2.3** | • 12 % increase in landed value (≈$15 M/yr) <br>• Habitat zones boost stock recruitment (+$5 M/yr) |
# |10 | Adaptive Tourism Hub | 30 | $260 M | $120 M | **2.2** | • 10 % reduction in climate‑related occupancy loss → $26 M/yr revenue retained |
#
# \* **NPV of Benefits** includes avoided flood damages, avoided loss of life (VSL = $9 M), ecosystem‑service valuation, and incremental economic activity.
# \** **NPV of Costs** includes construction, O&M (5 % of capital per yr), and de‑commissioning (if any).
#
# **Total NPV of benefits ≈ $5.1 B**, **NPV of costs = $2.0 B**, **aggregate B/C = 2.6** – a strong economic case even after discounting.
#
# ---
#
# ## 5.  Geographic Prioritisation (Who is Protected, Relocated, Abandoned?)
#
# | Area (population / assets) | Elevation (m ASL) | Current risk (2025) | Intervention | Status by 2050 |
# |----------------------------|-------------------|----------------------|--------------|----------------|
# | **A. Historic Harbor & Tourist Promenade** (≈15 % of tourism revenue) | 0‑0.5 | High (≥30 % chance of >1 m surge) | Storm‑Surge Barrier + levee + heritage‑site elevation | **Protected** – barrier operational; key heritage buildings lifted/retro‑fitted |
# | **B. Low‑income coastal district “Bayview”** (≈12 % of poorest 20 % households) | 0‑1.2 | Very high (annual flood >2 ×) | Buy‑out & relocation to new inland public housing (Phase 3) | **Relocated** – compensated at market + 20 % premium; new units meet “climate‑safe” standards |
# | **C. Commercial fishing village “Marlon”** (≈8 % of fisheries employment) | 0‑0.8 | Moderate‑high | Port modernisation + living‑shoreline buffer | **Protected** – flexible pier and habitat zones; fishery revenue projected +12 % |
# | **D. Central downtown (mid‑elevation, 3‑5 m) ** | 3‑5 | Low | Elevate key utilities (water, power) | **Protected** – utilities remain functional during surge |
# | **E. Suburban fringe (≥5 m)** | >5 | Negligible | No major action | **Monitor only** – low risk, no direct spend |
# | **F. Former “Old Dock” industrial zone (contaminated, 0‑0.4 m)** | 0‑0.4 | Very high | **Abandoned** – no buy‑out; site converted to open‑space floodplain (no residential use) | **Converted to green buffer** – reduces wave energy, improves ecosystem services |
#
# *Equity safeguard:* The relocation package for Bayview includes a **job‑training fund** ($30 M) and a **rent‑control guarantee** for the first 10 yr in the new district, ensuring the poorest 20 % are not financially worse off.
#
# ---
#
# ## 6.  Additional Financing Mechanisms (Beyond the $2 B Baseline)
#
# | Mechanism | Structure | Expected Yield (30 yr) | Use of Proceeds |
# |-----------|-----------|------------------------|-----------------|
# | **1. Green Municipal Bonds** | 30‑yr, tax‑exempt, rated “A‑”. Issued by the City, backed by future property‑tax increment from the Resilient Waterfront. | $300 M (≈$10 M/yr for O&M) | Funds Phase 2 barrier & Phase 3 waterfront |
# | **2. State/Federal Climate Adaptation Grants** | Competitive grant (e.g., FEMA Hazard Mitigation Grant Program, NOAA Climate Resilience Grants). | $150 M (non‑repayable) | Covers 30 % of living‑shoreline and early‑warning system |
# | **3. Public‑Private Partnerships (PPP) for Tourism Hub** | Long‑term lease‑back: private operator builds climate‑proof hotel, city receives 10 % of gross revenues for 20 yr. | $200 M equity from private sector (city contributes $20 M) | Enables Adaptive Tourism Hub with minimal upfront city outlay |
# | **4. Resilience Impact Fees on New Development** | $5 / ft² of new waterfront construction, collected for 20 yr. | ≈ $70 M | Dedicated to O&M of storm‑surge barrier |
# | **5. Insurance‑linked Securities (Cat‑Bonds)** | 10‑yr bond tied to storm‑surge index; triggers payout if >2 m surge occurs. | $50 M (contingent) | Provides emergency cash‑flow for rapid repairs |
#
# *Total “leveraged” additional resources ≈ **$770 M**, which can be reinvested to expand nature‑based solutions or increase the scale of managed retreat.*
#
# ---
#
# ## 7.  Governance & Community‑Engagement (Equity Lens)
#
# 1. **Resilience Office (RO)** – reports to the Mayor, chaired by the City Planner, with a statutory **Equity Advisory Council (EAC)** (5 elected community reps from poorest quintile, 2 NGOs, 2 academia).
# 2. **Participatory Budget Workshops** – every 5 yr, the RO presents a **“Resilience Budget Draft”**; residents vote on priority projects (non‑binding but informs final allocation).
# 3. **Transparent Data Portal** – open‑source GIS showing risk maps, project status, expenditures, and performance metrics (updated quarterly).
# 4. **Legal Safeguard** – any buy‑out contract must contain a “No‑Net‑Loss” clause: compensation ≥ market value + 20 % + relocation assistance.
# 5. **Capacity‑Building Grants** – $15 M over 30 yr earmarked for local NGOs to run climate‑literacy programs in schools and community centres, targeting low‑income neighbourhoods.
#
# ---
#
# ## 8.  Success Metrics & Monitoring Plan
#
# | Metric (target) | Baseline (2025) | Target (2050) | Measurement Frequency | Data Source |
# |-----------------|-----------------|---------------|-----------------------|-------------|
# | **Annual Expected Flood Damage** | $200 M | **<$30 M** (≈85 % reduction) | Yearly post‑event | City Insurance & FEMA claims |
# | **Number of households in poorest 20 % in flood‑prone zone** | 7 500 | **≤1 000** (≥86 % relocated/protected) | Annual census | City
# Competitor: llama3.2
#
# **Adaptation Plan**
#
# The proposed 30-year adaptation plan allocates the $2.0B budget across six concrete interventions, prioritizing those with the highest expected benefits and lowest costs.
#
# 1. **Sea Wall and Pump Replacement** (Year 1-5, $400M)
# Expected economic benefit: Reduce flood damage by 80% ($60M/year), increase property values by 25%
# Social benefit: Enhance quality of life, reduce displacement of vulnerable residents
# Environmental benefit: Protect infrastructure, preserve ecological habitats
# Costs estimated using a 4m/s flood velocity and storm surge frequency data; assuming an economic damages function, with higher expected benefits at lower cost thresholds (γ = 2.5).
#
# Phase-by-Phase Allocation:
# Year 1 - $40M for sea wall design and permitting
# Year 2 - $40M for pump installation
# Year 3 - $50M for sea level rise data analysis and policy development
# Year 4 - $75M for sea wall construction
# Year 5 - $55M for punch list items (accessibility, erosion control)
#
# Benefit-Cost Ratio: Estimated 3.9
#
# 2. **Erosion Mitigation in High-Risk Areas** (Year 5-10, $150M)
# Expected social benefit: Preserve low-income and elderly neighborhoods ($30M/year), reduce displacement risk
# Environmental benefits: Protect ecological habitats and infrastructure
#
# Benefit-Cost Ratio: Estimated 4.3
#
# Phase-by-Phase Allocation:
# Year 5 - $15M for site assessments and planning
# Year 6 - $20M for erosion control measures (vegetation, seawalls)
# Year 7 - $30M for construction of beach nourishment project
# Year 8 - $25M for restoration of habitats
# Year 9 - $20M for monitoring and maintenance
# Year 10 - $20M for community engagement and outreach
#
# 3. **Resilient Buildings and Infrastructure** (Year 5-15, $800M)
# Expected economic benefit: Reduce business interruption costs by 70% ($125M/year), increase property values by 15%
# Social benefit: Enhance quality of life, reduce displacement risk
# Environmental benefits: Protect infrastructure and ecological habitats
#
# Benefit-Cost Ratio: Estimated 3.9
#
# Phase-by-Phase Allocation:
# Year 5 - $50M for building codes update and training
# Year 6 - $80M for foundation reinforcement ( foundations, piers)
# Year 7 - $100M for elevated walkways and boardwalks
# Year 8 - $120M for seawall support structures
# Year 9 - $75M for roof reinforcements
# Year 10-15 - $350M for ongoing maintenance and monitoring
#
# 4. **Ecological Restoration** (Year 5-20, $200M)
# Expected social benefit: Support ecosystem services, preserve biodiversity ($40M/year), reduce storm surges ($10M/year)
# Environmental benefits: Preserve ecological habitats, restore natural barriers to ocean waves
#
# Benefit-Cost Ratio: Estimated 3.6
#
# Phase-by-Phase Allocation:
# Year 5 - $10M for habitat monitoring and restoration planning
# Year 6-10 - $20M for wetland restoration
# Year 11-15 - $40M for mangrove enhancement projects
# Year 16-20 - $50M for larger-scale ecological restoration initiatives
#
# 5. **Cultural Heritage Preservation** (Year 5-25, $150M)
# Expected social benefit: Preserve community history and cultural identity ($30M/year), support local heritage industries
# Environmental benefits: Reduce disruption caused by urban planning
#
# Benefit-Cost Ratio: Estimated 3.9
#
# Phase-by-Phase Allocation:
# Year 5 - $12M for heritage analysis and planning
# Year 6-8 - $20M for historic building restorations
# Year 9-15 - $30M for community engagement and education initiatives
# Year 16-25 - $60M for ongoing preservation and management
#
# 6. **Climate-Resilient Water** (Year 10-30, $200M)
# Expected social benefit: Address water quality concerns ($40M/year), strengthen wastewater infrastructure
# Environmental benefits: Reduce aquatic pollution
#
# Benefit-Cost Ratio: Estimated 4.5
#
# Phase-by-Phase Allocation:
# Year 10 - $15M for climate-resilient sewer design and implementation
# Year 11-20 - $60M for upgrades to the city's water treatment plant
# Year 21-25 - $35M for rehabilitation of affected aquifers
#
# **Funding and Finance Mechanisms**
#
# To supplement the $2.0B budget, we propose:
#
# 1. **Grants and Public Partnerships**: Collaborate with state, federal, and NGO partners to leverage an additional $100M over 10 years.
# 2. **Green Bond Financing**: Issues a climate-resilient infrastructure bond ($500M) within the first five years of our plan, taking advantage of favorable funding structures and expected long-term returns.
# 3. **Insurance Premiums**: Develop and manage specialized insurance products and premiums ($200M), leveraging municipal expertise alongside private sector risk management best practices.
#
# **Governance and Community Engagement**
#
# The administration will ensure equitable participation through:
#
# 1. City-led stakeholder groups
# 2. Regular public forums and consultations
# 3. Training programs on climate change and planning processes for vulnerable communities
#
# To verify the effectiveness of our plan, we have established measurable objectives like (a) a reduction of 20% in damages due to flooding and erosion within three decades; (b) community satisfaction rates >60% regarding overall quality of life by end Year 15.
#
# **Sensitivity Analysis**
#
# If parameters change,
#
# 1. An increase or decrease in damage functions would adjust relative priority allocation among projects.
# 2. Changes in economic discount rate impact return on investment, adjusting the final benefit-cost ratios and resource distribution across all projects.
# 3. Estimated impacts on public confidence would lead prioritization of long-term community benefits
#
# **Three Important Risks/Risk Modes and Contingency Actions**
#
# 1. Underestimated sea level rise or storm surge severity: Implement monitoring stations for updated predictions; reassess project durations under increased timelines.
#
# 2. Unsatisfactory stakeholder consensus, hindering adaptation planning feasibility.
#
# 3. Failure to implement effective measures to address inequality among target groups—revisit planning processes with community feedback and re-critical review the project's benefits distribution assumptions

# %%
# Let's bring this together - note the use of "enumerate"

together = ""
for index, answer in enumerate(answers):
    together += f"# Response from competitor {index+1}\n\n"
    together += answer + "\n\n"

# %%
print(together)
# Out:
# # Response from competitor 1
#
# Executive summary
# - Goal: Build a 30-year, equity-conscious, cost-effective adaptation plan for a medium coastal city (population ~350k) whose economy hinges on tourism and fisheries. Sea-level rise is projected to 1.0 m in 50 years; storm surge is expected to intensify. The city has a $2.0B budget for adaptation over 30 years, and policies must not worsen the poorest 20% of residents.
# - Core design: A phased package of hard protection, nature-based solutions, infrastructure upgrades, and voluntary relocation/buyout, prioritized by risk, economic value, and equity. The plan aims to reduce long-term economic losses from coastal hazards while preserving ecological services and cultural heritage.
# - Outcome (at a glance): Net present value (NPV) of benefits roughly matches the baseline budget, with substantial risk reduction in high-value zones and a path to long-term resilience that does not leave the poorest residents worse off. The plan includes governance, financing, and monitoring to ensure equity and transparency.
# - Confidence: Moderate-to-strong (about 72%). Reasonable assumptions and phased funding allow risk-managed implementation, but outcomes depend on financing stability, timely permitting, and community buy-in.
#
# A. Assumptions and data inputs (explicit)
# - Population and growth
#   - Current population: 350,000
#   - Baseline growth assumption: 0.60% per year (compound over 30 years) for planning purposes
#   - Sensitivity scenario: ±20% around growth rate
# - Sea-level rise and hazards
#   - SLR: 1.0 m rise projected over 50 years (approximate, regional variation acknowledged)
#   - Storm surge/frequency: Increases anticipated; higher surge heights during extreme events; risk concentrates in nearshore and low-lying zones
# - Valuation and damages
#   - Coastal-exposed asset value (coastal zone with high economic concentration): ~$16B
#   - Baseline annual hazard damage rate without adaptation: ~0.75% of coastal-exposed asset value in year 1, rising modestly with hazard intensification (roughly escalates over time with surge intensity and flood extent)
#   - Discount rate (real): 3% per year (used for PV calculations)
# - Economic structure and sectors
#   - Tourism and fisheries as primary sectors; damages affect hotels, ports/harbors, fishery facilities, boatyards, supply chains, and associated services
# - Equity and social values
#   - No program may reduce the material well-being or safety of the bottom 20% (poorest households)
#   - Protective plans include targeted housing assistance, relocation options, and affordable housing guarantees
# - Baseline governance and delivery
#   - 30-year horizon, with phased implementation and periodic evaluation
#   - Local cost of capital and permitting timelines assumed reasonable for a mid-sized city; delays risk higher costs or lower benefits
#
# Notes on data and calculations used
# - Present-value factor for 30 years at 3%: PV factor = [1 − (1.03)−30]/0.03 ≈ 19.6
# - Baseline EAD (present value) calculation example:
#   - Year 1 EAD = 0.75% × $16B ≈ $0.12B/year
#   - PV of 30-year annuity at 3%: $0.12B × 19.6 ≈ $2.35B
#   - This is a simplified illustration; we model gradual escalation with surges and other factors in the plan description.
# - Targeted reductions from interventions are estimated in PV terms (see intervention-specific numbers below)
#
# B. Priority 30-year adaptation plan (a) concrete interventions and (b) benefits/costs (numerical estimates where possible)
#
# Overarching design
# - Guiding principles: protect high-value economic assets and critical infrastructure; deploy nature-based solutions to preserve ecological services; ensure resilience of cultural heritage; implement voluntary, equitable relocation where needed; avoid worsening the poorest 20%; maintain and expand jobs in tourism and fisheries.
# - Total budget: $2.0B (nominal) over 30 years; plan uses phased spending and leverages other funds (see section D).
#
# Phase 1: Foundations, planning, and initial protections (Years 1–5)
# Budget: ~$400M
#
# - Governance, planning, and equity oversight
#   - Establish Climate Adaptation Authority; stakeholder engagement; data portal; annual public reporting
#   - Cost: ~$60M
# - Early nature-based and nearshore protection (living shorelines, dune restoration, buffer habitats)
#   - Targeted nearshore living shorelines to reduce wave energy and restore habitats; initial dune restoration along select beaches
#   - Cost: ~$150M
# - Interim protection of critical public facilities
#   - Elevation and floodproofing of city hall, main fire/police facilities, and wastewater treatment plant
#   - Cost: ~$110M
# - Evacuation planning, early warning, and core resilience communications
#   - Advanced warning systems, signage, drills, and evacuation route strengthening
#   - Cost: ~$40M
# - Readiness for buyouts (planning and first-draw funding)
#   - Voluntary buyout readiness for highest-risk parcels; appraisal framework; community outreach
#   - Cost: ~$40M
# - Small-scale risk reduction at priority tourist/fishing zones (e.g., minor seawall segments, floodproofing of marina facilities)
#   - Cost: ~$40M
#
# Net rationale: This phase builds the governance backbone, tests nature-based approaches, protects essential services, and sets up voluntary relocation processes without displacing any households yet. It also begins reducing risk exposure in high-visibility areas.
#
# Phase 2: Core protective infrastructure and targeted relocation (Years 6–12)
# Budget: ~$900M
#
# - Seawalls and surge barriers in high-value districts
#   - Focus on downtown core, harborfront hotels, cruise/port interface, and primary fishing harbor
#   - Estimated cost: ~$520M
#   - Expected benefit: substantial reduction in EAD for top-value zones; protection of tourism economy and port operations
# - Expanded nature-based protections and living shorelines
#   - Complement hard defenses with restored wetlands and oyster reefs, improving flood attenuation and habitat
#   - Estimated cost: ~$120M
#   - Expected benefit: additional EAD reductions; ecological co-benefits
# - Elevation/retrofit of additional critical infrastructure
#   - Water treatment, power substation, hospital secondary facilities, harbor-related infrastructure
#   - Estimated cost: ~$60M
# - Voluntary relocation/buyout program (Phase 1 deployments)
#   - Target households in high-risk housing with low replacement costs; provide relocation assistance and affordable replacement housing
#   - Estimated cost: ~$120M
#   - Rationale: reduce exposure where protection costs are high or where social equity concerns are acute
# - Enhanced evacuation routes and critical-asset redundancy
#   - Additional gates, bridges, and redundancy for critical corridors; back-up power for evacuation centers
#   - Estimated cost: ~$80M
# - Monitoring, adaptive management, and governance strengthening
#   - KPIs, independent oversight, annual progress report, and community feedback mechanisms
#   - Estimated cost: ~$20M
#
# Rationale: Phase 2 focuses on protecting high-value economic zones (port/tourist core) while expanding nature-based solutions and pushing forward the voluntary relocation program in a targeted, equitable way. The goal is to lower risk in the most valuable economic districts and begin reducing exposure in low- to middle-income neighborhoods where buyouts are most feasible and socially acceptable.
#
# Phase 3: Expansion, long-term protection, and cultural heritage resilience (Years 13–30)
# Budget: ~$700M
#
# - Expansion of protective corridors and additional seawall segments as needed
#   - Extend protection to peri-urban and additional tourism/fisheries corridors with phased segments
#   - Estimated cost: ~$420M
# - Long-term relocation/abandonment planning (where voluntary buyouts are accepted or feasible)
#   - Complete buyouts for remaining high-risk parcels; ensure affordable housing alternatives
#   - Estimated cost: ~$100M
# - Cultural heritage preservation and climate-proofing of historic districts
#   - Implement climate-resilient restoration, floodproofing, and display of cultural assets with community engagement
#   - Estimated cost: ~$80M
# - Ecosystem restoration and restoration of degraded coastal habitats
#   - Restoration of mangroves, wetlands, and nearshore habitats to support ecological services
#   - Estimated cost: ~$40M
# - Monitoring, governance, and continuous improvement
#   - Long-term program evaluation, equity audits, and adaptive management
#   - Estimated cost: ~$60M
#
# Rationale: Phase 3 consolidates gains, expands protection to more neighborhoods and assets, and preserves cultural heritage and ecological services. It also completes voluntary relocation in a manner that protects the poorest and avoids forced resettlement.
#
# Total budget by phase (summed estimates)
# - Phase 1 (Years 1–5): ~$400M
# - Phase 2 (Years 6–12): ~$900M
# - Phase 3 (Years 13–30): ~$700M
# - Total: ~$2.0B
#
# C. Neighborhoods/assets protected, relocated, or abandoned (why)
#
# - Protected (high-value economic and critical-assets):
#   - Downtown core, harborfront, primary hotels, cruise-ship and tourism-related infrastructure, main fishing harbor, and hospital/water/wastewater facilities
#   - Rationale: these assets generate the bulk of current economic activity (tourism and fisheries) and provide essential services; their protection yields the highest near-term economic and societal payoff and reduces risk to the broader economy.
# - Relocated (voluntary buyouts for equity and risk reduction):
#   - High-risk residential blocks in low-to-moderate property-value zones immediately adjacent to the shoreline; lower-income neighborhoods with limited mobility options; parcels with feasible replacement housing options
#   - Rationale: reduce displacement risk for poorer households; ensure fair compensation and replacement housing; voluntary buyouts minimize social conflict and support equity objectives.
# - Abandoned (economic/ease-of-risk decisions)
#   - In cases where the cost of protection is drastically higher than the asset value, or when risk is unacceptable (e.g., single-structure properties with extremely high hazard profiles and no feasible relocation options)
#   - Rationale: avoid locking in unsustainable costs; where feasible, offer relocation or conversion to non-residential uses (e.g., parks, open space) rather than continued hazard exposure. This would be pursued only if voluntary options are exhausted and risk remains unacceptable after protection investments.
#
# D. Funding and financing mechanisms beyond the $2.0B baseline
# 1) Climate resilience bonds (green or blue bonds)
#    - Sell city-backed bonds specifically for adaptation projects; issue debt with proceeds restricted to resilience interventions
#    - Rationale: broad market access, longer tenors, potential favorable rates for green issuance; aligns with investor appetite for resilience assets
# 2) Public-private partnerships (P3) for port/tourism infrastructure and critical facilities
#    - Leverage private sector investment in uptime, resilience, and service delivery (e.g., seawall maintenance, floodproofing of private assets near the port, or flood-resilient hotel upgrades) with performance-based payments
#    - Rationale: attract capital and expertise; accelerate delivery; align incentives for long-term maintenance
# 3) Federal/state grants, and disaster risk reduction funds (BRIC/HMA equivalents)
#    - Seek competitive grants targeted at resilience, hazard mitigation, and coastal restoration; apply for federal/state resilience and climate-adaptation programs
#    - Rationale: non-debt funding that does not impact local taxes or debt capacity
# 4) Catastrophe bonds and parametric insurance instruments
#    - Weather-triggered securitizations to cover extreme-event losses; funds can be earmarked for rapid post-disaster resilience investments or early-stage protection
#    - Rationale: diversify risk financing; provide rapid liquidity after extreme events
# 5) Tax-increment financing (TIF) or special assessment districts for targeted districts
#    - Create districts where incremental value from investments funds resilience works in specific corridors (e.g., harbor area) while preserving equity safeguards
#    - Rationale: leverages future gains to finance current improvements, with transparency and governance safeguards
#
# E. Governance, equity, and community engagement (measures to ensure equity)
# - Equity-focused oversight
#   - Establish an independent Equity and Adaptation Commission that includes representatives from affected neighborhoods, fisheries, tourism associations, historians, and public health
#   - Annual public report on equity metrics (cost burdens, displacement risk, access to housing, and benefits distribution)
# - Participatory planning
#   - Regular community town halls in multiple languages; community-defined project briefings; participatory budgeting elements for small but meaningful allocations
# - Transparent data and procurement
#   - Public data portal with hazard maps, asset inventories, project schedules, procurement logs, and contract performance
# - Housing and social safeguards
#   - Require affordable housing guarantees for relocated households; ensure rent protections and anti-displacement policies; provide mobility services and retraining programs where necessary
# - Cultural heritage safeguards
#   - Involve local cultural groups to guide restoration and interpretation of heritage sites; ensure accessible, inclusive interpretation for residents and visitors
# - Grievance and redress mechanisms
#   - Independent ombudsman to handle complaints related to relocation, compensation, or implementation delays
#
# F. Measurable success metrics and monitoring strategies
# - Physical and structural metrics
#   - Percent of high-value assets protected or retrofitted for flood and surge resistance
#   - Number of critical facilities with floodproofing or elevation completed
#   - Distance of evacuation routes improved or expanded; number of safe shelters with backup power
# - Economic metrics
#   - Reduction in expected annual damages (EAD) from coastal hazards; PV of avoided damages over 30 years
#   - Preservation or growth of tourism revenue and port activity in adaptation zones compared to baseline
#   - Reduced downtime for fisheries infrastructure during extreme events
# - Social equity metrics
#   - Share of benefits allocated to the bottom 40% and bottom 20% (poverty-weighted distribution)
#   - Number of households in lowest-income quintile aided by relocation/affordable housing guarantees
# - Environmental metrics
#   - Habitat restoration progress (wetlands, mangroves, reefs)
#   - Water quality and sediment transport indicators in nearshore zones
# - Governance and process metrics
#   - Transparency score (public dashboards updated quarterly)
#   - Community satisfaction and participation rates in engagement activities
# - Monitoring plan
#   - Annual reporting by the Climate Adaptation Authority
#   - Independent mid-term review at year 10; third-party evaluations at years 20 and 30
#   - Real-time dashboards for hazard events, system uptime, and shelter availability
#
# G. Explicit assumptions and data inputs used (catalog)
# - Population: 350k now; 0.60% annual growth assumed for planning (±20% sensitivity)
# - Discount rate: 3% real
# - Hazard exposure: coastal-exposed asset value ≈ $16B; baseline annual damage rate ≈ 0.75% of exposed value (year 1), escalating modestly with hazard intensification
# - SLR: +1.0 m by year 50 (50 years)
# - Storm surge: increasing frequency and intensity; nearshore protection needs
# - Economic structure: tourism and fisheries provide the majority of regional GDP and employment; disruption has multiplier effects
# - Equity constraint: poorest 20% must not be worse off; relocation/housing assistance programs included to ensure equity
# - Capital availability: baseline $2.0B funding is available; additional mechanisms will be used to bridge gaps
# - Construction and permitting timelines: phased schedule assumed feasible within local regulatory constraints and financing
# - Environmental co-benefits: habitat restoration improves ecology and resilience; certain interventions have spillover benefits (recreation, biodiversity)
#
# H. Sensitivity analysis (±20% on three key parameters)
# Method: Recompute a simplified PV of EAD with and without interventions, focusing on the core three levers below. Compare the net PV (benefits − costs) and rank changes among the major interventions.
#
# Parameters varied by ±20%:
# - Discount rate (real)
#   - Baseline: 3.0% → low: 2.4% high: 3.6%
# - Baseline hazard growth (EAD growth rate due to climate and hazard escalation)
#   - Baseline annual EAD growth: 0% escalation for simplicity in PV calculation (illustrative). Alternative: +0.5%/yr and +1.0%/yr escalations (compounding hazard escalation)
# - Population growth
#   - Baseline 0.60%/yr → low: 0.48%/yr; high: 0.72%/yr
#
# Illustrative numbers (order-of-magnitude; for the sake of comparison only)
# - PV of baseline EAD without adaptation (years 1–30, 3% discount)
#   - Baseline hazard growth 0%: ≈ $2.35B (as shown in the assumptions section)
#   - With +0.5% annual escalation: ≈ $2.72B
#   - With +1.0% annual escalation: ≈ $3.25B
# - PV of adaptation benefits (present value of avoided damages) for core interventions
#   - Seawalls +port protection (Phase 2): baseline PV avoided ≈ ($1.30–$1.60)B
#   - Nature-based solutions (Phase 1–2): baseline PV avoided ≈ ($0.45–$0.60)B
#   - Infrastructure elevation and floodproofing: baseline PV avoided ≈ ($0.25–$0.35)B
#   - Voluntary relocation/buyouts: baseline PV avoided ≈ ($0.15–$0.25)B
# - Net PV (PV benefits − PV costs)
#   - Baseline (discount 3%, hazard growth 0%, population growth 0.60%): Net PV ≈ +$0.25B to +$0.50B (positive)
#   - Lower discount rate (2.4%): Net PV increases by ~+15% to +25% for core components
#   - Higher hazard growth (+0.5% or +1.0%): Net PV decreases by ~10%–25%, depending on the phase
#   - Higher population growth (+0.72%): Increases exposure, but also increases benefits of protection; net PV may shift modestly upward if benefits scale with population
# Interpretation:
# - The ranking of interventions (hard protection first, then nature-based, then relocation) remains generally robust under ±20% variations in discount rate, hazard escalation, and population growth, though the magnitude of PV benefits shifts.
# - If discount rate falls, PV benefits rise; if hazards escalate quickly, costs are higher and urgent protection of high-value assets is more compelling.
#
# I. Risks, failure modes, and contingency actions (three per key risk)
#
# 1) Financing risk
# - Risk: Insufficient or delayed funding to complete planned phases; market conditions raise borrowing costs.
# - Contingencies:
#   - Front-load low-cost, high-ambiguity elements (governance, initial nature-based works) to maintain momentum
#   - Activate alternate financing (catalyze green bonds or cat bonds; apply for BRIC/HMA grants; pursue P3 structures)
#   - Phase gate decisions with clear triggers to release further funds; maintain reserve lines
#
# 2) Equity and community legitimacy risk
# - Risk: Plans that improve infrastructure but worsen or fail to protect the poorest; loss of trust and participation
# - Contingencies:
#   - Strengthen targeted protections and relocation guarantees; ensure affordable housing and relocation assistance
#   - Create an independent equity advisory panel with legal oversight and transparent metrics
#   - Maintain a robust grievance mechanism; adjust program scope based on feedback
#
# 3) Technical and permitting risk
# - Risk: Technical failures or delays (e.g., structural seawalls not performing as expected; environmental permitting delays)
# - Contingencies:
#   - Use modular, testable components; pilot segments with adaptive management
#   - Employ independent design reviews and third-party verification; maintain contingency budgets for redesigns
#   - Build redundancy (alternative evacuation routes, backup power) and non-structural measures (early warning, land-use planning)
#
# 4) Governance and political risk
# - Risk: Changes in leadership or policy priorities threaten long-term plan continuity
# - Contingencies:
#   - Enshrine plan in a formal city policy framework; secure multi-party support and charter formalities
#   - Establish durable governance bodies with long-term terms and rotating leadership
#   - Regular public reporting and citizen oversight to sustain legitimacy
#
# 5) Environmental and ecological risk
# - Risk: Unintended ecological impacts from interventions; habitat degradation
# - Contingencies:
#   - Implement adaptive management with ecological monitoring; adjust projects if biodiversity signals decline
#   - Prioritize nature-based solutions where possible to maximize co-benefits
#   - Require environmental impact assessments and post-implementation auditing
#
# J. Three falsifiable pieces of evidence that would lead to abandoning the plan (within 10 years)
# 1) Material failure to reduceEAD or to protect key economic zones
#   - If, after a 5–10 year window, the PV of avoided damages is below 50% of projected baseline damages and high-value districts experience repeated multi-hazard losses, re-evaluate the cost-effectiveness of the protection strategy or pivot to alternative approaches.
# 2) Worsening inequities among the bottom 20%
#   - If equity metrics show that the bottom quintile’s safety, housing affordability, or access to essential services deteriorate despite program implementation (e.g., net losses in living standards, rising displacement burden), stop the current buyout/relocation approach and redesign with stronger social protections, housing subsidies, and inclusive economic supports.
# 3) Infeasibility or insolvency of financing mechanisms
#   - If critical funding channels (bonds, grants, cat bonds, or P3 pipelines) fail to materialize or become prohibitively costly, and the city cannot sustain the 30-year plan without compromising essential services or equity commitments, pause and renegotiate the program design, focusing on non-debt financing, grant-expedited projects, and a narrower scope.
#
# K. Simple calculations illustrating core logic (selected calculations shown)
# - PV factor for 30 years at 3%: 19.6
# - Baseline EAD example (illustrative)
#   - Year 1 EAD ≈ 0.75% × $16B = $120M
#   - PV of 30-year annuity: $120M × 19.6 ≈ $2.35B
# - Intervention PV (illustrative ranges)
#   - Seawalls/port protection PV avoided: ~$1.30–$1.60B
#   - Nature-based solutions PV avoided: ~$0.45–$0.60B
#   - Infrastructure floodproofing PV avoided: ~$0.25–$0.35B
#   - Relocation/buyouts PV avoided: ~$0.15–$0.25B
#   - Total PV avoided: ~ $2.15–$2.75B
# - Net PV (illustrative)
#   - Baseline PV damages: ~$2.35B
#   - PV avoided by plan: ~ $2.15–$2.75B
#   - Net PV range: approx −$0.20B to +$0.40B (with a sensitivity leaning toward positive when benefits are on the higher end)
# - Budget alignment
#   - Program cost: $2.0B nominal
#   - PV-equivalent cost (3%): ~$1.8B
#   - Net PV: relative advantage within a narrow band near break-even, but with substantial tail benefits in avoided damages and ecological/cultural gains
#
# L. Overall confidence in achieving goals (0–100%)
# - Confidence estimate: 72%
# - Justification: The proposed plan is phased, equity-focused, and leverages multiple financing avenues, which improves feasibility. The expected benefits in high-value economic zones are substantial, and nature-based solutions add co-benefits and cost-effectiveness. However, confidence is constrained by:
#   - Financing risks (the need to mobilize additional funds beyond the baseline)
#   - Potential delays in permitting and implementation
#   - The necessity of robust community engagement to avoid inequitable outcomes
#   - The reliance on behavioral responses (voluntary relocation) and the political will to maintain continuity over 30 years
# - The plan remains viable if financing channels are efficiently activated, equity safeguards are rigorously implemented, and governance structures are stable. If these do not materialize, confidence would decrease accordingly.
#
# Bottom line
# - A phased, equity-forward mix of hard protection, nature-based solutions, infrastructure upgrades, and voluntary relocation can meet the city’s goals of reducing long-term losses, protecting ecological and cultural assets, and avoiding harm to the poorest residents, within the $2.0B baseline and leveraging additional financing. Ongoing governance, transparent monitoring, and strong community engagement are essential to realize the plan’s objectives and adjust to evolving hazards and economic conditions. A transparent, adaptive approach maximizes the probability of achieving long-term resilience while keeping the poorest residents safe and economically secure.
#
# # Response from competitor 2
#
# # 30-Year Coastal Adaptation Plan for Mid-Sized Coastal City
#
# ## EXECUTIVE SUMMARY
# This plan allocates $2.0B across hybrid grey-green infrastructure, strategic retreat, and social resilience programs. The strategy protects the downtown core and working waterfront while facilitating managed relocation from high-risk areas, prioritizing the most vulnerable populations.
#
# ---
#
# ## PART A: BUDGET ALLOCATION & INTERVENTION TIMELINE
#
# ### Phase 1: Years 1-10 (Foundation & Protection) - $850M
#
# **1. Critical Infrastructure Hardening - $280M**
# - Elevate water/sewage treatment plants (+2.5m): $120M
# - Relocate emergency services & critical facilities: $90M
# - Upgrade stormwater drainage system: $70M
#
# **2. Hybrid Coastal Defense (Downtown & Port) - $320M**
# - Living seawall with oyster reefs (4 km): $180M
# - Beach nourishment + dune restoration (6 km): $85M
# - Tidal gate system at harbor entrance: $55M
#
# **3. Early Warning & Monitoring Infrastructure - $35M**
# - Real-time flood sensor network: $15M
# - Storm surge prediction system: $12M
# - Community alert infrastructure: $8M
#
# **4. Equity-Focused Relocation Preparation - $155M**
# - Purchase 450 properties in highest-risk zones: $110M
# - Establish relocation trust fund: $30M
# - Community planning & social services: $15M
#
# **5. Nature-Based Solutions (Ecological Buffer) - $60M**
# - Restore 200 hectares coastal wetlands: $40M
# - Create 50 hectares upland buffer forest: $20M
#
# ### Phase 2: Years 11-20 (Transformation & Adaptation) - $780M
#
# **6. Strategic Managed Retreat - $380M**
# - Acquire additional 650 properties: $240M
# - Buyout compensation (above market for poorest 20%): $85M
# - Infrastructure decommissioning: $35M
# - New affordable housing in safe zones: $20M
#
# **7. Enhanced Coastal Defense (Selective) - $210M**
# - Multi-layer protection for cultural heritage district: $95M
# - Working waterfront adaptation (floating docks, elevated facilities): $80M
# - Green infrastructure expansion (urban wetlands, bioswales): $35M
#
# **8. Economic Transition Support - $115M**
# - Fisheries adaptation (climate-resilient aquaculture): $50M
# - Tourism infrastructure relocation/upgrade: $40M
# - Workforce retraining programs: $25M
#
# **9. Social Infrastructure & Resilience Hubs - $75M**
# - Five community resilience centers (cooling, emergency shelter): $50M
# - Subsidized flood insurance pool: $25M
#
# ### Phase 3: Years 21-30 (Consolidation & Maintenance) - $370M
#
# **10. Ongoing Maintenance & Adaptive Management - $180M**
# - Infrastructure upkeep (6M/year × 30 years): $180M
#
# **11. Second-Generation Interventions - $120M**
# - Technology upgrades and replacements: $70M
# - Additional nature-based solutions: $50M
#
# **12. Contingency Reserve - $70M**
# - For accelerated sea-level rise or major storm damage
#
# ---
#
# ## PART B: COST-BENEFIT ANALYSIS
#
# ### Economic Benefits (Present Value, 3% discount rate, 50-year horizon)
#
# **Avoided Damages:**
# - Protected property value: ~$4.2B (12,000 structures × $350K average)
# - Avoided annual flood losses: $85M/year → PV ≈ $2.1B
# - Maintained tourism revenue: $180M/year × 30% at risk → PV ≈ $1.4B
# - Fisheries infrastructure protection: PV ≈ $420M
# - **Total avoided economic losses: ~$8.1B**
#
# **Direct Economic Returns:**
# - Green infrastructure ecosystem services: $8M/year → PV ≈ $200M
# - Enhanced property values in protected zones (+12%): PV ≈ $380M
# - Tourism resilience premium: PV ≈
#
# # Response from competitor 3
#
# As an independent policy advisor, I have developed a comprehensive 30-year climate adaptation plan for your city. This plan prioritizes resilience, equity, and sustainable growth, aiming to minimize long-term economic losses while safeguarding your unique ecological and cultural heritage.
#
# ## Executive Summary
#
# This 30-year adaptation plan, budgeted at $2.0 billion, is designed to protect your mid-sized coastal city (population 350,000) from an anticipated 1.0 m sea-level rise and increased storm surge frequency/intensity over the next 50 years. The plan adopts a phased approach, combining nature-based solutions, targeted hard defenses, strategic infrastructure upgrades, and managed retreat, all underpinned by robust community engagement and a commitment to social equity. It aims to prevent an estimated $7-8 billion in economic losses, while preserving critical ecological services and cultural sites. The plan includes innovative funding mechanisms, strong governance, and clear monitoring strategies to ensure its success and adaptability.
#
# ## I. Assumptions and Data Inputs
#
# To develop this plan, the following explicit assumptions and data inputs were used:
#
# *   **Current City Population:** 350,000.
# *   **Population Growth Rate:** Assumed a modest 0.5% annual growth, leading to ~390,000 by year 30. This impacts future asset values and population at risk.
# *   **Sea-Level Rise (SLR):**
#     *   **Long-term Projection:** 1.0 meter over 50 years.
#     *   **30-Year Projection (for planning):** Assumed a linear rise, so (1.0 m / 50 years) * 30 years = **0.6 meters by year 30**. However, critical infrastructure interventions are designed with the full 1.0m (plus contingency) in mind due to their long lifespans.
# *   **Storm Surge Frequency & Intensity:** Assume a significant increase, where a current 1-in-100 year event effectively becomes a 1-in-50 year event, and typical storm surge heights increase by an additional **0.5 meters** during major events (on top of SLR).
# *   **Vulnerable Areas:** Estimated **20% of the city's land area** and associated assets (residential, commercial, infrastructure) are highly vulnerable to 0.6m SLR + surge, increasing to 25-30% with 1.0m SLR + surge.
# *   **Economic Structure:** Highly dependent on Tourism and Fisheries. Adaptation measures must support these sectors.
# *   **Property Values (Averages for Estimation):**
#     *   Residential Unit: $400,000
#     *   Commercial Establishment: $1,000,000
#     *   Public Infrastructure (per linear km for roads/utilities in vulnerable areas): $5,000,000
# *   **Total Asset Value at Risk (without adaptation):** Estimated cumulative potential economic damages over 30 years from chronic inundation and increased storm events (e.g., property damage, business interruption, infrastructure repair, environmental degradation) to be approximately **$10 billion**. This represents roughly 15-20% of the total estimated private and public asset value within the vulnerable zone (approx. 30,000 housing units, 1,000 commercial, 100km infrastructure).
# *   **Discount Rate:** Used **4%** for present value calculations, balancing short-term costs with long-term benefits.
# *   **Social Equity Constraint:** The poorest 20% of the population (approx. 70,000 individuals currently) **must not be made worse off**. This mandates targeted support for relocation, job training, and equitable access to protected areas.
# *   **Ecological Services & Cultural Heritage:** These are non-negotiable values requiring protection or appropriate mitigation/relocation.
# *   **Intervention Cost Estimates (Order of Magnitude):**
#     *   Nature-Based Solutions (NBS) (wetland/dune restoration): $5-15 million per km
#     *   Hard Defenses (seawalls, dikes): $15-25 million per km
#     *   Building Elevation/Flood-proofing: $100,000 - $200,000 per structure
#     *   Managed Retreat (property acquisition & relocation): $400,000 - $600,000 per household (includes property value, moving, social support).
# *   **Budget Allocation:** The available $2.0 billion over 30 years, implying an average annual spend of ~$67 million.
#
# ## II. Prioritized 30-Year Adaptation Plan
#
# The plan is structured into three phases, each building on the previous, with an emphasis on "no-regrets" actions and flexibility. The overall goal is to prevent approximately **$7-8 billion in cumulative economic losses** over 30 years, yielding an estimated Benefit-Cost Ratio (BCR) of 3.5:1 to 4:1 for the $2.0 billion investment.
#
# ### Phase 1: Planning, Nature-Based Solutions & Capacity Building (Years 1-10)
# *   **Budget Allocation:** $500 million
# *   **SLR by End of Phase:** ~0.2 m
#
# | Intervention | Description | Budget (Million) | Expected Benefits (30-yr cumulative) | Costs (30-yr cumulative) | Protected/Relocated/Abandoned & Why |
# | :---------- | :---------- | :--------------- | :---------------------------------- | :---------------------------- | :----------------------------------- |
# | **1. Comprehensive Vulnerability Assessment & Master Plan Integration** | Update zoning, building codes; detailed flood mapping; SLR scenarios. | $50 | Informed decision-making, reduced future maladaptation. Avoided **$500M** in misallocated funds. | Admin costs. | All areas - informs future actions. |
# | **2. Nature-Based Coastal Protection** | Restore/expand 25 km of wetlands & mangrove forests (estuaries, vulnerable coastlines); build 15 km of resilient dune systems. | $250 ($6.25M/km avg) | **Ecological:** Enhanced fisheries habitat, improved water quality, increased biodiversity. **Economic:** Natural storm buffer (avoided damages up to **$1.5B** in vulnerable low-lying commercial/residential areas near estuaries), boosted eco-tourism, carbon sequestration. **Social:** Recreational areas. | Land acquisition, planting, monitoring. | **Protected:** Key ecological zones, adjacent low-lying residential areas (e.g., "South Bay Wetlands"), some fishing communities. |
# | **3. Early Warning Systems & Evacuation Infrastructure** | Upgrade sensors, communication networks, reinforce evacuation routes and shelters. | $50 | **Social:** Reduced loss of life, safer evacuations. **Economic:** Reduced emergency response costs (avoided **$100M**), minimized business interruption. | Hardware, training, infrastructure. | All residents, particularly vulnerable communities. |
# | **4. Building Code Update & Pilot Flood-Proofing Program** | Mandatory new construction standards (elevation, flood-proofing). Pilot program for existing homes in moderate risk zones (500 homes). | $100 | **Economic:** Reduced property damage for new construction & participating homes (avoided **$200M** for pilot). **Social:** Increased homeowner resilience. | Admin, subsidies for pilot. | Select neighborhoods at moderate risk, future developments. |
# | **5. Cultural Heritage & Equity Preservation** | Inventory vulnerable sites; develop rapid relocation/documentation plans for key movable assets. Establish community engagement hubs. | $50 | **Cultural:** Safeguarding identity. **Social:** Inclusive planning, ensuring poorest 20% are engaged and informed. | Surveys, planning, initial engagement. | Specific historic districts (e.g., "Old Quarter"), vulnerable community assets. |
#
# ### Phase 2: Hardening Critical Assets & Strategic Retreat (Years 11-20)
# *   **Budget Allocation:** $800 million
# *   **SLR by End of Phase:** ~0.4 m
#
# | Intervention | Description | Budget (Million) | Expected Benefits (30-yr cumulative) | Costs (30-yr cumulative) | Protected/Relocated/Abandoned & Why |
# | :---------- | :---------- | :--------------- | :---------------------------------- | :---------------------------- | :----------------------------------- |
# | **1. Targeted Hard Defenses** | Construct/elevate 20 km of seawalls/dikes around the CBD, port, and key tourist zones. Incorporate floodgates. | $400 ($20M/km avg) | **Economic:** Direct protection of high-value commercial, tourism assets, and critical port infrastructure (avoided **$3.0B** in damages). Ensures business continuity. | Construction, maintenance. | **Protected:** Central Business District, Main Port Facilities, Premier Tourist Resorts. |
# | **2. Resilient Infrastructure Network** | Elevate and flood-proof critical utilities (substations, water treatment plants, communication hubs). Redundant systems. | $100 | **Economic:** Prevents cascading failures, maintains essential services (avoided **$500M** in economic disruption and repair). **Social:** Ensures public health and safety. | Engineering, construction. | All city infrastructure, supporting all residents. |
# | **3. Managed Retreat Program - Phase 1** | Acquire ~1,000 highly vulnerable low-income properties in designated flood zones (e.g., "Fisherman's Landing" and parts of "Old Town"). Provide comprehensive relocation assistance, job training, and new housing options (uphill, equitable). | $350 ($350k/household avg) | **Economic:** Avoided long-term protection costs for unviable areas (avoided **$700M** in property damages). **Social:** Enhanced safety, improved living conditions for vulnerable populations, upholding equity constraint. | Property acquisition, relocation services, social support. | **Relocated:** "Fisherman's Landing" (high flood risk, critical infrastructure in area to be relocated/elevated), parts of "Old Town" (historically significant but severely low-lying, with low-income residents). **Abandoned:** The vacated land will be converted into green space/tidal wetlands to provide further natural protection. |
# | **4. Cultural Heritage - Relocation/Documentation** | Begin physical relocation of selected smaller, movable cultural heritage assets; comprehensive digital documentation of immovable sites. | $50 | **Cultural:** Preservation of heritage. | Relocation, digital archiving. | Specific cultural heritage sites identified as unprotectable in situ. |
#
# ### Phase 3: Long-Term Resilience, Economic Diversification & Adaptive Management (Years 21-30)
# *   **Budget Allocation:** $700 million
# *   **SLR by End of Phase:** ~0.6 m
#
# | Intervention | Description | Budget (Million) | Expected Benefits (30-yr cumulative) | Costs (30-yr cumulative) | Protected/Relocated/Abandoned & Why |
# | :---------- | :---------- | :--------------- | :---------------------------------- | :---------------------------- | :----------------------------------- |
# | **1. Expansion of Multi-layered Defenses** | Further strengthen and extend 10 km of existing hard and nature-based defenses, based on updated SLR projections. | $300 ($15M/km avg) | **Economic:** Continued protection of critical assets, adapting to evolving threats (avoided **$1.5B** in damages post-Year 20). | Construction, maintenance. | Extended protection for key areas, new buffer zones. |
# | **2. Managed Retreat Program - Phase 2** | Acquire ~500 more properties in newly vulnerable or economically unviable areas; continue relocation and support programs. | $250 ($500k/household avg) | **Economic:** Avoided future protection costs (avoided **$350M**). **Social:** Prevents future displacement crises, ensures equity. | Property acquisition, relocation, new housing. | **Relocated:** Additional highly vulnerable residential areas (e.g., some waterfront homes), small commercial properties in newly identified risk zones. **Abandoned:** Converted to green infrastructure or nature preserves. |
# | **3. Economic Diversification & Green Jobs** | Invest in training programs for new 'blue economy' jobs (e.g., aquaculture, marine renewable energy, resilience consulting) for those affected by fisheries/tourism shifts. | $50 | **Economic:** Reduced reliance on vulnerable sectors, new growth opportunities. **Social:** Job security, reduced unemployment, enhances social equity. | Training programs, seed funding. | All residents, especially those affected by coastal changes. |
# | **4. Adaptive Governance & Monitoring Endowment** | Establish an endowment for ongoing monitoring, research, and adaptive management. Fund a permanent Climate Resilience Office. | $100 | **Operational:** Ensures long-term sustainability and flexibility of the plan. Continuous learning. | Endowment investment, staffing. | All aspects of the plan. |
#
# **Summary of Avoided Damages (Cumulative over 30 years):**
# *   Nature-Based Solutions: ~$1.5 Billion
# *   Pilot Flood-Proofing: ~$0.2 Billion
# *   Targeted Hard Defenses: ~$3.0 Billion
# *   Resilient Infrastructure: ~$0.5 Billion
# *   Managed Retreat: ~$1.05 Billion ($700M + $350M)
# *   Expansion of Defenses: ~$1.5 Billion
# *   **Total Estimated Avoided Damages:** ~$7.75 Billion (against a $2.0B investment)
#
# ## III. Funding and Finance Mechanisms (Beyond the $2.0B Baseline)
#
# The $2.0 billion budget is a strong start, but climate adaptation is an ongoing challenge. Here are three additional mechanisms to secure long-term funding:
#
# 1.  **Municipal Green Bonds:** The city could issue "Coastal Resilience Bonds" to attract socially responsible investors. These bonds would specifically fund eligible adaptation projects (e.g., nature-based solutions, resilient infrastructure).
#     *   **Mechanism:** Bonds are issued by the city, purchased by investors, and principal/interest repaid from general city revenues or dedicated fees.
#     *   **Potential:** Could raise an additional $500 million to $1 billion over the next 30 years, depending on market conditions and city credit rating.
#     *   **Benefit:** Diversifies funding, taps into a growing market for green investments, and signals the city's commitment to sustainability.
#
# 2.  **Tourism & Resilience Levy:** Implement a small, dedicated levy on tourism-related services (e.g., 1-2% on hotel stays, short-term rentals, or major attraction tickets).
#     *   **Mechanism:** Collected by businesses and remitted to a dedicated "Coastal Resilience Fund."
#     *   **Potential:** Given the city's tourism-dependent economy, this could generate $10-20 million annually (assuming $1 billion annual tourism revenue), accumulating to $300-600 million over 30 years.
#     *   **Benefit:** Directly links the industry benefiting from coastal attractions to their preservation. Tourists often accept small surcharges for environmental causes.
#
# 3.  **Public-Private Partnerships (PPPs) & Federal/State Grant Pursuit:** Actively pursue co-funding and partnerships for large-scale projects.
#     *   **Mechanism:**
#         *   **PPPs:** For projects benefiting specific private entities (e.g., port upgrades, beachfront resort protection), private developers or businesses contribute to project costs in exchange for long-term operational benefits or preferential leases.
#         *   **Federal/State Grants:** Dedicated grants for coastal resilience, infrastructure, wetland restoration, and community development.
#     *   **Potential:** Highly variable, but successful grant applications and PPPs could unlock hundreds of millions of dollars (e.g., $100-300 million over 30 years).
#     *   **Benefit:** Leverages external capital and expertise, reduces direct city burden, and ensures alignment with national/state resilience goals.
#
# ## IV. Governance and Community-Engagement Measures
#
# Ensuring equity and effectiveness requires robust governance and continuous community involvement:
#
# *   **1. City Resilience Office (CRO):** Establish a dedicated office with a Chief Resilience Officer reporting directly to the Mayor. This office will be responsible for plan implementation, inter-departmental coordination, external partnerships, and monitoring.
# *   **2. Multi-Stakeholder Resilience Task Force:** Create an oversight body comprising city officials, scientists, business leaders (tourism, fisheries), environmental NGOs, community representatives (including representatives from vulnerable groups), and cultural heritage experts. This task force will provide strategic guidance and ensure broad buy-in.
# *   **3. Neighborhood Resilience Hubs & Advisory Boards:** For areas most affected by proposed interventions (e.g., managed retreat zones, areas receiving new defenses), establish local hubs and dedicated advisory boards. These will serve as direct channels for feedback, co-design of solutions, and grievance resolution, ensuring the "poorest 20% not worse off" clause is upheld.
# *   **4. Dedicated Equity & Relocation Ombudsman:** An independent ombudsman will oversee the managed retreat and social support programs, ensuring fair compensation, equitable relocation options, and access to resources for affected households, particularly the poorest 20%.
# *   **5. Transparent Communication & Accessible Data:** Implement a public-facing dashboard showing project progress, spending, and monitoring data. Regular town halls, workshops, and accessible informational materials (multi-lingual) will foster trust and informed participation.
#
# ## V. Measurable Success Metrics and Monitoring Strategies
#
# **Measurable Success Metrics:**
#
# 1.  **Reduced Economic Losses:**
#     *   **Metric:** X% reduction in average annual direct property damages (residential, commercial) from storm events compared to the 5-year average pre-plan. Target: **30% reduction by Year 10, 60% by Year 20, 75% by Year 30.**
#     *   **Metric:** X% reduction in average annual business interruption losses from storm events. Target: **25% reduction by Year 10, 50% by Year 20, 70% by Year 30.**
# 2.  **Coastal Protection & Infrastructure Resilience:**
#     *   **Metric:** X km of coast protected by nature-based solutions (Target: 40 km).
#     *   **Metric:** X km of critical hard defenses constructed/elevated (Target: 30 km).
#     *   **Metric:** X% of critical public infrastructure (power, water, communication) in vulnerable zones upgraded to withstand 1.0m SLR + surge. Target: **80% by Year 30.**
# 3.  **Social Equity & Community Impact:**
#     *   **Metric:** Number of households successfully relocated with comprehensive support, without a decrease in household income or access to essential services for the poorest 20%. Target: **~1,500 households by Year 30.**
#     *   **Metric:** X% of affected residents reporting satisfaction with engagement processes and outcomes (via surveys). Target: **>70% satisfaction.**
#     *   **Metric:** No net increase in the poverty rate within the lowest 20% of the population due to adaptation initiatives.
# 4.  **Ecological Health & Cultural Heritage:**
#     *   **Metric:** X hectares of key coastal ecosystems (wetlands, dunes) restored/created, with documented increase in biodiversity (e.g., specific indicator species populations). Target: **>3,000 hectares.**
#     *   **Metric:** X number of priority cultural heritage sites physically protected or successfully relocated/digitally preserved. Target: **All identified priority sites.**
# 5.  **Funding & Governance:**
#     *   **Metric:** X% of annual budget successfully disbursed according to plan.
#     *   **Metric:** X additional funding secured from external sources.
#
# **Monitoring Strategies:**
#
# *   **Real-time Environmental Monitoring:** Network of tide gauges, wave buoys, and meteorological stations to track SLR, storm surge, and weather patterns.
# *   **Remote Sensing & GIS:** Regular aerial photography, LiDAR scans, and satellite imagery to track coastline changes, wetland health, and land use patterns.
# *   **Post-Event Damage Assessments:** Standardized protocols for quantifying direct and indirect economic losses after every major storm event, feeding into an economic impact model.
# *   **Socio-Economic Surveys:** Biennial surveys of vulnerable populations to track income, housing stability, access to services, and perceived safety/well-being. Specific focus on relocated communities.
# *   **Ecological Health Assessments:** Regular biodiversity surveys, water quality testing, and fisheries stock assessments in restoration areas and adjacent waters.
# *   **Financial Audits & Performance Reviews:** Annual audits of expenditure and independent reviews of project effectiveness against metrics.
# ...
# | **Value of ecosystem services (wetland, reef, dunes)** | **$1.2 B** (present value 2025‑2070) | US EPA coastal ecosystem valuation |
# | **Social cost of carbon (SCC)** | **$55 / t CO₂** (2025) | US DOT SCC 2021 |
# | **Construction cost index (CCI)** | 1.0 in 2025; 1.5 by 2070 (inflation + material) | AIA construction cost forecast |
# | **Equity threshold** | Bottom‑quintile household income = **$30 k / yr** | City tax‑records |
# | **Maximum acceptable net‑present‑value (NPV) loss for poorest 20 %** | **0** (no net loss) | Policy mandate |
#
# All monetary figures are **real dollars** (inflation‑adjusted).
#
# ---
#
# ## 3.  Phase‑Based Budget Allocation
#
# | Phase | Years | Main Objectives | Core Interventions (cost) | % of $2 B | Real‑term spending (US$) |
# |-------|-------|----------------|--------------------------|----------|---------------------------|
# | **Phase 1 – Foundations** | **1‑5** | Rapid risk reduction, data, governance set‑up | • 1 km “Living‑Shoreline” pilot (wetland + oyster reef) – $40 M  <br>• City‑wide Flood‑Risk Mapping & Early‑Warning System – $30 M  <br>• Equity‑Resilience Office (staff, advisory board) – $10 M  <br>• Pilot “Elevate‑Critical‑Infrastructure” (water treatment plant) – $60 M | 7 % | **$140 M** |
# | **Phase 2 – Hard + Nature‑Based Defenses** | **6‑15** | Protect high‑value tourism & cultural assets, create buffer zones | • **Storm‑Surge Barrier** at main harbor (gate + levee) – $600 M  <br>• **Living‑Shoreline Expansion** (5 km of marsh & dune restoration) – $150 M  <br>• **Elevated Road Network** (primary arterial & evacuation routes) – $250 M  <br>• **Green Roof & Flood‑Resilient Housing Retrofits** for 3 000 low‑income units – $120 M  | 62 % | **$1 240 M** |
# | **Phase 3 – Managed Retreat & Adaptive Growth** | **16‑30** | Relocate untenable zones, re‑zone, sustain fisheries & tourism | • **Buy‑out & Relocation Program** for 1 500 properties in the historic waterfront (≈15 % of at‑risk housing) – $350 M  <br>• **New “Resilient Waterfront”** mixed‑use district on reclaimed upland (public‑private) – $300 M (city equity, private capital)  <br>• **Fisheries Port Modernisation** (dry‑dock, flexible‑pier, habitat zones) – $150 M  <br>• **Adaptive Tourism Hub** (climate‑proof hotels, boardwalks) – $120 M  | 31 % | **$620 M** |
# | **Contingency & Administration** | **All** | 5 % of total for overruns, monitoring, community outreach | — | **5 %** | **$100 M** |
# | **Total** | **30 yr** | — | — | **100 %** | **$2 000 M** |
#
# *All spending is front‑loaded to the first 15 yr because early risk reduction yields the highest NPV (see Section 5).*
#
# ---
#
# ## 4.  Intervention‑by‑Intervention Benefit‑Cost Summary
#
# | # | Intervention | Lifetime (yr) | NPV of Benefits* | NPV of Costs** | B/C Ratio (3 % disc.) | Primary Benefits (quantified) |
# |---|--------------|--------------|------------------|----------------|----------------------|--------------------------------|
# | 1 | Living‑Shoreline pilot (1 km) | 30 | $95 M | $40 M | **2.4** | • 0.15 km² marsh sequesters 0.3 Mt CO₂ → $16 M SCC benefit  <br>• Flood attenuation: 0.8 m reduction → $12 M avoided damage annually (PV $120 M) |
# | 2 | City‑wide Flood‑Risk Mapping + Early‑Warning | 30 | $80 M | $30 M | **2.7** | • 15 % reduction in storm‑surge casualties (value of statistical life $9 M) → $12 M PV <br>• Faster recovery saves $6 M/yr in business interruption |
# | 3 | Storm‑Surge Barrier (harbor) | 30 | $1 200 M | $600 M | **2.0** | • Protects $3 B of tourism & port assets (PV) → $1 200 M avoided loss <br>• Enables continued operation of heritage cruise terminal |
# | 4 | Living‑Shoreline expansion (5 km) | 30 | $400 M | $150 M | **2.7** | • Adds 0.75 km² wetland → $45 M SCC + $30 M flood protection <br>• Enhances fish nursery → $20 M fisheries revenue |
# | 5 | Elevated Road Network (10 km) | 30 | $520 M | $250 M | **2.1** | • Keeps evacuation routes functional → $40 M saved in life‑value <br>• Prevents $30 M/yr in freight disruption |
# | 6 | Flood‑Resilient Housing Retrofits (3 000 units) | 30 | $260 M | $120 M | **2.2** | • Keeps 3 000 low‑income families in place → $45 M avoided relocation cost <br>• Energy‑efficiency savings $5 M/yr |
# | 7 | Buy‑out & Relocation (1 500 homes) | 30 | $470 M | $350 M | **1.3** | • Eliminates exposure of 4 % of city‑wide built‑up area <br>• Opens land for public park (social value $30 M) |
# | 8 | Resilient Waterfront (mixed‑use) | 30 | $560 M | $300 M | **1.9** | • Generates $80 M/yr new tax base (PV $560 M) <br>• Provides climate‑safe tourism capacity |
# | 9 | Fisheries Port Modernisation | 30 | $340 M | $150 M | **2.3** | • 12 % increase in landed value (≈$15 M/yr) <br>• Habitat zones boost stock recruitment (+$5 M/yr) |
# |10 | Adaptive Tourism Hub | 30 | $260 M | $120 M | **2.2** | • 10 % reduction in climate‑related occupancy loss → $26 M/yr revenue retained |
#
# \* **NPV of Benefits** includes avoided flood damages, avoided loss of life (VSL = $9 M), ecosystem‑service valuation, and incremental economic activity.
# \** **NPV of Costs** includes construction, O&M (5 % of capital per yr), and de‑commissioning (if any).
#
# **Total NPV of benefits ≈ $5.1 B**, **NPV of costs = $2.0 B**, **aggregate B/C = 2.6** – a strong economic case even after discounting.
#
# ---
#
# ## 5.  Geographic Prioritisation (Who is Protected, Relocated, Abandoned?)
#
# | Area (population / assets) | Elevation (m ASL) | Current risk (2025) | Intervention | Status by 2050 |
# |----------------------------|-------------------|----------------------|--------------|----------------|
# | **A. Historic Harbor & Tourist Promenade** (≈15 % of tourism revenue) | 0‑0.5 | High (≥30 % chance of >1 m surge) | Storm‑Surge Barrier + levee + heritage‑site elevation | **Protected** – barrier operational; key heritage buildings lifted/retro‑fitted |
# | **B. Low‑income coastal district “Bayview”** (≈12 % of poorest 20 % households) | 0‑1.2 | Very high (annual flood >2 ×) | Buy‑out & relocation to new inland public housing (Phase 3) | **Relocated** – compensated at market + 20 % premium; new units meet “climate‑safe” standards |
# | **C. Commercial fishing village “Marlon”** (≈8 % of fisheries employment) | 0‑0.8 | Moderate‑high | Port modernisation + living‑shoreline buffer | **Protected** – flexible pier and habitat zones; fishery revenue projected +12 % |
# | **D. Central downtown (mid‑elevation, 3‑5 m) ** | 3‑5 | Low | Elevate key utilities (water, power) | **Protected** – utilities remain functional during surge |
# | **E. Suburban fringe (≥5 m)** | >5 | Negligible | No major action | **Monitor only** – low risk, no direct spend |
# | **F. Former “Old Dock” industrial zone (contaminated, 0‑0.4 m)** | 0‑0.4 | Very high | **Abandoned** – no buy‑out; site converted to open‑space floodplain (no residential use) | **Converted to green buffer** – reduces wave energy, improves ecosystem services |
#
# *Equity safeguard:* The relocation package for Bayview includes a **job‑training fund** ($30 M) and a **rent‑control guarantee** for the first 10 yr in the new district, ensuring the poorest 20 % are not financially worse off.
#
# ---
#
# ## 6.  Additional Financing Mechanisms (Beyond the $2 B Baseline)
#
# | Mechanism | Structure | Expected Yield (30 yr) | Use of Proceeds |
# |-----------|-----------|------------------------|-----------------|
# | **1. Green Municipal Bonds** | 30‑yr, tax‑exempt, rated “A‑”. Issued by the City, backed by future property‑tax increment from the Resilient Waterfront. | $300 M (≈$10 M/yr for O&M) | Funds Phase 2 barrier & Phase 3 waterfront |
# | **2. State/Federal Climate Adaptation Grants** | Competitive grant (e.g., FEMA Hazard Mitigation Grant Program, NOAA Climate Resilience Grants). | $150 M (non‑repayable) | Covers 30 % of living‑shoreline and early‑warning system |
# | **3. Public‑Private Partnerships (PPP) for Tourism Hub** | Long‑term lease‑back: private operator builds climate‑proof hotel, city receives 10 % of gross revenues for 20 yr. | $200 M equity from private sector (city contributes $20 M) | Enables Adaptive Tourism Hub with minimal upfront city outlay |
# | **4. Resilience Impact Fees on New Development** | $5 / ft² of new waterfront construction, collected for 20 yr. | ≈ $70 M | Dedicated to O&M of storm‑surge barrier |
# | **5. Insurance‑linked Securities (Cat‑Bonds)** | 10‑yr bond tied to storm‑surge index; triggers payout if >2 m surge occurs. | $50 M (contingent) | Provides emergency cash‑flow for rapid repairs |
#
# *Total “leveraged” additional resources ≈ **$770 M**, which can be reinvested to expand nature‑based solutions or increase the scale of managed retreat.*
#
# ---
#
# ## 7.  Governance & Community‑Engagement (Equity Lens)
#
# 1. **Resilience Office (RO)** – reports to the Mayor, chaired by the City Planner, with a statutory **Equity Advisory Council (EAC)** (5 elected community reps from poorest quintile, 2 NGOs, 2 academia).
# 2. **Participatory Budget Workshops** – every 5 yr, the RO presents a **“Resilience Budget Draft”**; residents vote on priority projects (non‑binding but informs final allocation).
# 3. **Transparent Data Portal** – open‑source GIS showing risk maps, project status, expenditures, and performance metrics (updated quarterly).
# 4. **Legal Safeguard** – any buy‑out contract must contain a “No‑Net‑Loss” clause: compensation ≥ market value + 20 % + relocation assistance.
# 5. **Capacity‑Building Grants** – $15 M over 30 yr earmarked for local NGOs to run climate‑literacy programs in schools and community centres, targeting low‑income neighbourhoods.
#
# ---
#
# ## 8.  Success Metrics & Monitoring Plan
#
# | Metric (target) | Baseline (2025) | Target (2050) | Measurement Frequency | Data Source |
# |-----------------|-----------------|---------------|-----------------------|-------------|
# | **Annual Expected Flood Damage** | $200 M | **<$30 M** (≈85 % reduction) | Yearly post‑event | City Insurance & FEMA claims |
# | **Number of households in poorest 20 % in flood‑prone zone** | 7 500 | **≤1 000** (≥86 % relocated/protected) | Annual census | City
#
# # Response from competitor 6
#
# **Adaptation Plan**
#
# The proposed 30-year adaptation plan allocates the $2.0B budget across six concrete interventions, prioritizing those with the highest expected benefits and lowest costs.
#
# 1. **Sea Wall and Pump Replacement** (Year 1-5, $400M)
# Expected economic benefit: Reduce flood damage by 80% ($60M/year), increase property values by 25%
# Social benefit: Enhance quality of life, reduce displacement of vulnerable residents
# Environmental benefit: Protect infrastructure, preserve ecological habitats
# Costs estimated using a 4m/s flood velocity and storm surge frequency data; assuming an economic damages function, with higher expected benefits at lower cost thresholds (γ = 2.5).
#
# Phase-by-Phase Allocation:
# Year 1 - $40M for sea wall design and permitting
# Year 2 - $40M for pump installation
# Year 3 - $50M for sea level rise data analysis and policy development
# Year 4 - $75M for sea wall construction
# Year 5 - $55M for punch list items (accessibility, erosion control)
#
# Benefit-Cost Ratio: Estimated 3.9
#
# 2. **Erosion Mitigation in High-Risk Areas** (Year 5-10, $150M)
# Expected social benefit: Preserve low-income and elderly neighborhoods ($30M/year), reduce displacement risk
# Environmental benefits: Protect ecological habitats and infrastructure
#
# Benefit-Cost Ratio: Estimated 4.3
#
# Phase-by-Phase Allocation:
# Year 5 - $15M for site assessments and planning
# Year 6 - $20M for erosion control measures (vegetation, seawalls)
# Year 7 - $30M for construction of beach nourishment project
# Year 8 - $25M for restoration of habitats
# Year 9 - $20M for monitoring and maintenance
# Year 10 - $20M for community engagement and outreach
#
# 3. **Resilient Buildings and Infrastructure** (Year 5-15, $800M)
# Expected economic benefit: Reduce business interruption costs by 70% ($125M/year), increase property values by 15%
# Social benefit: Enhance quality of life, reduce displacement risk
# Environmental benefits: Protect infrastructure and ecological habitats
#
# Benefit-Cost Ratio: Estimated 3.9
#
# Phase-by-Phase Allocation:
# Year 5 - $50M for building codes update and training
# Year 6 - $80M for foundation reinforcement ( foundations, piers)
# Year 7 - $100M for elevated walkways and boardwalks
# Year 8 - $120M for seawall support structures
# Year 9 - $75M for roof reinforcements
# Year 10-15 - $350M for ongoing maintenance and monitoring
#
# 4. **Ecological Restoration** (Year 5-20, $200M)
# Expected social benefit: Support ecosystem services, preserve biodiversity ($40M/year), reduce storm surges ($10M/year)
# Environmental benefits: Preserve ecological habitats, restore natural barriers to ocean waves
#
# Benefit-Cost Ratio: Estimated 3.6
#
# Phase-by-Phase Allocation:
# Year 5 - $10M for habitat monitoring and restoration planning
# Year 6-10 - $20M for wetland restoration
# Year 11-15 - $40M for mangrove enhancement projects
# Year 16-20 - $50M for larger-scale ecological restoration initiatives
#
# 5. **Cultural Heritage Preservation** (Year 5-25, $150M)
# Expected social benefit: Preserve community history and cultural identity ($30M/year), support local heritage industries
# Environmental benefits: Reduce disruption caused by urban planning
#
# Benefit-Cost Ratio: Estimated 3.9
#
# Phase-by-Phase Allocation:
# Year 5 - $12M for heritage analysis and planning
# Year 6-8 - $20M for historic building restorations
# Year 9-15 - $30M for community engagement and education initiatives
# Year 16-25 - $60M for ongoing preservation and management
#
# 6. **Climate-Resilient Water** (Year 10-30, $200M)
# Expected social benefit: Address water quality concerns ($40M/year), strengthen wastewater infrastructure
# Environmental benefits: Reduce aquatic pollution
#
# Benefit-Cost Ratio: Estimated 4.5
#
# Phase-by-Phase Allocation:
# Year 10 - $15M for climate-resilient sewer design and implementation
# Year 11-20 - $60M for upgrades to the city's water treatment plant
# Year 21-25 - $35M for rehabilitation of affected aquifers
#
# **Funding and Finance Mechanisms**
#
# To supplement the $2.0B budget, we propose:
#
# 1. **Grants and Public Partnerships**: Collaborate with state, federal, and NGO partners to leverage an additional $100M over 10 years.
# 2. **Green Bond Financing**: Issues a climate-resilient infrastructure bond ($500M) within the first five years of our plan, taking advantage of favorable funding structures and expected long-term returns.
# 3. **Insurance Premiums**: Develop and manage specialized insurance products and premiums ($200M), leveraging municipal expertise alongside private sector risk management best practices.
#
# **Governance and Community Engagement**
#
# The administration will ensure equitable participation through:
#
# 1. City-led stakeholder groups
# 2. Regular public forums and consultations
# 3. Training programs on climate change and planning processes for vulnerable communities
#
# To verify the effectiveness of our plan, we have established measurable objectives like (a) a reduction of 20% in damages due to flooding and erosion within three decades; (b) community satisfaction rates >60% regarding overall quality of life by end Year 15.
#
# **Sensitivity Analysis**
#
# If parameters change,
#
# 1. An increase or decrease in damage functions would adjust relative priority allocation among projects.
# 2. Changes in economic discount rate impact return on investment, adjusting the final benefit-cost ratios and resource distribution across all projects.
# 3. Estimated impacts on public confidence would lead prioritization of long-term community benefits
#
# **Three Important Risks/Risk Modes and Contingency Actions**
#
# 1. Underestimated sea level rise or storm surge severity: Implement monitoring stations for updated predictions; reassess project durations under increased timelines.
#
# 2. Unsatisfactory stakeholder consensus, hindering adaptation planning feasibility.
#
# 3. Failure to implement effective measures to address inequality among target groups—revisit planning processes with community feedback and re-critical review the project's benefits distribution assumptions

# %%
judge = f"""You are judging a competition between {len(competitors)} competitors.
Each model has been given this question:

{question}

Your job is to evaluate each response for clarity and strength of argument, and rank them in order of best to worst.
Respond with JSON, and only JSON, with the following format:
{{"results": ["best competitor number", "second best competitor number", "third best competitor number", ...]}}

Here are the responses from each competitor:

{together}

Now respond with the JSON with the ranked order of the competitors, nothing else. Do not include markdown formatting or code blocks."""

# %%
print(judge)
# Out:
# You are judging a competition between 6 competitors.
# Each model has been given this question:
#
# You are an independent policy advisor to the mayor of a real but unnamed mid-sized coastal city (population 350,000) whose economy depends on tourism and fisheries. Sea-level projections suggest a 1.0 m rise over the next 50 years; storm surge frequency and intensity are also expected to increase. The city has $2.0 billion available over the next 30 years for adaptation, must preserve social equity (no program may make the poorest 20% worse off), and seeks to minimize long-term economic losses while maintaining ecological services and cultural heritage sites.
#
# Design a prioritized 30-year adaptation plan for the city that: (a) allocates the $2.0B budget across concrete interventions (with year-by-year or phase-by-phase spending where appropriate), (b) estimates the expected economic, social, and environmental benefits and costs for each intervention (provide numerical estimates where possible), (c) identifies which neighborhoods or assets are protected, relocated, or abandoned and why, (d) proposes at least three funding or finance mechanisms beyond the $2.0B baseline, (e) includes governance and community-engagement measures to ensure equity, and (f) specifies measurable success metrics and monitoring strategies.
#
# Also, for your proposal: list all explicit assumptions and data inputs you used (population growth, discount rate, damage functions, social values, etc.), provide a simple sensitivity analysis showing how the plan or its ranking changes if three key parameters each vary by ±20%, identify the three most important risks or failure modes and contingency actions for each, and finally state three concrete, falsifiable pieces of evidence that—if observed within the next 10 years—would make you abandon your plan.
#
# Present your answer with clear reasoning and show relevant calculations; then give a single overall confidence estimate (0–100%) in the plan’s likelihood of meeting the city’s goals and briefly justify that percentage.
#
# Your job is to evaluate each response for clarity and strength of argument, and rank them in order of best to worst.
# Respond with JSON, and only JSON, with the following format:
# {"results": ["best competitor number", "second best competitor number", "third best competitor number", ...]}
#
# Here are the responses from each competitor:
#
# # Response from competitor 1
#
# Executive summary
# - Goal: Build a 30-year, equity-conscious, cost-effective adaptation plan for a medium coastal city (population ~350k) whose economy hinges on tourism and fisheries. Sea-level rise is projected to 1.0 m in 50 years; storm surge is expected to intensify. The city has a $2.0B budget for adaptation over 30 years, and policies must not worsen the poorest 20% of residents.
# - Core design: A phased package of hard protection, nature-based solutions, infrastructure upgrades, and voluntary relocation/buyout, prioritized by risk, economic value, and equity. The plan aims to reduce long-term economic losses from coastal hazards while preserving ecological services and cultural heritage.
# - Outcome (at a glance): Net present value (NPV) of benefits roughly matches the baseline budget, with substantial risk reduction in high-value zones and a path to long-term resilience that does not leave the poorest residents worse off. The plan includes governance, financing, and monitoring to ensure equity and transparency.
# - Confidence: Moderate-to-strong (about 72%). Reasonable assumptions and phased funding allow risk-managed implementation, but outcomes depend on financing stability, timely permitting, and community buy-in.
#
# A. Assumptions and data inputs (explicit)
# - Population and growth
#   - Current population: 350,000
#   - Baseline growth assumption: 0.60% per year (compound over 30 years) for planning purposes
#   - Sensitivity scenario: ±20% around growth rate
# - Sea-level rise and hazards
#   - SLR: 1.0 m rise projected over 50 years (approximate, regional variation acknowledged)
#   - Storm surge/frequency: Increases anticipated; higher surge heights during extreme events; risk concentrates in nearshore and low-lying zones
# - Valuation and damages
#   - Coastal-exposed asset value (coastal zone with high economic concentration): ~$16B
#   - Baseline annual hazard damage rate without adaptation: ~0.75% of coastal-exposed asset value in year 1, rising modestly with hazard intensification (roughly escalates over time with surge intensity and flood extent)
#   - Discount rate (real): 3% per year (used for PV calculations)
# - Economic structure and sectors
#   - Tourism and fisheries as primary sectors; damages affect hotels, ports/harbors, fishery facilities, boatyards, supply chains, and associated services
# - Equity and social values
#   - No program may reduce the material well-being or safety of the bottom 20% (poorest households)
#   - Protective plans include targeted housing assistance, relocation options, and affordable housing guarantees
# - Baseline governance and delivery
#   - 30-year horizon, with phased implementation and periodic evaluation
#   - Local cost of capital and permitting timelines assumed reasonable for a mid-sized city; delays risk higher costs or lower benefits
#
# Notes on data and calculations used
# - Present-value factor for 30 years at 3%: PV factor = [1 − (1.03)−30]/0.03 ≈ 19.6
# - Baseline EAD (present value) calculation example:
#   - Year 1 EAD = 0.75% × $16B ≈ $0.12B/year
#   - PV of 30-year annuity at 3%: $0.12B × 19.6 ≈ $2.35B
#   - This is a simplified illustration; we model gradual escalation with surges and other factors in the plan description.
# - Targeted reductions from interventions are estimated in PV terms (see intervention-specific numbers below)
#
# B. Priority 30-year adaptation plan (a) concrete interventions and (b) benefits/costs (numerical estimates where possible)
#
# Overarching design
# - Guiding principles: protect high-value economic assets and critical infrastructure; deploy nature-based solutions to preserve ecological services; ensure resilience of cultural heritage; implement voluntary, equitable relocation where needed; avoid worsening the poorest 20%; maintain and expand jobs in tourism and fisheries.
# - Total budget: $2.0B (nominal) over 30 years; plan uses phased spending and leverages other funds (see section D).
#
# Phase 1: Foundations, planning, and initial protections (Years 1–5)
# Budget: ~$400M
#
# - Governance, planning, and equity oversight
#   - Establish Climate Adaptation Authority; stakeholder engagement; data portal; annual public reporting
#   - Cost: ~$60M
# - Early nature-based and nearshore protection (living shorelines, dune restoration, buffer habitats)
#   - Targeted nearshore living shorelines to reduce wave energy and restore habitats; initial dune restoration along select beaches
#   - Cost: ~$150M
# - Interim protection of critical public facilities
#   - Elevation and floodproofing of city hall, main fire/police facilities, and wastewater treatment plant
#   - Cost: ~$110M
# - Evacuation planning, early warning, and core resilience communications
#   - Advanced warning systems, signage, drills, and evacuation route strengthening
#   - Cost: ~$40M
# - Readiness for buyouts (planning and first-draw funding)
#   - Voluntary buyout readiness for highest-risk parcels; appraisal framework; community outreach
#   - Cost: ~$40M
# - Small-scale risk reduction at priority tourist/fishing zones (e.g., minor seawall segments, floodproofing of marina facilities)
#   - Cost: ~$40M
#
# Net rationale: This phase builds the governance backbone, tests nature-based approaches, protects essential services, and sets up voluntary relocation processes without displacing any households yet. It also begins reducing risk exposure in high-visibility areas.
#
# Phase 2: Core protective infrastructure and targeted relocation (Years 6–12)
# Budget: ~$900M
#
# - Seawalls and surge barriers in high-value districts
#   - Focus on downtown core, harborfront hotels, cruise/port interface, and primary fishing harbor
#   - Estimated cost: ~$520M
#   - Expected benefit: substantial reduction in EAD for top-value zones; protection of tourism economy and port operations
# - Expanded nature-based protections and living shorelines
#   - Complement hard defenses with restored wetlands and oyster reefs, improving flood attenuation and habitat
#   - Estimated cost: ~$120M
#   - Expected benefit: additional EAD reductions; ecological co-benefits
# - Elevation/retrofit of additional critical infrastructure
#   - Water treatment, power substation, hospital secondary facilities, harbor-related infrastructure
#   - Estimated cost: ~$60M
# - Voluntary relocation/buyout program (Phase 1 deployments)
#   - Target households in high-risk housing with low replacement costs; provide relocation assistance and affordable replacement housing
#   - Estimated cost: ~$120M
#   - Rationale: reduce exposure where protection costs are high or where social equity concerns are acute
# - Enhanced evacuation routes and critical-asset redundancy
#   - Additional gates, bridges, and redundancy for critical corridors; back-up power for evacuation centers
#   - Estimated cost: ~$80M
# - Monitoring, adaptive management, and governance strengthening
#   - KPIs, independent oversight, annual progress report, and community feedback mechanisms
#   - Estimated cost: ~$20M
#
# Rationale: Phase 2 focuses on protecting high-value economic zones (port/tourist core) while expanding nature-based solutions and pushing forward the voluntary relocation program in a targeted, equitable way. The goal is to lower risk in the most valuable economic districts and begin reducing exposure in low- to middle-income neighborhoods where buyouts are most feasible and socially acceptable.
#
# Phase 3: Expansion, long-term protection, and cultural heritage resilience (Years 13–30)
# Budget: ~$700M
#
# - Expansion of protective corridors and additional seawall segments as needed
#   - Extend protection to peri-urban and additional tourism/fisheries corridors with phased segments
#   - Estimated cost: ~$420M
# - Long-term relocation/abandonment planning (where voluntary buyouts are accepted or feasible)
#   - Complete buyouts for remaining high-risk parcels; ensure affordable housing alternatives
#   - Estimated cost: ~$100M
# - Cultural heritage preservation and climate-proofing of historic districts
#   - Implement climate-resilient restoration, floodproofing, and display of cultural assets with community engagement
#   - Estimated cost: ~$80M
# - Ecosystem restoration and restoration of degraded coastal habitats
#   - Restoration of mangroves, wetlands, and nearshore habitats to support ecological services
#   - Estimated cost: ~$40M
# - Monitoring, governance, and continuous improvement
#   - Long-term program evaluation, equity audits, and adaptive management
#   - Estimated cost: ~$60M
#
# Rationale: Phase 3 consolidates gains, expands protection to more neighborhoods and assets, and preserves cultural heritage and ecological services. It also completes voluntary relocation in a manner that protects the poorest and avoids forced resettlement.
#
# Total budget by phase (summed estimates)
# - Phase 1 (Years 1–5): ~$400M
# - Phase 2 (Years 6–12): ~$900M
# - Phase 3 (Years 13–30): ~$700M
# - Total: ~$2.0B
#
# C. Neighborhoods/assets protected, relocated, or abandoned (why)
#
# - Protected (high-value economic and critical-assets):
#   - Downtown core, harborfront, primary hotels, cruise-ship and tourism-related infrastructure, main fishing harbor, and hospital/water/wastewater facilities
#   - Rationale: these assets generate the bulk of current economic activity (tourism and fisheries) and provide essential services; their protection yields the highest near-term economic and societal payoff and reduces risk to the broader economy.
# - Relocated (voluntary buyouts for equity and risk reduction):
#   - High-risk residential blocks in low-to-moderate property-value zones immediately adjacent to the shoreline; lower-income neighborhoods with limited mobility options; parcels with feasible replacement housing options
#   - Rationale: reduce displacement risk for poorer households; ensure fair compensation and replacement housing; voluntary buyouts minimize social conflict and support equity objectives.
# - Abandoned (economic/ease-of-risk decisions)
#   - In cases where the cost of protection is drastically higher than the asset value, or when risk is unacceptable (e.g., single-structure properties with extremely high hazard profiles and no feasible relocation options)
#   - Rationale: avoid locking in unsustainable costs; where feasible, offer relocation or conversion to non-residential uses (e.g., parks, open space) rather than continued hazard exposure. This would be pursued only if voluntary options are exhausted and risk remains unacceptable after protection investments.
#
# D. Funding and financing mechanisms beyond the $2.0B baseline
# 1) Climate resilience bonds (green or blue bonds)
#    - Sell city-backed bonds specifically for adaptation projects; issue debt with proceeds restricted to resilience interventions
#    - Rationale: broad market access, longer tenors, potential favorable rates for green issuance; aligns with investor appetite for resilience assets
# 2) Public-private partnerships (P3) for port/tourism infrastructure and critical facilities
#    - Leverage private sector investment in uptime, resilience, and service delivery (e.g., seawall maintenance, floodproofing of private assets near the port, or flood-resilient hotel upgrades) with performance-based payments
#    - Rationale: attract capital and expertise; accelerate delivery; align incentives for long-term maintenance
# 3) Federal/state grants, and disaster risk reduction funds (BRIC/HMA equivalents)
#    - Seek competitive grants targeted at resilience, hazard mitigation, and coastal restoration; apply for federal/state resilience and climate-adaptation programs
#    - Rationale: non-debt funding that does not impact local taxes or debt capacity
# 4) Catastrophe bonds and parametric insurance instruments
#    - Weather-triggered securitizations to cover extreme-event losses; funds can be earmarked for rapid post-disaster resilience investments or early-stage protection
#    - Rationale: diversify risk financing; provide rapid liquidity after extreme events
# 5) Tax-increment financing (TIF) or special assessment districts for targeted districts
#    - Create districts where incremental value from investments funds resilience works in specific corridors (e.g., harbor area) while preserving equity safeguards
#    - Rationale: leverages future gains to finance current improvements, with transparency and governance safeguards
#
# E. Governance, equity, and community engagement (measures to ensure equity)
# - Equity-focused oversight
#   - Establish an independent Equity and Adaptation Commission that includes representatives from affected neighborhoods, fisheries, tourism associations, historians, and public health
#   - Annual public report on equity metrics (cost burdens, displacement risk, access to housing, and benefits distribution)
# - Participatory planning
#   - Regular community town halls in multiple languages; community-defined project briefings; participatory budgeting elements for small but meaningful allocations
# - Transparent data and procurement
#   - Public data portal with hazard maps, asset inventories, project schedules, procurement logs, and contract performance
# - Housing and social safeguards
#   - Require affordable housing guarantees for relocated households; ensure rent protections and anti-displacement policies; provide mobility services and retraining programs where necessary
# - Cultural heritage safeguards
#   - Involve local cultural groups to guide restoration and interpretation of heritage sites; ensure accessible, inclusive interpretation for residents and visitors
# - Grievance and redress mechanisms
#   - Independent ombudsman to handle complaints related to relocation, compensation, or implementation delays
#
# F. Measurable success metrics and monitoring strategies
# - Physical and structural metrics
#   - Percent of high-value assets protected or retrofitted for flood and surge resistance
#   - Number of critical facilities with floodproofing or elevation completed
#   - Distance of evacuation routes improved or expanded; number of safe shelters with backup power
# - Economic metrics
#   - Reduction in expected annual damages (EAD) from coastal hazards; PV of avoided damages over 30 years
#   - Preservation or growth of tourism revenue and port activity in adaptation zones compared to baseline
#   - Reduced downtime for fisheries infrastructure during extreme events
# - Social equity metrics
#   - Share of benefits allocated to the bottom 40% and bottom 20% (poverty-weighted distribution)
#   - Number of households in lowest-income quintile aided by relocation/affordable housing guarantees
# - Environmental metrics
#   - Habitat restoration progress (wetlands, mangroves, reefs)
#   - Water quality and sediment transport indicators in nearshore zones
# - Governance and process metrics
#   - Transparency score (public dashboards updated quarterly)
#   - Community satisfaction and participation rates in engagement activities
# - Monitoring plan
#   - Annual reporting by the Climate Adaptation Authority
#   - Independent mid-term review at year 10; third-party evaluations at years 20 and 30
#   - Real-time dashboards for hazard events, system uptime, and shelter availability
#
# G. Explicit assumptions and data inputs used (catalog)
# - Population: 350k now; 0.60% annual growth assumed for planning (±20% sensitivity)
# - Discount rate: 3% real
# - Hazard exposure: coastal-exposed asset value ≈ $16B; baseline annual damage rate ≈ 0.75% of exposed value (year 1), escalating modestly with hazard intensification
# - SLR: +1.0 m by year 50 (50 years)
# - Storm surge: increasing frequency and intensity; nearshore protection needs
# - Economic structure: tourism and fisheries provide the majority of regional GDP and employment; disruption has multiplier effects
# - Equity constraint: poorest 20% must not be worse off; relocation/housing assistance programs included to ensure equity
# - Capital availability: baseline $2.0B funding is available; additional mechanisms will be used to bridge gaps
# - Construction and permitting timelines: phased schedule assumed feasible within local regulatory constraints and financing
# - Environmental co-benefits: habitat restoration improves ecology and resilience; certain interventions have spillover benefits (recreation, biodiversity)
#
# H. Sensitivity analysis (±20% on three key parameters)
# Method: Recompute a simplified PV of EAD with and without interventions, focusing on the core three levers below. Compare the net PV (benefits − costs) and rank changes among the major interventions.
#
# Parameters varied by ±20%:
# - Discount rate (real)
#   - Baseline: 3.0% → low: 2.4% high: 3.6%
# - Baseline hazard growth (EAD growth rate due to climate and hazard escalation)
#   - Baseline annual EAD growth: 0% escalation for simplicity in PV calculation (illustrative). Alternative: +0.5%/yr and +1.0%/yr escalations (compounding hazard escalation)
# - Population growth
#   - Baseline 0.60%/yr → low: 0.48%/yr; high: 0.72%/yr
#
# Illustrative numbers (order-of-magnitude; for the sake of comparison only)
# - PV of baseline EAD without adaptation (years 1–30, 3% discount)
#   - Baseline hazard growth 0%: ≈ $2.35B (as shown in the assumptions section)
#   - With +0.5% annual escalation: ≈ $2.72B
#   - With +1.0% annual escalation: ≈ $3.25B
# - PV of adaptation benefits (present value of avoided damages) for core interventions
#   - Seawalls +port protection (Phase 2): baseline PV avoided ≈ ($1.30–$1.60)B
#   - Nature-based solutions (Phase 1–2): baseline PV avoided ≈ ($0.45–$0.60)B
#   - Infrastructure elevation and floodproofing: baseline PV avoided ≈ ($0.25–$0.35)B
#   - Voluntary relocation/buyouts: baseline PV avoided ≈ ($0.15–$0.25)B
# - Net PV (PV benefits − PV costs)
#   - Baseline (discount 3%, hazard growth 0%, population growth 0.60%): Net PV ≈ +$0.25B to +$0.50B (positive)
#   - Lower discount rate (2.4%): Net PV increases by ~+15% to +25% for core components
#   - Higher hazard growth (+0.5% or +1.0%): Net PV decreases by ~10%–25%, depending on the phase
#   - Higher population growth (+0.72%): Increases exposure, but also increases benefits of protection; net PV may shift modestly upward if benefits scale with population
# Interpretation:
# - The ranking of interventions (hard protection first, then nature-based, then relocation) remains generally robust under ±20% variations in discount rate, hazard escalation, and population growth, though the magnitude of PV benefits shifts.
# - If discount rate falls, PV benefits rise; if hazards escalate quickly, costs are higher and urgent protection of high-value assets is more compelling.
#
# I. Risks, failure modes, and contingency actions (three per key risk)
#
# 1) Financing risk
# - Risk: Insufficient or delayed funding to complete planned phases; market conditions raise borrowing costs.
# - Contingencies:
#   - Front-load low-cost, high-ambiguity elements (governance, initial nature-based works) to maintain momentum
#   - Activate alternate financing (catalyze green bonds or cat bonds; apply for BRIC/HMA grants; pursue P3 structures)
#   - Phase gate decisions with clear triggers to release further funds; maintain reserve lines
#
# 2) Equity and community legitimacy risk
# - Risk: Plans that improve infrastructure but worsen or fail to protect the poorest; loss of trust and participation
# - Contingencies:
#   - Strengthen targeted protections and relocation guarantees; ensure affordable housing and relocation assistance
#   - Create an independent equity advisory panel with legal oversight and transparent metrics
#   - Maintain a robust grievance mechanism; adjust program scope based on feedback
#
# 3) Technical and permitting risk
# - Risk: Technical failures or delays (e.g., structural seawalls not performing as expected; environmental permitting delays)
# - Contingencies:
#   - Use modular, testable components; pilot segments with adaptive management
#   - Employ independent design reviews and third-party verification; maintain contingency budgets for redesigns
#   - Build redundancy (alternative evacuation routes, backup power) and non-structural measures (early warning, land-use planning)
#
# 4) Governance and political risk
# - Risk: Changes in leadership or policy priorities threaten long-term plan continuity
# - Contingencies:
#   - Enshrine plan in a formal city policy framework; secure multi-party support and charter formalities
#   - Establish durable governance bodies with long-term terms and rotating leadership
#   - Regular public reporting and citizen oversight to sustain legitimacy
#
# 5) Environmental and ecological risk
# - Risk: Unintended ecological impacts from interventions; habitat degradation
# - Contingencies:
#   - Implement adaptive management with ecological monitoring; adjust projects if biodiversity signals decline
#   - Prioritize nature-based solutions where possible to maximize co-benefits
#   - Require environmental impact assessments and post-implementation auditing
#
# J. Three falsifiable pieces of evidence that would lead to abandoning the plan (within 10 years)
# 1) Material failure to reduceEAD or to protect key economic zones
#   - If, after a 5–10 year window, the PV of avoided damages is below 50% of projected baseline damages and high-value districts experience repeated multi-hazard losses, re-evaluate the cost-effectiveness of the protection strategy or pivot to alternative approaches.
# 2) Worsening inequities among the bottom 20%
#   - If equity metrics show that the bottom quintile’s safety, housing affordability, or access to essential services deteriorate despite program implementation (e.g., net losses in living standards, rising displacement burden), stop the current buyout/relocation approach and redesign with stronger social protections, housing subsidies, and inclusive economic supports.
# 3) Infeasibility or insolvency of financing mechanisms
#   - If critical funding channels (bonds, grants, cat bonds, or P3 pipelines) fail to materialize or become prohibitively costly, and the city cannot sustain the 30-year plan without compromising essential services or equity commitments, pause and renegotiate the program design, focusing on non-debt financing, grant-expedited projects, and a narrower scope.
#
# K. Simple calculations illustrating core logic (selected calculations shown)
# - PV factor for 30 years at 3%: 19.6
# - Baseline EAD example (illustrative)
#   - Year 1 EAD ≈ 0.75% × $16B = $120M
#   - PV of 30-year annuity: $120M × 19.6 ≈ $2.35B
# - Intervention PV (illustrative ranges)
#   - Seawalls/port protection PV avoided: ~$1.30–$1.60B
#   - Nature-based solutions PV avoided: ~$0.45–$0.60B
#   - Infrastructure floodproofing PV avoided: ~$0.25–$0.35B
#   - Relocation/buyouts PV avoided: ~$0.15–$0.25B
#   - Total PV avoided: ~ $2.15–$2.75B
# - Net PV (illustrative)
#   - Baseline PV damages: ~$2.35B
#   - PV avoided by plan: ~ $2.15–$2.75B
#   - Net PV range: approx −$0.20B to +$0.40B (with a sensitivity leaning toward positive when benefits are on the higher end)
# - Budget alignment
#   - Program cost: $2.0B nominal
#   - PV-equivalent cost (3%): ~$1.8B
#   - Net PV: relative advantage within a narrow band near break-even, but with substantial tail benefits in avoided damages and ecological/cultural gains
#
# L. Overall confidence in achieving goals (0–100%)
# - Confidence estimate: 72%
# - Justification: The proposed plan is phased, equity-focused, and leverages multiple financing avenues, which improves feasibility. The expected benefits in high-value economic zones are substantial, and nature-based solutions add co-benefits and cost-effectiveness. However, confidence is constrained by:
#   - Financing risks (the need to mobilize additional funds beyond the baseline)
#   - Potential delays in permitting and implementation
#   - The necessity of robust community engagement to avoid inequitable outcomes
#   - The reliance on behavioral responses (voluntary relocation) and the political will to maintain continuity over 30 years
# - The plan remains viable if financing channels are efficiently activated, equity safeguards are rigorously implemented, and governance structures are stable. If these do not materialize, confidence would decrease accordingly.
#
# Bottom line
# - A phased, equity-forward mix of hard protection, nature-based solutions, infrastructure upgrades, and voluntary relocation can meet the city’s goals of reducing long-term losses, protecting ecological and cultural assets, and avoiding harm to the poorest residents, within the $2.0B baseline and leveraging additional financing. Ongoing governance, transparent monitoring, and strong community engagement are essential to realize the plan’s objectives and adjust to evolving hazards and economic conditions. A transparent, adaptive approach maximizes the probability of achieving long-term resilience while keeping the poorest residents safe and economically secure.
#
# # Response from competitor 2
#
# # 30-Year Coastal Adaptation Plan for Mid-Sized Coastal City
#
# ## EXECUTIVE SUMMARY
# This plan allocates $2.0B across hybrid grey-green infrastructure, strategic retreat, and social resilience programs. The strategy protects the downtown core and working waterfront while facilitating managed relocation from high-risk areas, prioritizing the most vulnerable populations.
#
# ---
#
# ## PART A: BUDGET ALLOCATION & INTERVENTION TIMELINE
#
# ### Phase 1: Years 1-10 (Foundation & Protection) - $850M
#
# **1. Critical Infrastructure Hardening - $280M**
# - Elevate water/sewage treatment plants (+2.5m): $120M
# - Relocate emergency services & critical facilities: $90M
# - Upgrade stormwater drainage system: $70M
#
# **2. Hybrid Coastal Defense (Downtown & Port) - $320M**
# - Living seawall with oyster reefs (4 km): $180M
# - Beach nourishment + dune restoration (6 km): $85M
# - Tidal gate system at harbor entrance: $55M
#
# **3. Early Warning & Monitoring Infrastructure - $35M**
# - Real-time flood sensor network: $15M
# - Storm surge prediction system: $12M
# - Community alert infrastructure: $8M
#
# **4. Equity-Focused Relocation Preparation - $155M**
# - Purchase 450 properties in highest-risk zones: $110M
# - Establish relocation trust fund: $30M
# - Community planning & social services: $15M
#
# **5. Nature-Based Solutions (Ecological Buffer) - $60M**
# - Restore 200 hectares coastal wetlands: $40M
# - Create 50 hectares upland buffer forest: $20M
#
# ### Phase 2: Years 11-20 (Transformation & Adaptation) - $780M
#
# **6. Strategic Managed Retreat - $380M**
# - Acquire additional 650 properties: $240M
# - Buyout compensation (above market for poorest 20%): $85M
# - Infrastructure decommissioning: $35M
# - New affordable housing in safe zones: $20M
#
# **7. Enhanced Coastal Defense (Selective) - $210M**
# - Multi-layer protection for cultural heritage district: $95M
# - Working waterfront adaptation (floating docks, elevated facilities): $80M
# - Green infrastructure expansion (urban wetlands, bioswales): $35M
#
# **8. Economic Transition Support - $115M**
# - Fisheries adaptation (climate-resilient aquaculture): $50M
# - Tourism infrastructure relocation/upgrade: $40M
# - Workforce retraining programs: $25M
#
# **9. Social Infrastructure & Resilience Hubs - $75M**
# - Five community resilience centers (cooling, emergency shelter): $50M
# - Subsidized flood insurance pool: $25M
#
# ### Phase 3: Years 21-30 (Consolidation & Maintenance) - $370M
#
# **10. Ongoing Maintenance & Adaptive Management - $180M**
# - Infrastructure upkeep (6M/year × 30 years): $180M
#
# **11. Second-Generation Interventions - $120M**
# - Technology upgrades and replacements: $70M
# - Additional nature-based solutions: $50M
#
# **12. Contingency Reserve - $70M**
# - For accelerated sea-level rise or major storm damage
#
# ---
#
# ## PART B: COST-BENEFIT ANALYSIS
#
# ### Economic Benefits (Present Value, 3% discount rate, 50-year horizon)
#
# **Avoided Damages:**
# - Protected property value: ~$4.2B (12,000 structures × $350K average)
# - Avoided annual flood losses: $85M/year → PV ≈ $2.1B
# - Maintained tourism revenue: $180M/year × 30% at risk → PV ≈ $1.4B
# - Fisheries infrastructure protection: PV ≈ $420M
# - **Total avoided economic losses: ~$8.1B**
#
# **Direct Economic Returns:**
# - Green infrastructure ecosystem services: $8M/year → PV ≈ $200M
# - Enhanced property values in protected zones (+12%): PV ≈ $380M
# - Tourism resilience premium: PV ≈
#
# # Response from competitor 3
#
# As an independent policy advisor, I have developed a comprehensive 30-year climate adaptation plan for your city. This plan prioritizes resilience, equity, and sustainable growth, aiming to minimize long-term economic losses while safeguarding your unique ecological and cultural heritage.
#
# ## Executive Summary
#
# This 30-year adaptation plan, budgeted at $2.0 billion, is designed to protect your mid-sized coastal city (population 350,000) from an anticipated 1.0 m sea-level rise and increased storm surge frequency/intensity over the next 50 years. The plan adopts a phased approach, combining nature-based solutions, targeted hard defenses, strategic infrastructure upgrades, and managed retreat, all underpinned by robust community engagement and a commitment to social equity. It aims to prevent an estimated $7-8 billion in economic losses, while preserving critical ecological services and cultural sites. The plan includes innovative funding mechanisms, strong governance, and clear monitoring strategies to ensure its success and adaptability.
#
# ## I. Assumptions and Data Inputs
#
# To develop this plan, the following explicit assumptions and data inputs were used:
#
# *   **Current City Population:** 350,000.
# *   **Population Growth Rate:** Assumed a modest 0.5% annual growth, leading to ~390,000 by year 30. This impacts future asset values and population at risk.
# *   **Sea-Level Rise (SLR):**
#     *   **Long-term Projection:** 1.0 meter over 50 years.
#     *   **30-Year Projection (for planning):** Assumed a linear rise, so (1.0 m / 50 years) * 30 years = **0.6 meters by year 30**. However, critical infrastructure interventions are designed with the full 1.0m (plus contingency) in mind due to their long lifespans.
# *   **Storm Surge Frequency & Intensity:** Assume a significant increase, where a current 1-in-100 year event effectively becomes a 1-in-50 year event, and typical storm surge heights increase by an additional **0.5 meters** during major events (on top of SLR).
# *   **Vulnerable Areas:** Estimated **20% of the city's land area** and associated assets (residential, commercial, infrastructure) are highly vulnerable to 0.6m SLR + surge, increasing to 25-30% with 1.0m SLR + surge.
# *   **Economic Structure:** Highly dependent on Tourism and Fisheries. Adaptation measures must support these sectors.
# *   **Property Values (Averages for Estimation):**
#     *   Residential Unit: $400,000
#     *   Commercial Establishment: $1,000,000
#     *   Public Infrastructure (per linear km for roads/utilities in vulnerable areas): $5,000,000
# *   **Total Asset Value at Risk (without adaptation):** Estimated cumulative potential economic damages over 30 years from chronic inundation and increased storm events (e.g., property damage, business interruption, infrastructure repair, environmental degradation) to be approximately **$10 billion**. This represents roughly 15-20% of the total estimated private and public asset value within the vulnerable zone (approx. 30,000 housing units, 1,000 commercial, 100km infrastructure).
# *   **Discount Rate:** Used **4%** for present value calculations, balancing short-term costs with long-term benefits.
# *   **Social Equity Constraint:** The poorest 20% of the population (approx. 70,000 individuals currently) **must not be made worse off**. This mandates targeted support for relocation, job training, and equitable access to protected areas.
# *   **Ecological Services & Cultural Heritage:** These are non-negotiable values requiring protection or appropriate mitigation/relocation.
# *   **Intervention Cost Estimates (Order of Magnitude):**
#     *   Nature-Based Solutions (NBS) (wetland/dune restoration): $5-15 million per km
#     *   Hard Defenses (seawalls, dikes): $15-25 million per km
#     *   Building Elevation/Flood-proofing: $100,000 - $200,000 per structure
#     *   Managed Retreat (property acquisition & relocation): $400,000 - $600,000 per household (includes property value, moving, social support).
# *   **Budget Allocation:** The available $2.0 billion over 30 years, implying an average annual spend of ~$67 million.
#
# ## II. Prioritized 30-Year Adaptation Plan
#
# The plan is structured into three phases, each building on the previous, with an emphasis on "no-regrets" actions and flexibility. The overall goal is to prevent approximately **$7-8 billion in cumulative economic losses** over 30 years, yielding an estimated Benefit-Cost Ratio (BCR) of 3.5:1 to 4:1 for the $2.0 billion investment.
#
# ### Phase 1: Planning, Nature-Based Solutions & Capacity Building (Years 1-10)
# *   **Budget Allocation:** $500 million
# *   **SLR by End of Phase:** ~0.2 m
#
# | Intervention | Description | Budget (Million) | Expected Benefits (30-yr cumulative) | Costs (30-yr cumulative) | Protected/Relocated/Abandoned & Why |
# | :---------- | :---------- | :--------------- | :---------------------------------- | :---------------------------- | :----------------------------------- |
# | **1. Comprehensive Vulnerability Assessment & Master Plan Integration** | Update zoning, building codes; detailed flood mapping; SLR scenarios. | $50 | Informed decision-making, reduced future maladaptation. Avoided **$500M** in misallocated funds. | Admin costs. | All areas - informs future actions. |
# | **2. Nature-Based Coastal Protection** | Restore/expand 25 km of wetlands & mangrove forests (estuaries, vulnerable coastlines); build 15 km of resilient dune systems. | $250 ($6.25M/km avg) | **Ecological:** Enhanced fisheries habitat, improved water quality, increased biodiversity. **Economic:** Natural storm buffer (avoided damages up to **$1.5B** in vulnerable low-lying commercial/residential areas near estuaries), boosted eco-tourism, carbon sequestration. **Social:** Recreational areas. | Land acquisition, planting, monitoring. | **Protected:** Key ecological zones, adjacent low-lying residential areas (e.g., "South Bay Wetlands"), some fishing communities. |
# | **3. Early Warning Systems & Evacuation Infrastructure** | Upgrade sensors, communication networks, reinforce evacuation routes and shelters. | $50 | **Social:** Reduced loss of life, safer evacuations. **Economic:** Reduced emergency response costs (avoided **$100M**), minimized business interruption. | Hardware, training, infrastructure. | All residents, particularly vulnerable communities. |
# | **4. Building Code Update & Pilot Flood-Proofing Program** | Mandatory new construction standards (elevation, flood-proofing). Pilot program for existing homes in moderate risk zones (500 homes). | $100 | **Economic:** Reduced property damage for new construction & participating homes (avoided **$200M** for pilot). **Social:** Increased homeowner resilience. | Admin, subsidies for pilot. | Select neighborhoods at moderate risk, future developments. |
# | **5. Cultural Heritage & Equity Preservation** | Inventory vulnerable sites; develop rapid relocation/documentation plans for key movable assets. Establish community engagement hubs. | $50 | **Cultural:** Safeguarding identity. **Social:** Inclusive planning, ensuring poorest 20% are engaged and informed. | Surveys, planning, initial engagement. | Specific historic districts (e.g., "Old Quarter"), vulnerable community assets. |
#
# ### Phase 2: Hardening Critical Assets & Strategic Retreat (Years 11-20)
# *   **Budget Allocation:** $800 million
# *   **SLR by End of Phase:** ~0.4 m
#
# | Intervention | Description | Budget (Million) | Expected Benefits (30-yr cumulative) | Costs (30-yr cumulative) | Protected/Relocated/Abandoned & Why |
# | :---------- | :---------- | :--------------- | :---------------------------------- | :---------------------------- | :----------------------------------- |
# | **1. Targeted Hard Defenses** | Construct/elevate 20 km of seawalls/dikes around the CBD, port, and key tourist zones. Incorporate floodgates. | $400 ($20M/km avg) | **Economic:** Direct protection of high-value commercial, tourism assets, and critical port infrastructure (avoided **$3.0B** in damages). Ensures business continuity. | Construction, maintenance. | **Protected:** Central Business District, Main Port Facilities, Premier Tourist Resorts. |
# | **2. Resilient Infrastructure Network** | Elevate and flood-proof critical utilities (substations, water treatment plants, communication hubs). Redundant systems. | $100 | **Economic:** Prevents cascading failures, maintains essential services (avoided **$500M** in economic disruption and repair). **Social:** Ensures public health and safety. | Engineering, construction. | All city infrastructure, supporting all residents. |
# | **3. Managed Retreat Program - Phase 1** | Acquire ~1,000 highly vulnerable low-income properties in designated flood zones (e.g., "Fisherman's Landing" and parts of "Old Town"). Provide comprehensive relocation assistance, job training, and new housing options (uphill, equitable). | $350 ($350k/household avg) | **Economic:** Avoided long-term protection costs for unviable areas (avoided **$700M** in property damages). **Social:** Enhanced safety, improved living conditions for vulnerable populations, upholding equity constraint. | Property acquisition, relocation services, social support. | **Relocated:** "Fisherman's Landing" (high flood risk, critical infrastructure in area to be relocated/elevated), parts of "Old Town" (historically significant but severely low-lying, with low-income residents). **Abandoned:** The vacated land will be converted into green space/tidal wetlands to provide further natural protection. |
# | **4. Cultural Heritage - Relocation/Documentation** | Begin physical relocation of selected smaller, movable cultural heritage assets; comprehensive digital documentation of immovable sites. | $50 | **Cultural:** Preservation of heritage. | Relocation, digital archiving. | Specific cultural heritage sites identified as unprotectable in situ. |
#
# ### Phase 3: Long-Term Resilience, Economic Diversification & Adaptive Management (Years 21-30)
# *   **Budget Allocation:** $700 million
# *   **SLR by End of Phase:** ~0.6 m
#
# | Intervention | Description | Budget (Million) | Expected Benefits (30-yr cumulative) | Costs (30-yr cumulative) | Protected/Relocated/Abandoned & Why |
# | :---------- | :---------- | :--------------- | :---------------------------------- | :---------------------------- | :----------------------------------- |
# | **1. Expansion of Multi-layered Defenses** | Further strengthen and extend 10 km of existing hard and nature-based defenses, based on updated SLR projections. | $300 ($15M/km avg) | **Economic:** Continued protection of critical assets, adapting to evolving threats (avoided **$1.5B** in damages post-Year 20). | Construction, maintenance. | Extended protection for key areas, new buffer zones. |
# | **2. Managed Retreat Program - Phase 2** | Acquire ~500 more properties in newly vulnerable or economically unviable areas; continue relocation and support programs. | $250 ($500k/household avg) | **Economic:** Avoided future protection costs (avoided **$350M**). **Social:** Prevents future displacement crises, ensures equity. | Property acquisition, relocation, new housing. | **Relocated:** Additional highly vulnerable residential areas (e.g., some waterfront homes), small commercial properties in newly identified risk zones. **Abandoned:** Converted to green infrastructure or nature preserves. |
# | **3. Economic Diversification & Green Jobs** | Invest in training programs for new 'blue economy' jobs (e.g., aquaculture, marine renewable energy, resilience consulting) for those affected by fisheries/tourism shifts. | $50 | **Economic:** Reduced reliance on vulnerable sectors, new growth opportunities. **Social:** Job security, reduced unemployment, enhances social equity. | Training programs, seed funding. | All residents, especially those affected by coastal changes. |
# | **4. Adaptive Governance & Monitoring Endowment** | Establish an endowment for ongoing monitoring, research, and adaptive management. Fund a permanent Climate Resilience Office. | $100 | **Operational:** Ensures long-term sustainability and flexibility of the plan. Continuous learning. | Endowment investment, staffing. | All aspects of the plan. |
#
# **Summary of Avoided Damages (Cumulative over 30 years):**
# *   Nature-Based Solutions: ~$1.5 Billion
# *   Pilot Flood-Proofing: ~$0.2 Billion
# *   Targeted Hard Defenses: ~$3.0 Billion
# *   Resilient Infrastructure: ~$0.5 Billion
# *   Managed Retreat: ~$1.05 Billion ($700M + $350M)
# *   Expansion of Defenses: ~$1.5 Billion
# *   **Total Estimated Avoided Damages:** ~$7.75 Billion (against a $2.0B investment)
#
# ## III. Funding and Finance Mechanisms (Beyond the $2.0B Baseline)
#
# The $2.0 billion budget is a strong start, but climate adaptation is an ongoing challenge. Here are three additional mechanisms to secure long-term funding:
#
# 1.  **Municipal Green Bonds:** The city could issue "Coastal Resilience Bonds" to attract socially responsible investors. These bonds would specifically fund eligible adaptation projects (e.g., nature-based solutions, resilient infrastructure).
#     *   **Mechanism:** Bonds are issued by the city, purchased by investors, and principal/interest repaid from general city revenues or dedicated fees.
#     *   **Potential:** Could raise an additional $500 million to $1 billion over the next 30 years, depending on market conditions and city credit rating.
#     *   **Benefit:** Diversifies funding, taps into a growing market for green investments, and signals the city's commitment to sustainability.
#
# 2.  **Tourism & Resilience Levy:** Implement a small, dedicated levy on tourism-related services (e.g., 1-2% on hotel stays, short-term rentals, or major attraction tickets).
#     *   **Mechanism:** Collected by businesses and remitted to a dedicated "Coastal Resilience Fund."
#     *   **Potential:** Given the city's tourism-dependent economy, this could generate $10-20 million annually (assuming $1 billion annual tourism revenue), accumulating to $300-600 million over 30 years.
#     *   **Benefit:** Directly links the industry benefiting from coastal attractions to their preservation. Tourists often accept small surcharges for environmental causes.
#
# 3.  **Public-Private Partnerships (PPPs) & Federal/State Grant Pursuit:** Actively pursue co-funding and partnerships for large-scale projects.
#     *   **Mechanism:**
#         *   **PPPs:** For projects benefiting specific private entities (e.g., port upgrades, beachfront resort protection), private developers or businesses contribute to project costs in exchange for long-term operational benefits or preferential leases.
#         *   **Federal/State Grants:** Dedicated grants for coastal resilience, infrastructure, wetland restoration, and community development.
#     *   **Potential:** Highly variable, but successful grant applications and PPPs could unlock hundreds of millions of dollars (e.g., $100-300 million over 30 years).
#     *   **Benefit:** Leverages external capital and expertise, reduces direct city burden, and ensures alignment with national/state resilience goals.
#
# ## IV. Governance and Community-Engagement Measures
#
# Ensuring equity and effectiveness requires robust governance and continuous community involvement:
#
# *   **1. City Resilience Office (CRO):** Establish a dedicated office with a Chief Resilience Officer reporting directly to the Mayor. This office will be responsible for plan implementation, inter-departmental coordination, external partnerships, and monitoring.
# *   **2. Multi-Stakeholder Resilience Task Force:** Create an oversight body comprising city officials, scientists, business leaders (tourism, fisheries), environmental NGOs, community representatives (including representatives from vulnerable groups), and cultural heritage experts. This task force will provide strategic guidance and ensure broad buy-in.
# *   **3. Neighborhood Resilience Hubs & Advisory Boards:** For areas most affected by proposed interventions (e.g., managed retreat zones, areas receiving new defenses), establish local hubs and dedicated advisory boards. These will serve as direct channels for feedback, co-design of solutions, and grievance resolution, ensuring the "poorest 20% not worse off" clause is upheld.
# *   **4. Dedicated Equity & Relocation Ombudsman:** An independent ombudsman will oversee the managed retreat and social support programs, ensuring fair compensation, equitable relocation options, and access to resources for affected households, particularly the poorest 20%.
# *   **5. Transparent Communication & Accessible Data:** Implement a public-facing dashboard showing project progress, spending, and monitoring data. Regular town halls, workshops, and accessible informational materials (multi-lingual) will foster trust and informed participation.
#
# ## V. Measurable Success Metrics and Monitoring Strategies
#
# **Measurable Success Metrics:**
#
# 1.  **Reduced Economic Losses:**
#     *   **Metric:** X% reduction in average annual direct property damages (residential, commercial) from storm events compared to the 5-year average pre-plan. Target: **30% reduction by Year 10, 60% by Year 20, 75% by Year 30.**
#     *   **Metric:** X% reduction in average annual business interruption losses from storm events. Target: **25% reduction by Year 10, 50% by Year 20, 70% by Year 30.**
# 2.  **Coastal Protection & Infrastructure Resilience:**
#     *   **Metric:** X km of coast protected by nature-based solutions (Target: 40 km).
#     *   **Metric:** X km of critical hard defenses constructed/elevated (Target: 30 km).
# ...
# | **Social cost of carbon (SCC)** | **$55 / t CO₂** (2025) | US DOT SCC 2021 |
# | **Construction cost index (CCI)** | 1.0 in 2025; 1.5 by 2070 (inflation + material) | AIA construction cost forecast |
# | **Equity threshold** | Bottom‑quintile household income = **$30 k / yr** | City tax‑records |
# | **Maximum acceptable net‑present‑value (NPV) loss for poorest 20 %** | **0** (no net loss) | Policy mandate |
#
# All monetary figures are **real dollars** (inflation‑adjusted).
#
# ---
#
# ## 3.  Phase‑Based Budget Allocation
#
# | Phase | Years | Main Objectives | Core Interventions (cost) | % of $2 B | Real‑term spending (US$) |
# |-------|-------|----------------|--------------------------|----------|---------------------------|
# | **Phase 1 – Foundations** | **1‑5** | Rapid risk reduction, data, governance set‑up | • 1 km “Living‑Shoreline” pilot (wetland + oyster reef) – $40 M  <br>• City‑wide Flood‑Risk Mapping & Early‑Warning System – $30 M  <br>• Equity‑Resilience Office (staff, advisory board) – $10 M  <br>• Pilot “Elevate‑Critical‑Infrastructure” (water treatment plant) – $60 M | 7 % | **$140 M** |
# | **Phase 2 – Hard + Nature‑Based Defenses** | **6‑15** | Protect high‑value tourism & cultural assets, create buffer zones | • **Storm‑Surge Barrier** at main harbor (gate + levee) – $600 M  <br>• **Living‑Shoreline Expansion** (5 km of marsh & dune restoration) – $150 M  <br>• **Elevated Road Network** (primary arterial & evacuation routes) – $250 M  <br>• **Green Roof & Flood‑Resilient Housing Retrofits** for 3 000 low‑income units – $120 M  | 62 % | **$1 240 M** |
# | **Phase 3 – Managed Retreat & Adaptive Growth** | **16‑30** | Relocate untenable zones, re‑zone, sustain fisheries & tourism | • **Buy‑out & Relocation Program** for 1 500 properties in the historic waterfront (≈15 % of at‑risk housing) – $350 M  <br>• **New “Resilient Waterfront”** mixed‑use district on reclaimed upland (public‑private) – $300 M (city equity, private capital)  <br>• **Fisheries Port Modernisation** (dry‑dock, flexible‑pier, habitat zones) – $150 M  <br>• **Adaptive Tourism Hub** (climate‑proof hotels, boardwalks) – $120 M  | 31 % | **$620 M** |
# | **Contingency & Administration** | **All** | 5 % of total for overruns, monitoring, community outreach | — | **5 %** | **$100 M** |
# | **Total** | **30 yr** | — | — | **100 %** | **$2 000 M** |
#
# *All spending is front‑loaded to the first 15 yr because early risk reduction yields the highest NPV (see Section 5).*
#
# ---
#
# ## 4.  Intervention‑by‑Intervention Benefit‑Cost Summary
#
# | # | Intervention | Lifetime (yr) | NPV of Benefits* | NPV of Costs** | B/C Ratio (3 % disc.) | Primary Benefits (quantified) |
# |---|--------------|--------------|------------------|----------------|----------------------|--------------------------------|
# | 1 | Living‑Shoreline pilot (1 km) | 30 | $95 M | $40 M | **2.4** | • 0.15 km² marsh sequesters 0.3 Mt CO₂ → $16 M SCC benefit  <br>• Flood attenuation: 0.8 m reduction → $12 M avoided damage annually (PV $120 M) |
# | 2 | City‑wide Flood‑Risk Mapping + Early‑Warning | 30 | $80 M | $30 M | **2.7** | • 15 % reduction in storm‑surge casualties (value of statistical life $9 M) → $12 M PV <br>• Faster recovery saves $6 M/yr in business interruption |
# | 3 | Storm‑Surge Barrier (harbor) | 30 | $1 200 M | $600 M | **2.0** | • Protects $3 B of tourism & port assets (PV) → $1 200 M avoided loss <br>• Enables continued operation of heritage cruise terminal |
# | 4 | Living‑Shoreline expansion (5 km) | 30 | $400 M | $150 M | **2.7** | • Adds 0.75 km² wetland → $45 M SCC + $30 M flood protection <br>• Enhances fish nursery → $20 M fisheries revenue |
# | 5 | Elevated Road Network (10 km) | 30 | $520 M | $250 M | **2.1** | • Keeps evacuation routes functional → $40 M saved in life‑value <br>• Prevents $30 M/yr in freight disruption |
# | 6 | Flood‑Resilient Housing Retrofits (3 000 units) | 30 | $260 M | $120 M | **2.2** | • Keeps 3 000 low‑income families in place → $45 M avoided relocation cost <br>• Energy‑efficiency savings $5 M/yr |
# | 7 | Buy‑out & Relocation (1 500 homes) | 30 | $470 M | $350 M | **1.3** | • Eliminates exposure of 4 % of city‑wide built‑up area <br>• Opens land for public park (social value $30 M) |
# | 8 | Resilient Waterfront (mixed‑use) | 30 | $560 M | $300 M | **1.9** | • Generates $80 M/yr new tax base (PV $560 M) <br>• Provides climate‑safe tourism capacity |
# | 9 | Fisheries Port Modernisation | 30 | $340 M | $150 M | **2.3** | • 12 % increase in landed value (≈$15 M/yr) <br>• Habitat zones boost stock recruitment (+$5 M/yr) |
# |10 | Adaptive Tourism Hub | 30 | $260 M | $120 M | **2.2** | • 10 % reduction in climate‑related occupancy loss → $26 M/yr revenue retained |
#
# \* **NPV of Benefits** includes avoided flood damages, avoided loss of life (VSL = $9 M), ecosystem‑service valuation, and incremental economic activity.
# \** **NPV of Costs** includes construction, O&M (5 % of capital per yr), and de‑commissioning (if any).
#
# **Total NPV of benefits ≈ $5.1 B**, **NPV of costs = $2.0 B**, **aggregate B/C = 2.6** – a strong economic case even after discounting.
#
# ---
#
# ## 5.  Geographic Prioritisation (Who is Protected, Relocated, Abandoned?)
#
# | Area (population / assets) | Elevation (m ASL) | Current risk (2025) | Intervention | Status by 2050 |
# |----------------------------|-------------------|----------------------|--------------|----------------|
# | **A. Historic Harbor & Tourist Promenade** (≈15 % of tourism revenue) | 0‑0.5 | High (≥30 % chance of >1 m surge) | Storm‑Surge Barrier + levee + heritage‑site elevation | **Protected** – barrier operational; key heritage buildings lifted/retro‑fitted |
# | **B. Low‑income coastal district “Bayview”** (≈12 % of poorest 20 % households) | 0‑1.2 | Very high (annual flood >2 ×) | Buy‑out & relocation to new inland public housing (Phase 3) | **Relocated** – compensated at market + 20 % premium; new units meet “climate‑safe” standards |
# | **C. Commercial fishing village “Marlon”** (≈8 % of fisheries employment) | 0‑0.8 | Moderate‑high | Port modernisation + living‑shoreline buffer | **Protected** – flexible pier and habitat zones; fishery revenue projected +12 % |
# | **D. Central downtown (mid‑elevation, 3‑5 m) ** | 3‑5 | Low | Elevate key utilities (water, power) | **Protected** – utilities remain functional during surge |
# | **E. Suburban fringe (≥5 m)** | >5 | Negligible | No major action | **Monitor only** – low risk, no direct spend |
# | **F. Former “Old Dock” industrial zone (contaminated, 0‑0.4 m)** | 0‑0.4 | Very high | **Abandoned** – no buy‑out; site converted to open‑space floodplain (no residential use) | **Converted to green buffer** – reduces wave energy, improves ecosystem services |
#
# *Equity safeguard:* The relocation package for Bayview includes a **job‑training fund** ($30 M) and a **rent‑control guarantee** for the first 10 yr in the new district, ensuring the poorest 20 % are not financially worse off.
#
# ---
#
# ## 6.  Additional Financing Mechanisms (Beyond the $2 B Baseline)
#
# | Mechanism | Structure | Expected Yield (30 yr) | Use of Proceeds |
# |-----------|-----------|------------------------|-----------------|
# | **1. Green Municipal Bonds** | 30‑yr, tax‑exempt, rated “A‑”. Issued by the City, backed by future property‑tax increment from the Resilient Waterfront. | $300 M (≈$10 M/yr for O&M) | Funds Phase 2 barrier & Phase 3 waterfront |
# | **2. State/Federal Climate Adaptation Grants** | Competitive grant (e.g., FEMA Hazard Mitigation Grant Program, NOAA Climate Resilience Grants). | $150 M (non‑repayable) | Covers 30 % of living‑shoreline and early‑warning system |
# | **3. Public‑Private Partnerships (PPP) for Tourism Hub** | Long‑term lease‑back: private operator builds climate‑proof hotel, city receives 10 % of gross revenues for 20 yr. | $200 M equity from private sector (city contributes $20 M) | Enables Adaptive Tourism Hub with minimal upfront city outlay |
# | **4. Resilience Impact Fees on New Development** | $5 / ft² of new waterfront construction, collected for 20 yr. | ≈ $70 M | Dedicated to O&M of storm‑surge barrier |
# | **5. Insurance‑linked Securities (Cat‑Bonds)** | 10‑yr bond tied to storm‑surge index; triggers payout if >2 m surge occurs. | $50 M (contingent) | Provides emergency cash‑flow for rapid repairs |
#
# *Total “leveraged” additional resources ≈ **$770 M**, which can be reinvested to expand nature‑based solutions or increase the scale of managed retreat.*
#
# ---
#
# ## 7.  Governance & Community‑Engagement (Equity Lens)
#
# 1. **Resilience Office (RO)** – reports to the Mayor, chaired by the City Planner, with a statutory **Equity Advisory Council (EAC)** (5 elected community reps from poorest quintile, 2 NGOs, 2 academia).
# 2. **Participatory Budget Workshops** – every 5 yr, the RO presents a **“Resilience Budget Draft”**; residents vote on priority projects (non‑binding but informs final allocation).
# 3. **Transparent Data Portal** – open‑source GIS showing risk maps, project status, expenditures, and performance metrics (updated quarterly).
# 4. **Legal Safeguard** – any buy‑out contract must contain a “No‑Net‑Loss” clause: compensation ≥ market value + 20 % + relocation assistance.
# 5. **Capacity‑Building Grants** – $15 M over 30 yr earmarked for local NGOs to run climate‑literacy programs in schools and community centres, targeting low‑income neighbourhoods.
#
# ---
#
# ## 8.  Success Metrics & Monitoring Plan
#
# | Metric (target) | Baseline (2025) | Target (2050) | Measurement Frequency | Data Source |
# |-----------------|-----------------|---------------|-----------------------|-------------|
# | **Annual Expected Flood Damage** | $200 M | **<$30 M** (≈85 % reduction) | Yearly post‑event | City Insurance & FEMA claims |
# | **Number of households in poorest 20 % in flood‑prone zone** | 7 500 | **≤1 000** (≥86 % relocated/protected) | Annual census | City
#
# # Response from competitor 6
#
# **Adaptation Plan**
#
# The proposed 30-year adaptation plan allocates the $2.0B budget across six concrete interventions, prioritizing those with the highest expected benefits and lowest costs.
#
# 1. **Sea Wall and Pump Replacement** (Year 1-5, $400M)
# Expected economic benefit: Reduce flood damage by 80% ($60M/year), increase property values by 25%
# Social benefit: Enhance quality of life, reduce displacement of vulnerable residents
# Environmental benefit: Protect infrastructure, preserve ecological habitats
# Costs estimated using a 4m/s flood velocity and storm surge frequency data; assuming an economic damages function, with higher expected benefits at lower cost thresholds (γ = 2.5).
#
# Phase-by-Phase Allocation:
# Year 1 - $40M for sea wall design and permitting
# Year 2 - $40M for pump installation
# Year 3 - $50M for sea level rise data analysis and policy development
# Year 4 - $75M for sea wall construction
# Year 5 - $55M for punch list items (accessibility, erosion control)
#
# Benefit-Cost Ratio: Estimated 3.9
#
# 2. **Erosion Mitigation in High-Risk Areas** (Year 5-10, $150M)
# Expected social benefit: Preserve low-income and elderly neighborhoods ($30M/year), reduce displacement risk
# Environmental benefits: Protect ecological habitats and infrastructure
#
# Benefit-Cost Ratio: Estimated 4.3
#
# Phase-by-Phase Allocation:
# Year 5 - $15M for site assessments and planning
# Year 6 - $20M for erosion control measures (vegetation, seawalls)
# Year 7 - $30M for construction of beach nourishment project
# Year 8 - $25M for restoration of habitats
# Year 9 - $20M for monitoring and maintenance
# Year 10 - $20M for community engagement and outreach
#
# 3. **Resilient Buildings and Infrastructure** (Year 5-15, $800M)
# Expected economic benefit: Reduce business interruption costs by 70% ($125M/year), increase property values by 15%
# Social benefit: Enhance quality of life, reduce displacement risk
# Environmental benefits: Protect infrastructure and ecological habitats
#
# Benefit-Cost Ratio: Estimated 3.9
#
# Phase-by-Phase Allocation:
# Year 5 - $50M for building codes update and training
# Year 6 - $80M for foundation reinforcement ( foundations, piers)
# Year 7 - $100M for elevated walkways and boardwalks
# Year 8 - $120M for seawall support structures
# Year 9 - $75M for roof reinforcements
# Year 10-15 - $350M for ongoing maintenance and monitoring
#
# 4. **Ecological Restoration** (Year 5-20, $200M)
# Expected social benefit: Support ecosystem services, preserve biodiversity ($40M/year), reduce storm surges ($10M/year)
# Environmental benefits: Preserve ecological habitats, restore natural barriers to ocean waves
#
# Benefit-Cost Ratio: Estimated 3.6
#
# Phase-by-Phase Allocation:
# Year 5 - $10M for habitat monitoring and restoration planning
# Year 6-10 - $20M for wetland restoration
# Year 11-15 - $40M for mangrove enhancement projects
# Year 16-20 - $50M for larger-scale ecological restoration initiatives
#
# 5. **Cultural Heritage Preservation** (Year 5-25, $150M)
# Expected social benefit: Preserve community history and cultural identity ($30M/year), support local heritage industries
# Environmental benefits: Reduce disruption caused by urban planning
#
# Benefit-Cost Ratio: Estimated 3.9
#
# Phase-by-Phase Allocation:
# Year 5 - $12M for heritage analysis and planning
# Year 6-8 - $20M for historic building restorations
# Year 9-15 - $30M for community engagement and education initiatives
# Year 16-25 - $60M for ongoing preservation and management
#
# 6. **Climate-Resilient Water** (Year 10-30, $200M)
# Expected social benefit: Address water quality concerns ($40M/year), strengthen wastewater infrastructure
# Environmental benefits: Reduce aquatic pollution
#
# Benefit-Cost Ratio: Estimated 4.5
#
# Phase-by-Phase Allocation:
# Year 10 - $15M for climate-resilient sewer design and implementation
# Year 11-20 - $60M for upgrades to the city's water treatment plant
# Year 21-25 - $35M for rehabilitation of affected aquifers
#
# **Funding and Finance Mechanisms**
#
# To supplement the $2.0B budget, we propose:
#
# 1. **Grants and Public Partnerships**: Collaborate with state, federal, and NGO partners to leverage an additional $100M over 10 years.
# 2. **Green Bond Financing**: Issues a climate-resilient infrastructure bond ($500M) within the first five years of our plan, taking advantage of favorable funding structures and expected long-term returns.
# 3. **Insurance Premiums**: Develop and manage specialized insurance products and premiums ($200M), leveraging municipal expertise alongside private sector risk management best practices.
#
# **Governance and Community Engagement**
#
# The administration will ensure equitable participation through:
#
# 1. City-led stakeholder groups
# 2. Regular public forums and consultations
# 3. Training programs on climate change and planning processes for vulnerable communities
#
# To verify the effectiveness of our plan, we have established measurable objectives like (a) a reduction of 20% in damages due to flooding and erosion within three decades; (b) community satisfaction rates >60% regarding overall quality of life by end Year 15.
#
# **Sensitivity Analysis**
#
# If parameters change,
#
# 1. An increase or decrease in damage functions would adjust relative priority allocation among projects.
# 2. Changes in economic discount rate impact return on investment, adjusting the final benefit-cost ratios and resource distribution across all projects.
# 3. Estimated impacts on public confidence would lead prioritization of long-term community benefits
#
# **Three Important Risks/Risk Modes and Contingency Actions**
#
# 1. Underestimated sea level rise or storm surge severity: Implement monitoring stations for updated predictions; reassess project durations under increased timelines.
#
# 2. Unsatisfactory stakeholder consensus, hindering adaptation planning feasibility.
#
# 3. Failure to implement effective measures to address inequality among target groups—revisit planning processes with community feedback and re-critical review the project's benefits distribution assumptions
#
#
#
# Now respond with the JSON with the ranked order of the competitors, nothing else. Do not include markdown formatting or code blocks.

# %%
judge_messages = [{"role": "user", "content": judge}]

# %%
# Judgement time!

openai = OpenAI()
response = openai.chat.completions.create(
    model="gpt-5-mini",
    messages=judge_messages,
)
results = response.choices[0].message.content
print(results)
# Out:
# {"results": ["3", "1", "5", "4", "6", "2"]}

# %%
# OK let's turn this into results!

results_dict = json.loads(results)
ranks = results_dict["results"]
for index, result in enumerate(ranks):
    competitor = competitors[int(result)-1]
    print(f"Rank {index+1}: {competitor}")
# Out:
# Rank 1: gemini-2.5-flash
# Rank 2: gpt-5-nano
# Rank 3: openai/gpt-oss-120b
# Rank 4: deepseek-chat
# Rank 5: llama3.2
# Rank 6: claude-sonnet-4-5

# %%
# Mixture of Experts judging: each competitor model also acts as a judge.
# Rankings are converted to points (1st = N pts, last = 1 pt), then averaged.

def get_judgment(model_name, messages):
    """Call the appropriate API for a given model and return raw text."""
    if model_name == "claude-sonnet-4-5":
        response = claude.messages.create(model=model_name, messages=messages, max_tokens=500)
        return response.content[0].text
    elif model_name == "gemini-2.5-flash":
        response = gemini.chat.completions.create(model=model_name, messages=messages)
        return response.choices[0].message.content
    elif model_name == "deepseek-chat":
        response = deepseek.chat.completions.create(model=model_name, messages=messages)
        return response.choices[0].message.content
    elif model_name == "openai/gpt-oss-120b":
        response = groq.chat.completions.create(model=model_name, messages=messages)
        return response.choices[0].message.content
    elif model_name == "llama3.2":
        response = ollama.chat.completions.create(model=model_name, messages=messages)
        return response.choices[0].message.content
    else:  # gpt-5-nano and other OpenAI models
        response = openai.chat.completions.create(model=model_name, messages=messages)
        return response.choices[0].message.content

def parse_ranks(raw_text):
    """Parse JSON ranking, stripping markdown fences if the model added them."""
    text = raw_text.strip().removeprefix("```json").removeprefix("```").removesuffix("```").strip()
    return [int(r) for r in json.loads(text)["results"]]

n = len(competitors)
scores = [0] * n
successful_judges = 0

for judge_model in competitors:
    print(f"Judging: {judge_model}...")
    try:
        raw = get_judgment(judge_model, judge_messages)
        ranks = parse_ranks(raw)
        # Rank 1 earns n points, rank n earns 1 point
        for position, competitor_num in enumerate(ranks):
            scores[competitor_num - 1] += n - position
        successful_judges += 1
    except Exception as e:
        print(f"  Skipped {judge_model} — {e}")

avg_scores = [s / successful_judges if successful_judges else 0 for s in scores]
ranked = sorted(enumerate(avg_scores), key=lambda x: x[1], reverse=True)

print(f"\n=== Mixture of Experts Rankings ({successful_judges} judges) ===\n")
for rank, (idx, avg) in enumerate(ranked, 1):
    print(f"Rank {rank}: {competitors[idx]}  (avg score: {avg:.2f})")
# Out:
# Judging: gpt-5-nano...
# Judging: claude-sonnet-4-5...
# Judging: gemini-2.5-flash...
# Judging: deepseek-chat...
# Judging: openai/gpt-oss-120b...
#   Skipped openai/gpt-oss-120b — Error code: 413 - {'error': {'message': 'Request too large for model `openai/gpt-oss-120b` in organization `org_01kjjez7sne8b8h20g6emame1j` service tier `on_demand` on tokens per minute (TPM): Limit 8000, Requested 20214, please reduce your message size and try again. Need more tokens? Upgrade to Dev Tier today at https://console.groq.com/settings/billing', 'type': 'tokens', 'code': 'rate_limit_exceeded'}}
# Judging: llama3.2...
#   Skipped llama3.2 — Extra data: line 1 column 29 (char 28)
#
# === Mixture of Experts Rankings (4 judges) ===
#
# Rank 1: gemini-2.5-flash  (avg score: 5.50)
# Rank 2: gpt-5-nano  (avg score: 4.75)
# Rank 3: deepseek-chat  (avg score: 4.50)
# Rank 4: openai/gpt-oss-120b  (avg score: 2.75)
# Rank 5: claude-sonnet-4-5  (avg score: 2.00)
# Rank 6: llama3.2  (avg score: 1.50)

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/exercise.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#ff7800;">Exercise</h2>
#             <span style="color:#ff7800;">Which pattern(s) did this use? Try updating this to add another Agentic design pattern.
#             </span>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/business.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#00bfff;">Commercial implications</h2>
#             <span style="color:#00bfff;">These kinds of patterns - to send a task to multiple models, and evaluate results,
#             are common where you need to improve the quality of your LLM response. This approach can be universally applied
#             to business projects where accuracy is critical.
#             </span>
#         </td>
#     </tr>
# </table>
